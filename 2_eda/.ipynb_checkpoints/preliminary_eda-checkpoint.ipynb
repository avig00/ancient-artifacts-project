# %% [markdown]
# ## load packages

# %%
# !pwd
# !ls
# Out:
# /Users/ricky/Desktop/sp23-ancient-artifacts-team8
# 0_data    2_eda     README.md

# %%
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## read data

# %%
master_micro = pd.read_csv("0_data/master.csv")

# %%
micro = master_micro[(master_micro['size_micro']=="unknown")].iloc[: , 1:]

# %%
micro
# Out:
#           Id  Img Id      Da      Dp  FWidth  FLength  FThickness  ELength  \
# 0        104   10708  30.893  38.251  36.878   46.822      10.179   44.168
# 1         19    5682  27.727  33.375  35.149   40.001       9.029   39.022
# 2         14    4826  26.726  36.061  30.199   46.332       8.025   47.365
# 3          1    2812  24.408  36.198  25.039   57.353       5.086   50.536
# 4         83    9441  22.869  29.388  24.044   39.820       4.390   38.568
# ...      ...     ...     ...     ...     ...      ...         ...      ...
# 78607  56682   19419   0.037   0.089   0.019    0.135       0.019    0.044
# 78608  71921   26912   0.035   0.064   0.036    0.080       0.036    0.077
# 78609  64014   24046   0.035   0.073   0.039    0.087       0.039    0.092
# 78610  67033   25158   0.029   0.075   0.040    0.084       0.040    0.095
# 78611  61189   22586   0.024   0.071   0.035    0.082       0.035    0.105
#
#        EThickness  EWidth    Volume     Area  Perimeter  CHull  Area  \
# 0          10.102  34.444  9202.973  749.562    120.170      802.914
# 1           7.978  34.108  6646.859  603.785    104.849      636.820
# 2           7.753  28.230  5879.233  560.995    113.290      642.874
# 3           4.904  23.943  3824.409  467.900    113.719      500.291
# 4           3.948  22.535  2200.862  410.744     92.327      436.309
# ...           ...     ...       ...      ...        ...          ...
# 78607       0.016   0.016     0.000    0.001      0.279        0.001
# 78608       0.015   0.015     0.000    0.001      0.202        0.002
# 78609       0.018   0.018     0.000    0.001      0.228        0.002
# 78610       0.024   0.024     0.000    0.001      0.235        0.002
# 78611       0.026   0.026     0.000    0.000      0.224        0.002
#
#        CHull Perimeter  Sphericity  L/T Ratio  T/L Aspect Ratio  Compactness  \
# 0              108.399       0.808      4.600             0.217        0.660
# 1               99.590       0.831      4.430             0.226        0.693
# 2              100.583       0.741      5.774             0.173        0.577
# 3              108.846       0.674     11.276             0.089        0.426
# 4               89.254       0.778      9.070             0.110        0.574
# ...                ...         ...        ...               ...          ...
# 78607            0.274       0.416      6.914             0.145        0.274
# 78608            0.194       0.545      2.237             0.447        0.440
# 78609            0.211       0.478      2.232             0.448        0.401
# 78610            0.210       0.390      2.078             0.481        0.348
# 78611            0.199       0.338      2.329             0.429        0.296
#
#        Roundness  Ellipse Ratio  Circularity  Solidity  Concavity  Convexity  \
# 0          0.435          0.229        0.652     0.934      0.066      0.902
# 1          0.480          0.204        0.690     0.948      0.052      0.950
# 2          0.333          0.164        0.549     0.873      0.127      0.888
# 3          0.181          0.097        0.455     0.935      0.065      0.957
# 4          0.330          0.102        0.606     0.941      0.059      0.967
# ...          ...            ...          ...       ...        ...        ...
# 78607      0.075          0.370        0.173     0.720      0.280      0.984
# 78608      0.193          0.190        0.297     0.577      0.423      0.960
# 78609      0.161          0.200        0.229     0.440      0.560      0.928
# 78610      0.121          0.256        0.152     0.317      0.683      0.894
# 78611      0.087          0.246        0.114     0.246      0.754      0.887
#
#        Extent  hash  Transparency  Curvature  Surface Area Filter0 Filter1  \
# 0       1.573     0         0.081        0.0      2998.247  Reject  Reject
# 1       1.672     0         0.126        0.0      2415.141  Reject  Reject
# 2       1.509     0         0.096        0.0      2243.981  Reject  Reject
# 3       1.604     0         0.088        0.0      1871.602  Reject  Reject
# 4       2.350     0         0.077        0.0      1642.977  Reject  Reject
# ...       ...   ...           ...        ...           ...     ...     ...
# 78607   0.409     0         0.660        0.0         0.004  Reject  Reject
# 78608   0.340     0         0.545        0.0         0.004  Reject  Reject
# 78609   0.282     0         0.514        0.0         0.004  Reject  Reject
# 78610   0.197     0         0.519        0.0         0.003  Reject  Reject
# 78611   0.160     0         0.564        0.0         0.002  Reject  Reject
#
#       Filter2 Filter3 Filter4 Filter5 Filter6  L/W Ratio  W/L Ratio  \
# 0      Reject  Reject  Reject  Reject  Reject      1.270      0.788
# 1      Reject  Reject  Reject  Reject  Reject      1.138      0.879
# 2      Reject  Reject  Reject  Reject  Reject      1.534      0.652
# 3      Reject  Reject  Reject  Reject  Reject      2.291      0.437
# 4      Reject  Reject  Reject  Reject  Reject      1.656      0.604
# ...       ...     ...     ...     ...     ...        ...        ...
# 78607  Reject  Reject  Reject  Reject  Reject      6.914      0.145
# 78608  Reject  Reject  Reject  Reject  Reject      2.237      0.447
# 78609  Reject  Reject  Reject  Reject  Reject      2.232      0.448
# 78610  Reject  Reject  Reject  Reject  Reject      2.078      0.481
# 78611  Reject  Reject  Reject  Reject  Reject      2.329      0.429
#
#        W/T Ratio  T/W Ratio  CHull Surface Area   Sieve  Angularity  \
# 0          3.623      0.276            3211.655  23.529      19.392
# 1          3.893      0.257            2547.278  22.089      20.688
# 2          3.763      0.266            2571.497  19.112      21.250
# 3          4.923      0.203            2001.165  15.063      18.233
# 4          5.477      0.183            1745.237  14.217      17.086
# ...          ...        ...                 ...     ...         ...
# 78607      1.000      1.000               0.006   0.019       0.000
# 78608      1.000      1.000               0.007   0.036      85.000
# 78609      1.000      1.000               0.009   0.039       0.000
# 78610      1.000      1.000               0.008   0.040     113.333
# 78611      1.000      1.000               0.007   0.035     113.333
#
#        Ellipticity  Fiber Length  Fiber Width  Krumbein Rnd size_micro  \
# 0            4.372        49.768       22.823         0.214    unknown
# 1            4.891        37.445        5.128         0.214    unknown
# 2            6.110        52.384       17.379         0.219    unknown
# 3           10.304        51.467       17.096         0.251    unknown
# 4            9.769        36.426        3.135         0.276    unknown
# ...            ...           ...          ...           ...        ...
# 78607        2.705         0.000        0.000         1.000    unknown
# 78608        5.253         0.000        0.000         1.000    unknown
# 78609        4.990         0.000        0.000         1.000    unknown
# 78610        3.906         0.000        0.000         1.000    unknown
# 78611        4.060         0.000        0.000         1.000    unknown
#
#       type_micro
# 0         lithic
# 1         lithic
# 2         lithic
# 3         lithic
# 4         lithic
# ...          ...
# 78607       soil
# 78608       soil
# 78609       soil
# 78610       soil
# 78611       soil
#
# [78612 rows x 50 columns]

# %%
# soil = pd.read_csv("0_data/ArchaeologicalSoilData.csv", skiprows=[1])
# lithic = pd.read_csv("0_data/LithicExperimentalData.csv", skiprows=[1])

# %%
# pd.set_option('display.max_columns', None)
# soil.head()

# %%
# pd.set_option('display.max_columns', None)
# lithic.head()

# %%
# soil_0125 = pd.read_csv("0_data/Experiment9-SandGravel-0.125mm.csv", skiprows=[1])
# soil_025 = pd.read_csv("0_data/Experiment9-SandGravel-0.25mm.csv", skiprows=[1])
# soil_05 = pd.read_csv("0_data/Experiment9-SandGravel-0.5mm.csv", skiprows=[1])
# soil_1 = pd.read_csv("0_data/Experiment9-SandGravel-1mm.csv", skiprows=[1])
# soil_2 = pd.read_csv("0_data/Experiment9-SandGravel-2mm.csv", skiprows=[1])
# soil_4 = pd.read_csv("0_data/Experiment9-SandGravel-4mm.csv", skiprows=[1])

# %% [markdown]
# ## Merge data (labelling)

# %%
# # Add a new column to indicate the group
# soil_0125 = soil_0125.assign(size_micro = '0.125mm')
# soil_025 = soil_025.assign(size_micro = '0.25mm')
# soil_05 = soil_05.assign(size_micro = '0.5mm')
# soil_1 = soil_1.assign(size_micro = '1mm')
# soil_2 = soil_2.assign(size_micro = '2mm')
# soil_4 = soil_4.assign(size_micro = '4mm')
# lithic = lithic.assign(size_micro = 'unknown')
# soil = soil.assign(size_micro = 'unknown')

# soil_0125 = soil_0125.assign(type_micro = 'soil')
# soil_025 = soil_025.assign(type_micro = 'soil')
# soil_05 = soil_05.assign(type_micro = 'soil')
# soil_1 = soil_1.assign(type_micro = 'soil')
# soil_2 = soil_2.assign(type_micro = 'soil')
# soil_4 = soil_4.assign(type_micro = 'soil')
# lithic = lithic.assign(type_micro = 'lithic')
# soil = soil.assign(type_micro = 'soil')

# # Concatenate the data sets along the rows
# micro_data = pd.concat([lithic,soil,soil_0125,soil_025,soil_05,soil_1,soil_2,soil_4], axis=0)

# %%
# micro_data

# %% [markdown]
# ## Output to master data

# %%
# micro_data.to_csv('0_data/master.csv')

# %% [markdown]
# ## Missingness

# %%
missing_values = micro.isnull().sum()
missing_values
# Out:
# Unnamed: 0                 0
# Id                         0
# Img Id                     0
# Da                         0
# Dp                         0
# FWidth                     0
# FLength                    0
# FThickness                 0
# ELength                    0
# EThickness                 0
# EWidth                     0
# Volume                     0
# Area                       0
# Perimeter                  0
# CHull  Area                0
# CHull Perimeter            0
# Sphericity                 0
# L/T Ratio                  0
# T/L Aspect Ratio           0
# Compactness                0
# Roundness                  0
# Ellipse Ratio              0
# Circularity                0
# Solidity                   0
# Concavity                  0
# Convexity                  0
# Extent                     0
# hash                       0
# Transparency               0
# Curvature                  0
# Surface Area               0
# Filter0                    0
# Filter1                    0
# Filter2                    0
# Filter3                    0
# Filter4                    0
# Filter5                    0
# Filter6                    0
# L/W Ratio                  0
# W/L Ratio                  0
# W/T Ratio                  0
# T/W Ratio                  0
# CHull Surface Area         0
# Sieve                      0
# Angularity                 0
# Ellipticity                0
# Fiber Length               0
# Fiber Width                0
# Krumbein Rnd          405041
# size_micro                 0
# type_micro                 0
# dtype: int64

# %%
msno.matrix(micro)
