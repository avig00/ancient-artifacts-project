# %% [markdown]
# ## load package

# %%
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.utils import resample

# %%
import lazypredict

# %% [markdown]
# ## import data

# %%
# !pwd
# Out:
# /Users/ricky/Desktop/sp23-ancient-artifacts-team8/3_ml

# %%
master_micro = pd.read_csv("../0_data/master.csv")

# %%
master_micro
# Out:
#         Unnamed: 0   Id  Img Id      Da      Dp  FWidth  FLength  FThickness  \
# 0                0  104   10708  30.893  38.251  36.878   46.822      10.179
# 1                1   19    5682  27.727  33.375  35.149   40.001       9.029
# 2                2   14    4826  26.726  36.061  30.199   46.332       8.025
# 3                3    1    2812  24.408  36.198  25.039   57.353       5.086
# 4                4   83    9441  22.869  29.388  24.044   39.820       4.390
# ...            ...  ...     ...     ...     ...     ...      ...         ...
# 483648         600  591   13305   0.146   0.155   0.129    0.168       0.129
# 483649         601  464   10826   0.137   0.141   0.128    0.155       0.128
# 483650         602  236    8388   0.144   0.149   0.128    0.163       0.128
# 483651         603  369    9727   0.148   0.154   0.126    0.179       0.126
# 483652         604  481   11134   0.142   0.154   0.126    0.186       0.126
#
#         ELength  EThickness  ...  T/W Ratio  CHull Surface Area   Sieve  \
# 0        44.168      10.102  ...      0.276            3211.655  23.529
# 1        39.022       7.978  ...      0.257            2547.278  22.089
# 2        47.365       7.753  ...      0.266            2571.497  19.112
# 3        50.536       4.904  ...      0.203            2001.165  15.063
# 4        38.568       3.948  ...      0.183            1745.237  14.217
# ...         ...         ...  ...        ...                 ...     ...
# 483648    0.166       0.131  ...      1.000               0.069   0.129
# 483649    0.147       0.127  ...      1.000               0.060   0.128
# 483650    0.156       0.132  ...      1.000               0.065   0.128
# 483651    0.174       0.126  ...      1.000               0.069   0.126
# 483652    0.173       0.119  ...      1.000               0.065   0.126
#
#         Angularity  Ellipticity  Fiber Length  Fiber Width  Krumbein Rnd  \
# 0           19.392        4.372        49.768       22.823         0.214
# 1           20.688        4.891        37.445        5.128         0.214
# 2           21.250        6.110        52.384       17.379         0.219
# 3           18.233       10.304        51.467       17.096         0.251
# 4           17.086        9.769        36.426        3.135         0.276
# ...            ...          ...           ...          ...           ...
# 483648      55.000        1.271         0.000        0.000           NaN
# 483649      63.750        1.164         0.000        0.000           NaN
# 483650      56.667        1.180         0.000        0.000           NaN
# 483651      56.667        1.383         0.000        0.000           NaN
# 483652      55.714        1.450         0.000        0.000           NaN
#
#         size_micro  type_micro
# 0          unknown      lithic
# 1          unknown      lithic
# 2          unknown      lithic
# 3          unknown      lithic
# 4          unknown      lithic
# ...            ...         ...
# 483648         4mm        soil
# 483649         4mm        soil
# 483650         4mm        soil
# 483651         4mm        soil
# 483652         4mm        soil
#
# [483653 rows x 51 columns]

# %%
micro = master_micro[(master_micro['size_micro']=="unknown") | (master_micro['type_micro']=="lithic")].iloc[: , 3:]

# %%
pd.set_option('display.max_columns', None)
micro
# Out:
#            Da      Dp  FWidth  FLength  FThickness  ELength  EThickness  \
# 0      30.893  38.251  36.878   46.822      10.179   44.168      10.102
# 1      27.727  33.375  35.149   40.001       9.029   39.022       7.978
# 2      26.726  36.061  30.199   46.332       8.025   47.365       7.753
# 3      24.408  36.198  25.039   57.353       5.086   50.536       4.904
# 4      22.869  29.388  24.044   39.820       4.390   38.568       3.948
# ...       ...     ...     ...      ...         ...      ...         ...
# 78607   0.037   0.089   0.019    0.135       0.019    0.044       0.016
# 78608   0.035   0.064   0.036    0.080       0.036    0.077       0.015
# 78609   0.035   0.073   0.039    0.087       0.039    0.092       0.018
# 78610   0.029   0.075   0.040    0.084       0.040    0.095       0.024
# 78611   0.024   0.071   0.035    0.082       0.035    0.105       0.026
#
#        EWidth    Volume     Area  Perimeter  CHull  Area  CHull Perimeter  \
# 0      34.444  9202.973  749.562    120.170      802.914          108.399
# 1      34.108  6646.859  603.785    104.849      636.820           99.590
# 2      28.230  5879.233  560.995    113.290      642.874          100.583
# 3      23.943  3824.409  467.900    113.719      500.291          108.846
# 4      22.535  2200.862  410.744     92.327      436.309           89.254
# ...       ...       ...      ...        ...          ...              ...
# 78607   0.016     0.000    0.001      0.279        0.001            0.274
# 78608   0.015     0.000    0.001      0.202        0.002            0.194
# 78609   0.018     0.000    0.001      0.228        0.002            0.211
# 78610   0.024     0.000    0.001      0.235        0.002            0.210
# 78611   0.026     0.000    0.000      0.224        0.002            0.199
#
#        Sphericity  L/T Ratio  T/L Aspect Ratio  Compactness  Roundness  \
# 0           0.808      4.600             0.217        0.660      0.435
# 1           0.831      4.430             0.226        0.693      0.480
# 2           0.741      5.774             0.173        0.577      0.333
# 3           0.674     11.276             0.089        0.426      0.181
# 4           0.778      9.070             0.110        0.574      0.330
# ...           ...        ...               ...          ...        ...
# 78607       0.416      6.914             0.145        0.274      0.075
# 78608       0.545      2.237             0.447        0.440      0.193
# 78609       0.478      2.232             0.448        0.401      0.161
# 78610       0.390      2.078             0.481        0.348      0.121
# 78611       0.338      2.329             0.429        0.296      0.087
#
#        Ellipse Ratio  Circularity  Solidity  Concavity  Convexity  Extent  \
# 0              0.229        0.652     0.934      0.066      0.902   1.573
# 1              0.204        0.690     0.948      0.052      0.950   1.672
# 2              0.164        0.549     0.873      0.127      0.888   1.509
# 3              0.097        0.455     0.935      0.065      0.957   1.604
# 4              0.102        0.606     0.941      0.059      0.967   2.350
# ...              ...          ...       ...        ...        ...     ...
# 78607          0.370        0.173     0.720      0.280      0.984   0.409
# 78608          0.190        0.297     0.577      0.423      0.960   0.340
# 78609          0.200        0.229     0.440      0.560      0.928   0.282
# 78610          0.256        0.152     0.317      0.683      0.894   0.197
# 78611          0.246        0.114     0.246      0.754      0.887   0.160
#
#        hash  Transparency  Curvature  Surface Area Filter0 Filter1 Filter2  \
# 0         0         0.081        0.0      2998.247  Reject  Reject  Reject
# 1         0         0.126        0.0      2415.141  Reject  Reject  Reject
# 2         0         0.096        0.0      2243.981  Reject  Reject  Reject
# 3         0         0.088        0.0      1871.602  Reject  Reject  Reject
# 4         0         0.077        0.0      1642.977  Reject  Reject  Reject
# ...     ...           ...        ...           ...     ...     ...     ...
# 78607     0         0.660        0.0         0.004  Reject  Reject  Reject
# 78608     0         0.545        0.0         0.004  Reject  Reject  Reject
# 78609     0         0.514        0.0         0.004  Reject  Reject  Reject
# 78610     0         0.519        0.0         0.003  Reject  Reject  Reject
# 78611     0         0.564        0.0         0.002  Reject  Reject  Reject
#
#       Filter3 Filter4 Filter5 Filter6  L/W Ratio  W/L Ratio  W/T Ratio  \
# 0      Reject  Reject  Reject  Reject      1.270      0.788      3.623
# 1      Reject  Reject  Reject  Reject      1.138      0.879      3.893
# 2      Reject  Reject  Reject  Reject      1.534      0.652      3.763
# 3      Reject  Reject  Reject  Reject      2.291      0.437      4.923
# 4      Reject  Reject  Reject  Reject      1.656      0.604      5.477
# ...       ...     ...     ...     ...        ...        ...        ...
# 78607  Reject  Reject  Reject  Reject      6.914      0.145      1.000
# 78608  Reject  Reject  Reject  Reject      2.237      0.447      1.000
# 78609  Reject  Reject  Reject  Reject      2.232      0.448      1.000
# 78610  Reject  Reject  Reject  Reject      2.078      0.481      1.000
# 78611  Reject  Reject  Reject  Reject      2.329      0.429      1.000
#
#        T/W Ratio  CHull Surface Area   Sieve  Angularity  Ellipticity  \
# 0          0.276            3211.655  23.529      19.392        4.372
# 1          0.257            2547.278  22.089      20.688        4.891
# 2          0.266            2571.497  19.112      21.250        6.110
# 3          0.203            2001.165  15.063      18.233       10.304
# 4          0.183            1745.237  14.217      17.086        9.769
# ...          ...                 ...     ...         ...          ...
# 78607      1.000               0.006   0.019       0.000        2.705
# 78608      1.000               0.007   0.036      85.000        5.253
# 78609      1.000               0.009   0.039       0.000        4.990
# 78610      1.000               0.008   0.040     113.333        3.906
# 78611      1.000               0.007   0.035     113.333        4.060
#
#        Fiber Length  Fiber Width  Krumbein Rnd size_micro type_micro
# 0            49.768       22.823         0.214    unknown     lithic
# 1            37.445        5.128         0.214    unknown     lithic
# 2            52.384       17.379         0.219    unknown     lithic
# 3            51.467       17.096         0.251    unknown     lithic
# 4            36.426        3.135         0.276    unknown     lithic
# ...             ...          ...           ...        ...        ...
# 78607         0.000        0.000         1.000    unknown       soil
# 78608         0.000        0.000         1.000    unknown       soil
# 78609         0.000        0.000         1.000    unknown       soil
# 78610         0.000        0.000         1.000    unknown       soil
# 78611         0.000        0.000         1.000    unknown       soil
#
# [78612 rows x 48 columns]

# %% [markdown]
# ## data processing

# %% [markdown]
# ### Other processing

# %%
# Drop the columns (filter1, filter2, ...)
to_drop = micro.filter(regex='^Filter').columns
micro = micro.drop(columns=to_drop)
micro
# Out:
#            Da      Dp  FWidth  FLength  FThickness  ELength  EThickness  \
# 0      30.893  38.251  36.878   46.822      10.179   44.168      10.102
# 1      27.727  33.375  35.149   40.001       9.029   39.022       7.978
# 2      26.726  36.061  30.199   46.332       8.025   47.365       7.753
# 3      24.408  36.198  25.039   57.353       5.086   50.536       4.904
# 4      22.869  29.388  24.044   39.820       4.390   38.568       3.948
# ...       ...     ...     ...      ...         ...      ...         ...
# 78607   0.037   0.089   0.019    0.135       0.019    0.044       0.016
# 78608   0.035   0.064   0.036    0.080       0.036    0.077       0.015
# 78609   0.035   0.073   0.039    0.087       0.039    0.092       0.018
# 78610   0.029   0.075   0.040    0.084       0.040    0.095       0.024
# 78611   0.024   0.071   0.035    0.082       0.035    0.105       0.026
#
#        EWidth    Volume     Area  Perimeter  CHull  Area  CHull Perimeter  \
# 0      34.444  9202.973  749.562    120.170      802.914          108.399
# 1      34.108  6646.859  603.785    104.849      636.820           99.590
# 2      28.230  5879.233  560.995    113.290      642.874          100.583
# 3      23.943  3824.409  467.900    113.719      500.291          108.846
# 4      22.535  2200.862  410.744     92.327      436.309           89.254
# ...       ...       ...      ...        ...          ...              ...
# 78607   0.016     0.000    0.001      0.279        0.001            0.274
# 78608   0.015     0.000    0.001      0.202        0.002            0.194
# 78609   0.018     0.000    0.001      0.228        0.002            0.211
# 78610   0.024     0.000    0.001      0.235        0.002            0.210
# 78611   0.026     0.000    0.000      0.224        0.002            0.199
#
#        Sphericity  L/T Ratio  T/L Aspect Ratio  Compactness  Roundness  \
# 0           0.808      4.600             0.217        0.660      0.435
# 1           0.831      4.430             0.226        0.693      0.480
# 2           0.741      5.774             0.173        0.577      0.333
# 3           0.674     11.276             0.089        0.426      0.181
# 4           0.778      9.070             0.110        0.574      0.330
# ...           ...        ...               ...          ...        ...
# 78607       0.416      6.914             0.145        0.274      0.075
# 78608       0.545      2.237             0.447        0.440      0.193
# 78609       0.478      2.232             0.448        0.401      0.161
# 78610       0.390      2.078             0.481        0.348      0.121
# 78611       0.338      2.329             0.429        0.296      0.087
#
#        Ellipse Ratio  Circularity  Solidity  Concavity  Convexity  Extent  \
# 0              0.229        0.652     0.934      0.066      0.902   1.573
# 1              0.204        0.690     0.948      0.052      0.950   1.672
# 2              0.164        0.549     0.873      0.127      0.888   1.509
# 3              0.097        0.455     0.935      0.065      0.957   1.604
# 4              0.102        0.606     0.941      0.059      0.967   2.350
# ...              ...          ...       ...        ...        ...     ...
# 78607          0.370        0.173     0.720      0.280      0.984   0.409
# 78608          0.190        0.297     0.577      0.423      0.960   0.340
# 78609          0.200        0.229     0.440      0.560      0.928   0.282
# 78610          0.256        0.152     0.317      0.683      0.894   0.197
# 78611          0.246        0.114     0.246      0.754      0.887   0.160
#
#        hash  Transparency  Curvature  Surface Area  L/W Ratio  W/L Ratio  \
# 0         0         0.081        0.0      2998.247      1.270      0.788
# 1         0         0.126        0.0      2415.141      1.138      0.879
# 2         0         0.096        0.0      2243.981      1.534      0.652
# 3         0         0.088        0.0      1871.602      2.291      0.437
# 4         0         0.077        0.0      1642.977      1.656      0.604
# ...     ...           ...        ...           ...        ...        ...
# 78607     0         0.660        0.0         0.004      6.914      0.145
# 78608     0         0.545        0.0         0.004      2.237      0.447
# 78609     0         0.514        0.0         0.004      2.232      0.448
# 78610     0         0.519        0.0         0.003      2.078      0.481
# 78611     0         0.564        0.0         0.002      2.329      0.429
#
#        W/T Ratio  T/W Ratio  CHull Surface Area   Sieve  Angularity  \
# 0          3.623      0.276            3211.655  23.529      19.392
# 1          3.893      0.257            2547.278  22.089      20.688
# 2          3.763      0.266            2571.497  19.112      21.250
# 3          4.923      0.203            2001.165  15.063      18.233
# 4          5.477      0.183            1745.237  14.217      17.086
# ...          ...        ...                 ...     ...         ...
# 78607      1.000      1.000               0.006   0.019       0.000
# 78608      1.000      1.000               0.007   0.036      85.000
# 78609      1.000      1.000               0.009   0.039       0.000
# 78610      1.000      1.000               0.008   0.040     113.333
# 78611      1.000      1.000               0.007   0.035     113.333
#
#        Ellipticity  Fiber Length  Fiber Width  Krumbein Rnd size_micro  \
# 0            4.372        49.768       22.823         0.214    unknown
# 1            4.891        37.445        5.128         0.214    unknown
# 2            6.110        52.384       17.379         0.219    unknown
# 3           10.304        51.467       17.096         0.251    unknown
# 4            9.769        36.426        3.135         0.276    unknown
# ...            ...           ...          ...           ...        ...
# 78607        2.705         0.000        0.000         1.000    unknown
# 78608        5.253         0.000        0.000         1.000    unknown
# 78609        4.990         0.000        0.000         1.000    unknown
# 78610        3.906         0.000        0.000         1.000    unknown
# 78611        4.060         0.000        0.000         1.000    unknown
#
#       type_micro
# 0         lithic
# 1         lithic
# 2         lithic
# 3         lithic
# 4         lithic
# ...          ...
# 78607       soil
# 78608       soil
# 78609       soil
# 78610       soil
# 78611       soil
#
# [78612 rows x 41 columns]

# %%
micro = micro.drop(columns=['hash', 'size_micro', 'Krumbein Rnd']) #'Krumbein Rnd'
micro
# Out:
#            Da      Dp  FWidth  FLength  FThickness  ELength  EThickness  \
# 0      30.893  38.251  36.878   46.822      10.179   44.168      10.102
# 1      27.727  33.375  35.149   40.001       9.029   39.022       7.978
# 2      26.726  36.061  30.199   46.332       8.025   47.365       7.753
# 3      24.408  36.198  25.039   57.353       5.086   50.536       4.904
# 4      22.869  29.388  24.044   39.820       4.390   38.568       3.948
# ...       ...     ...     ...      ...         ...      ...         ...
# 78607   0.037   0.089   0.019    0.135       0.019    0.044       0.016
# 78608   0.035   0.064   0.036    0.080       0.036    0.077       0.015
# 78609   0.035   0.073   0.039    0.087       0.039    0.092       0.018
# 78610   0.029   0.075   0.040    0.084       0.040    0.095       0.024
# 78611   0.024   0.071   0.035    0.082       0.035    0.105       0.026
#
#        EWidth    Volume     Area  Perimeter  CHull  Area  CHull Perimeter  \
# 0      34.444  9202.973  749.562    120.170      802.914          108.399
# 1      34.108  6646.859  603.785    104.849      636.820           99.590
# 2      28.230  5879.233  560.995    113.290      642.874          100.583
# 3      23.943  3824.409  467.900    113.719      500.291          108.846
# 4      22.535  2200.862  410.744     92.327      436.309           89.254
# ...       ...       ...      ...        ...          ...              ...
# 78607   0.016     0.000    0.001      0.279        0.001            0.274
# 78608   0.015     0.000    0.001      0.202        0.002            0.194
# 78609   0.018     0.000    0.001      0.228        0.002            0.211
# 78610   0.024     0.000    0.001      0.235        0.002            0.210
# 78611   0.026     0.000    0.000      0.224        0.002            0.199
#
#        Sphericity  L/T Ratio  T/L Aspect Ratio  Compactness  Roundness  \
# 0           0.808      4.600             0.217        0.660      0.435
# 1           0.831      4.430             0.226        0.693      0.480
# 2           0.741      5.774             0.173        0.577      0.333
# 3           0.674     11.276             0.089        0.426      0.181
# 4           0.778      9.070             0.110        0.574      0.330
# ...           ...        ...               ...          ...        ...
# 78607       0.416      6.914             0.145        0.274      0.075
# 78608       0.545      2.237             0.447        0.440      0.193
# 78609       0.478      2.232             0.448        0.401      0.161
# 78610       0.390      2.078             0.481        0.348      0.121
# 78611       0.338      2.329             0.429        0.296      0.087
#
#        Ellipse Ratio  Circularity  Solidity  Concavity  Convexity  Extent  \
# 0              0.229        0.652     0.934      0.066      0.902   1.573
# 1              0.204        0.690     0.948      0.052      0.950   1.672
# 2              0.164        0.549     0.873      0.127      0.888   1.509
# 3              0.097        0.455     0.935      0.065      0.957   1.604
# 4              0.102        0.606     0.941      0.059      0.967   2.350
# ...              ...          ...       ...        ...        ...     ...
# 78607          0.370        0.173     0.720      0.280      0.984   0.409
# 78608          0.190        0.297     0.577      0.423      0.960   0.340
# 78609          0.200        0.229     0.440      0.560      0.928   0.282
# 78610          0.256        0.152     0.317      0.683      0.894   0.197
# 78611          0.246        0.114     0.246      0.754      0.887   0.160
#
#        Transparency  Curvature  Surface Area  L/W Ratio  W/L Ratio  W/T Ratio  \
# 0             0.081        0.0      2998.247      1.270      0.788      3.623
# 1             0.126        0.0      2415.141      1.138      0.879      3.893
# 2             0.096        0.0      2243.981      1.534      0.652      3.763
# 3             0.088        0.0      1871.602      2.291      0.437      4.923
# 4             0.077        0.0      1642.977      1.656      0.604      5.477
# ...             ...        ...           ...        ...        ...        ...
# 78607         0.660        0.0         0.004      6.914      0.145      1.000
# 78608         0.545        0.0         0.004      2.237      0.447      1.000
# 78609         0.514        0.0         0.004      2.232      0.448      1.000
# 78610         0.519        0.0         0.003      2.078      0.481      1.000
# 78611         0.564        0.0         0.002      2.329      0.429      1.000
#
#        T/W Ratio  CHull Surface Area   Sieve  Angularity  Ellipticity  \
# 0          0.276            3211.655  23.529      19.392        4.372
# 1          0.257            2547.278  22.089      20.688        4.891
# 2          0.266            2571.497  19.112      21.250        6.110
# 3          0.203            2001.165  15.063      18.233       10.304
# 4          0.183            1745.237  14.217      17.086        9.769
# ...          ...                 ...     ...         ...          ...
# 78607      1.000               0.006   0.019       0.000        2.705
# 78608      1.000               0.007   0.036      85.000        5.253
# 78609      1.000               0.009   0.039       0.000        4.990
# 78610      1.000               0.008   0.040     113.333        3.906
# 78611      1.000               0.007   0.035     113.333        4.060
#
#        Fiber Length  Fiber Width type_micro
# 0            49.768       22.823     lithic
# 1            37.445        5.128     lithic
# 2            52.384       17.379     lithic
# 3            51.467       17.096     lithic
# 4            36.426        3.135     lithic
# ...             ...          ...        ...
# 78607         0.000        0.000       soil
# 78608         0.000        0.000       soil
# 78609         0.000        0.000       soil
# 78610         0.000        0.000       soil
# 78611         0.000        0.000       soil
#
# [78612 rows x 38 columns]

# %% [markdown]
# ### Redersampling

# %% [markdown]
# https://machinelearningmastery.com/undersampling-algorithms-for-imbalanced-classification/
# https://www.analyticsvidhya.com/blog/2020/07/10-techniques-to-deal-with-class-imbalance-in-machine-learning/
# https://towardsdatascience.com/imbalanced-classification-in-python-smote-tomek-links-method-6e48dfe69bbc

# %%
# !pip install imblearn

# %%
# from imblearn.combine import SMOTETomek
from imblearn.under_sampling import TomekLinks
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTETomek
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import CondensedNearestNeighbour

# %%
micro.groupby('type_micro').describe()
# Out:
#                  Da                                                          \
#               count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic       5299.0  0.408032  1.629126  0.040  0.161  0.193  0.251  30.893
# soil        73313.0  0.231986  0.376004  0.024  0.152  0.174  0.236  13.303
#
#                  Dp                                                          \
#               count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic       5299.0  0.533303  2.193727  0.058  0.198  0.250  0.330  38.251
# soil        73313.0  0.284808  0.467939  0.058  0.166  0.197  0.283  16.888
#
#              FWidth                                                          \
#               count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic       5299.0  0.351058  1.685466  0.021  0.107  0.138  0.194  36.878
# soil        73313.0  0.183764  0.372174  0.019  0.112  0.137  0.179  12.966
#
#             FLength                                                          \
#               count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic       5299.0  0.731248  3.023436  0.074  0.254  0.339  0.458  57.353
# soil        73313.0  0.361650  0.575190  0.074  0.187  0.243  0.367  17.865
#
#            FThickness                                                          \
#                 count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic         5299.0  0.220404  0.661258  0.021  0.102  0.130  0.170  16.445
# soil          73313.0  0.170072  0.292985  0.019  0.112  0.135  0.173  11.317
#
#             ELength                                                           \
#               count      mean       std    min    25%    50%     75%     max
# type_micro
# lithic       5299.0  0.700690  2.950370  0.041  0.238  0.315  0.4315  50.536
# soil        73313.0  0.360535  0.581504  0.041  0.175  0.232  0.3650  16.400
#
#            EThickness                                                          \
#                 count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic         5299.0  0.208487  0.623842  0.015  0.096  0.122  0.163  16.227
# soil          73313.0  0.164455  0.283009  0.014  0.106  0.129  0.167  11.309
#
#              EWidth                                                          \
#               count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic       5299.0  0.336963  1.629089  0.015  0.100  0.130  0.186  34.444
# soil        73313.0  0.177981  0.360868  0.014  0.107  0.131  0.173  13.021
#
#              Volume                                                   \
#               count       mean         std  min    25%    50%    75%
# type_micro
# lithic       5299.0  16.602042  236.156080  0.0  0.002  0.003  0.007
# soil        73313.0   0.429839   11.821718  0.0  0.001  0.002  0.006
#
#                          Area                                            \
#                  max    count      mean        std    min    25%    50%
# type_micro
# lithic      9202.973   5299.0  2.214862  25.126003  0.001  0.020  0.029
# soil        1282.697  73313.0  0.153318   1.757901  0.000  0.018  0.024
#
#                            Perimeter                                           \
#               75%      max     count      mean       std    min    25%    50%
# type_micro
# lithic      0.049  749.562    5299.0  1.675445  6.891800  0.183  0.623  0.785
# soil        0.044  138.982   73313.0  0.894744  1.470069  0.183  0.520  0.620
#
#                            CHull  Area                                     \
#               75%      max       count      mean        std    min    25%
# type_micro
# lithic      1.036  120.170      5299.0  2.402839  27.222648  0.001  0.021
# soil        0.890   53.054     73313.0  0.168385   1.917235  0.001  0.018
#
#                                   CHull Perimeter                             \
#               50%    75%      max           count      mean       std    min
# type_micro
# lithic      0.031  0.052  802.914          5299.0  1.632610  6.573565  0.183
# soil        0.024  0.046  149.950         73313.0  0.878655  1.370493  0.183
#
#                                          Sphericity                      \
#               25%    50%    75%      max      count      mean       std
# type_micro
# lithic      0.622  0.779  1.026  108.846     5299.0  0.790303  0.117014
# soil        0.520  0.618  0.885   45.259    73313.0  0.846456  0.104359
#
#                                               L/T Ratio                      \
#               min    25%    50%    75%    max     count      mean       std
# type_micro
# lithic      0.226  0.726  0.813  0.881  0.981    5299.0  2.962653  1.638428
# soil        0.211  0.798  0.878  0.922  0.991   73313.0  2.220883  1.064239
#
#                                                T/L Aspect Ratio            \
#               min    25%    50%    75%     max            count      mean
# type_micro
# lithic      1.084  1.908  2.535  3.524  19.069           5299.0  0.413635
# soil        1.041  1.555  1.903  2.512  16.258          73313.0  0.522858
#
#                                                         Compactness            \
#                  std    min    25%    50%    75%    max       count      mean
# type_micro
# lithic      0.168698  0.052  0.284  0.394  0.524  0.922      5299.0  0.599855
# soil        0.174829  0.062  0.398  0.526  0.643  0.961     73313.0  0.686378
#
#                                                          Roundness            \
#                  std    min    25%    50%     75%    max     count      mean
# type_micro
# lithic      0.130086  0.194  0.507  0.601  0.6945  0.941    5299.0  0.376740
# soil        0.126418  0.141  0.605  0.702  0.7730  0.969   73313.0  0.487069
#
#                                                         Ellipse Ratio  \
#                  std    min    25%    50%    75%    max         count
# type_micro
# lithic      0.156491  0.037  0.257  0.361  0.482  0.885        5299.0
# soil        0.167032  0.020  0.366  0.493  0.597  0.938       73313.0
#
#                                                                  Circularity  \
#                 mean       std    min    25%    50%     75%  max       count
# type_micro
# lithic      0.420723  0.182279  0.043  0.280  0.402  0.5485  1.0      5299.0
# soil        0.533611  0.200962  0.046  0.384  0.557  0.6670  1.0     73313.0
#
#                                                                   Solidity  \
#                 mean       std    min    25%    50%    75%    max    count
# type_micro
# lithic      0.638278  0.172553  0.051  0.527  0.660  0.776  0.962   5299.0
# soil        0.727352  0.161785  0.044  0.637  0.771  0.849  0.982  73313.0
#
#                                                                 Concavity  \
#                 mean       std    min    25%    50%    75%  max     count
# type_micro
# lithic      0.943644  0.080178  0.111  0.936  0.971  0.988  1.0    5299.0
# soil        0.958334  0.074017  0.167  0.959  0.983  0.996  1.0   73313.0
#
#                                                                 Convexity  \
#                 mean       std  min    25%    50%    75%    max     count
# type_micro
# lithic      0.056356  0.080179  0.0  0.012  0.029  0.064  0.889    5299.0
# soil        0.041666  0.074017  0.0  0.004  0.017  0.041  0.833   73313.0
#
#                                                                   Extent  \
#                 mean       std    min    25%    50%    75%  max    count
# type_micro
# lithic      0.991046  0.018609  0.530  0.991  0.997  0.999  1.0   5299.0
# soil        0.994073  0.015326  0.535  0.996  0.998  1.000  1.0  73313.0
#
#                                                                    \
#                 mean       std    min    25%    50%    75%    max
# type_micro
# lithic      0.730798  0.187890  0.071  0.653  0.711  0.764  3.002
# soil        0.734823  0.099227  0.118  0.697  0.743  0.784  2.240
#
#            Transparency                                                       \
#                   count      mean       std  min    25%    50%    75%    max
# type_micro
# lithic           5299.0  0.456355  0.162607  0.0  0.424  0.512  0.551  0.832
# soil            73313.0  0.258064  0.172110  0.0  0.000  0.318  0.374  0.894
#
#            Curvature                                                 \
#                count      mean       std  min  25%  50%  75%    max
# type_micro
# lithic        5299.0  0.075975  0.320574  0.0  0.0  0.0  0.0  6.108
# soil         73313.0  0.069942  0.368632  0.0  0.0  0.0  0.0  6.214
#
#            Surface Area                                                    \
#                   count      mean         std    min    25%    50%    75%
# type_micro
# lithic           5299.0  8.859449  100.504014  0.005  0.082  0.117  0.198
# soil            73313.0  0.613250    7.031607  0.002  0.073  0.095  0.175
#
#                      L/W Ratio                                           \
#                  max     count      mean       std    min    25%    50%
# type_micro
# lithic      2998.247    5299.0  2.614261  1.261189  1.084  1.756  2.269
# soil         555.926   73313.0  2.168756  1.053205  1.041  1.500  1.839
#
#                           W/L Ratio                                           \
#               75%     max     count      mean       std    min    25%    50%
# type_micro
# lithic      3.102  18.300    5299.0  0.451302  0.166853  0.055  0.322  0.441
# soil        2.441  16.258   73313.0  0.537299  0.179893  0.062  0.410  0.544
#
#                          W/T Ratio                                          \
#               75%    max     count      mean       std  min  25%  50%  75%
# type_micro
# lithic      0.569  0.922    5299.0  1.175189  0.565394  1.0  1.0  1.0  1.0
# soil        0.667  0.961   73313.0  1.032428  0.135499  1.0  1.0  1.0  1.0
#
#                   T/W Ratio                                                 \
#               max     count      mean       std    min  25%  50%  75%  max
# type_micro
# lithic      6.841    5299.0  0.930623  0.179607  0.146  1.0  1.0  1.0  1.0
# soil        5.830   73313.0  0.978484  0.078574  0.172  1.0  1.0  1.0  1.0
#
#            CHull Surface Area                                             \
#                         count      mean         std    min    25%    50%
# type_micro
# lithic                 5299.0  9.611345  108.890588  0.006  0.086  0.125
# soil                  73313.0  0.673543    7.668940  0.006  0.073  0.098
#
#                                Sieve                                           \
#               75%       max    count      mean       std    min    25%    50%
# type_micro
# lithic      0.210  3211.655   5299.0  0.285732  1.145785  0.021  0.107  0.137
# soil        0.185   599.801  73313.0  0.176918  0.331536  0.019  0.112  0.136
#
#                            Angularity                                     \
#                75%     max      count       mean        std  min     25%
# type_micro
# lithic      0.1835  23.529     5299.0  69.491435  27.561298  0.0  63.333
# soil        0.1760  12.042    73313.0  53.778604  35.364862  0.0   0.000
#
#                               Ellipticity                                  \
#              50%   75%    max       count      mean       std  min    25%
# type_micro
# lithic      70.0  85.0  120.0      5299.0  3.009928  1.868712  1.0  1.824
# soil        68.0  85.0  132.5     73313.0  2.296649  1.350226  1.0  1.500
#
#                                   Fiber Length                                \
#               50%     75%     max        count      mean       std  min  25%
# type_micro
# lithic      2.489  3.5765  23.322       5299.0  0.648506  3.047920  0.0  0.0
# soil        1.794  2.6050  21.898      73313.0  0.273778  0.764155  0.0  0.0
#
#                                  Fiber Width                                \
#               50%    75%     max       count      mean       std  min  25%
# type_micro
# lithic      0.272  0.396  52.384      5299.0  0.193938  0.937805  0.0  0.0
# soil        0.092  0.298  29.682     73313.0  0.101909  0.326652  0.0  0.0
#
#
#               50%    75%     max
# type_micro
# lithic      0.084  0.126  22.823
# soil        0.016  0.123   8.959

# %%
# define the undersampling method
# undersample = SMOTE(sampling_strategy='minority')
# undersample = TomekLinks(sampling_strategy='majority')
undersample = RandomUnderSampler(random_state=42, replacement=True)
# undersample = CondensedNearestNeighbour(n_neighbors=1)

# Separate majority and minority classes
class_column = ['type_micro']
X = micro.drop(columns=class_column)
y = micro[class_column]

X_resampled, y_resampled = undersample.fit_resample(X, y)

# %%
data_resampled = pd.concat([X_resampled, y_resampled], axis=1)

# %%
data_resampled.columns = X.columns.tolist() + ['type_micro']

# %%
data_resampled
# Out:
#            Da      Dp  FWidth  FLength  FThickness  ELength  EThickness  \
# 0      30.893  38.251  36.878   46.822      10.179   44.168      10.102
# 1      27.727  33.375  35.149   40.001       9.029   39.022       7.978
# 2      26.726  36.061  30.199   46.332       8.025   47.365       7.753
# 3      24.408  36.198  25.039   57.353       5.086   50.536       4.904
# 4      22.869  29.388  24.044   39.820       4.390   38.568       3.948
# ...       ...     ...     ...      ...         ...      ...         ...
# 10593   0.163   0.170   0.159    0.174       0.159    0.163       0.163
# 10594   0.299   0.316   0.257    0.349       0.257    0.345       0.261
# 10595   0.300   0.478   0.160    0.685       0.160    0.751       0.142
# 10596   0.180   0.188   0.152    0.225       0.152    0.213       0.148
# 10597   0.194   0.201   0.165    0.229       0.165    0.225       0.164
#
#        EWidth    Volume     Area  Perimeter  CHull  Area  CHull Perimeter  \
# 0      34.444  9202.973  749.562    120.170      802.914          108.399
# 1      34.108  6646.859  603.785    104.849      636.820           99.590
# 2      28.230  5879.233  560.995    113.290      642.874          100.583
# 3      23.943  3824.409  467.900    113.719      500.291          108.846
# 4      22.535  2200.862  410.744     92.327      436.309           89.254
# ...       ...       ...      ...        ...          ...              ...
# 10593   0.163     0.002    0.021      0.533        0.021            0.532
# 10594   0.261     0.012    0.070      0.994        0.072            0.987
# 10595   0.142     0.009    0.071      1.503        0.088            1.486
# 10596   0.148     0.003    0.026      0.591        0.026            0.591
# 10597   0.164     0.003    0.030      0.631        0.030            0.631
#
#        Sphericity  L/T Ratio  T/L Aspect Ratio  Compactness  Roundness  \
# 0           0.808      4.600             0.217        0.660      0.435
# 1           0.831      4.430             0.226        0.693      0.480
# 2           0.741      5.774             0.173        0.577      0.333
# 3           0.674     11.276             0.089        0.426      0.181
# 4           0.778      9.070             0.110        0.574      0.330
# ...           ...        ...               ...          ...        ...
# 10593       0.962      1.094             0.914        0.940      0.883
# 10594       0.946      1.361             0.735        0.856      0.733
# 10595       0.627      4.273             0.234        0.438      0.192
# 10596       0.959      1.486             0.673        0.800      0.641
# 10597       0.966      1.387             0.721        0.848      0.718
#
#        Ellipse Ratio  Circularity  Solidity  Concavity  Convexity  Extent  \
# 0              0.229        0.652     0.934      0.066      0.902   1.573
# 1              0.204        0.690     0.948      0.052      0.950   1.672
# 2              0.164        0.549     0.873      0.127      0.888   1.509
# 3              0.097        0.455     0.935      0.065      0.957   1.604
# 4              0.102        0.606     0.941      0.059      0.967   2.350
# ...              ...          ...       ...        ...        ...     ...
# 10593          1.000        0.925     0.981      0.019      0.998   0.759
# 10594          0.756        0.895     0.981      0.019      0.993   0.784
# 10595          0.189        0.393     0.805      0.195      0.989   0.644
# 10596          0.696        0.920     1.000      0.000      1.000   0.748
# 10597          0.726        0.932     1.000      0.000      1.000   0.783
#
#        Transparency  Curvature  Surface Area  L/W Ratio  W/L Ratio  W/T Ratio  \
# 0             0.081        0.0      2998.247      1.270      0.788      3.623
# 1             0.126        0.0      2415.141      1.138      0.879      3.893
# 2             0.096        0.0      2243.981      1.534      0.652      3.763
# 3             0.088        0.0      1871.602      2.291      0.437      4.923
# 4             0.077        0.0      1642.977      1.656      0.604      5.477
# ...             ...        ...           ...        ...        ...        ...
# 10593         0.000        0.0         0.084      1.094      0.914      1.000
# 10594         0.254        0.0         0.281      1.361      0.735      1.000
# 10595         0.537        0.0         0.283      4.273      0.234      1.000
# 10596         0.515        0.0         0.102      1.486      0.673      1.000
# 10597         0.416        0.0         0.118      1.387      0.721      1.000
#
#        T/W Ratio  CHull Surface Area   Sieve  Angularity  Ellipticity  \
# 0          0.276            3211.655  23.529      19.392        4.372
# 1          0.257            2547.278  22.089      20.688        4.891
# 2          0.266            2571.497  19.112      21.250        6.110
# 3          0.203            2001.165  15.063      18.233       10.304
# 4          0.183            1745.237  14.217      17.086        9.769
# ...          ...                 ...     ...         ...          ...
# 10593      1.000               0.085   0.159       0.000        1.000
# 10594      1.000               0.287   0.257      60.000        1.324
# 10595      1.000               0.351   0.160      55.714        5.285
# 10596      1.000               0.102   0.152      68.000        1.437
# 10597      1.000               0.118   0.165      70.000        1.378
#
#        Fiber Length  Fiber Width type_micro
# 0            49.768       22.823     lithic
# 1            37.445        5.128     lithic
# 2            52.384       17.379     lithic
# 3            51.467       17.096     lithic
# 4            36.426        3.135     lithic
# ...             ...          ...        ...
# 10593         0.000        0.000       soil
# 10594         0.000        0.000       soil
# 10595         0.631        0.112       soil
# 10596         0.000        0.000       soil
# 10597         0.000        0.000       soil
#
# [10598 rows x 38 columns]

# %%
data_resampled.groupby('type_micro').describe()
# Out:
#                 Da                                                         \
#              count      mean       std   min    25%    50%    75%     max
# type_micro
# lithic      5299.0  0.408032  1.629126  0.04  0.161  0.193  0.251  30.893
# soil        5299.0  0.236270  0.353787  0.04  0.152  0.177  0.238   5.519
#
#                 Dp                                                         \
#              count      mean       std    min    25%   50%    75%     max
# type_micro
# lithic      5299.0  0.533303  2.193727  0.058  0.198  0.25  0.330  38.251
# soil        5299.0  0.290335  0.446631  0.058  0.167  0.20  0.287   8.347
#
#             FWidth                                                          \
#              count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic      5299.0  0.351058  1.685466  0.021  0.107  0.138  0.194  36.878
# soil        5299.0  0.187055  0.347608  0.021  0.112  0.140  0.183   5.498
#
#            FLength                                                          \
#              count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic      5299.0  0.731248  3.023436  0.074  0.254  0.339  0.458  57.353
# soil        5299.0  0.368267  0.554412  0.074  0.190  0.248  0.373  11.912
#
#            FThickness                                                          \
#                 count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic         5299.0  0.220404  0.661258  0.021  0.102  0.130  0.170  16.445
# soil           5299.0  0.173376  0.272318  0.021  0.112  0.137  0.175   4.324
#
#            ELength                                                           \
#              count      mean       std    min    25%    50%     75%     max
# type_micro
# lithic      5299.0  0.700690  2.950370  0.041  0.238  0.315  0.4315  50.536
# soil        5299.0  0.368152  0.571056  0.041  0.178  0.237  0.3720  12.888
#
#            EThickness                                                          \
#                 count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic         5299.0  0.208487  0.623842  0.015  0.096  0.122  0.163  16.227
# soil           5299.0  0.167176  0.260722  0.021  0.109  0.132  0.169   4.124
#
#             EWidth                                                          \
#              count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic      5299.0  0.336963  1.629089  0.015  0.100  0.130  0.186  34.444
# soil        5299.0  0.180685  0.336578  0.021  0.109  0.134  0.176   5.695
#
#             Volume                                                             \
#              count       mean         std  min    25%    50%    75%       max
# type_micro
# lithic      5299.0  16.602042  236.156080  0.0  0.002  0.003  0.007  9202.973
# soil        5299.0   0.276170    3.326194  0.0  0.001  0.002  0.006    89.819
#
#               Area                                                            \
#              count      mean        std    min    25%    50%    75%      max
# type_micro
# lithic      5299.0  2.214862  25.126003  0.001  0.020  0.029  0.049  749.562
# soil        5299.0  0.142138   1.081805  0.001  0.018  0.025  0.045   23.925
#
#            Perimeter                                                           \
#                count      mean       std    min    25%    50%    75%      max
# type_micro
# lithic        5299.0  1.675445  6.891800  0.183  0.623  0.785  1.036  120.170
# soil          5299.0  0.912113  1.403125  0.183  0.525  0.630  0.902   26.223
#
#            CHull  Area                                                   \
#                  count      mean        std    min    25%    50%    75%
# type_micro
# lithic          5299.0  2.402839  27.222648  0.001  0.021  0.031  0.052
# soil            5299.0  0.157523   1.200074  0.001  0.018  0.025  0.047
#
#                     CHull Perimeter                                           \
#                 max           count      mean       std    min    25%    50%
# type_micro
# lithic      802.914          5299.0  1.632610  6.573565  0.183  0.622  0.779
# soil         27.259          5299.0  0.895674  1.314751  0.183  0.524  0.629
#
#                            Sphericity                                    \
#               75%      max      count      mean       std    min    25%
# type_micro
# lithic      1.026  108.846     5299.0  0.790303  0.117014  0.226  0.726
# soil        0.897   23.555     5299.0  0.846856  0.104743  0.280  0.798
#
#                                 L/T Ratio                                    \
#               50%    75%    max     count      mean       std    min    25%
# type_micro
# lithic      0.813  0.881  0.981    5299.0  2.962653  1.638428  1.084  1.908
# soil        0.878  0.923  0.986    5299.0  2.213585  1.040888  1.081  1.547
#
#                                  T/L Aspect Ratio                             \
#               50%    75%     max            count      mean       std    min
# type_micro
# lithic      2.535  3.524  19.069           5299.0  0.413635  0.168698  0.052
# soil        1.897  2.522  13.038           5299.0  0.524185  0.176084  0.077
#
#                                         Compactness                      \
#                25%    50%    75%    max       count      mean       std
# type_micro
# lithic      0.2840  0.394  0.524  0.922      5299.0  0.599855  0.130086
# soil        0.3965  0.527  0.647  0.925      5299.0  0.686783  0.127457
#
#                                                 Roundness                      \
#               min     25%    50%     75%    max     count      mean       std
# type_micro
# lithic      0.194  0.5070  0.601  0.6945  0.941    5299.0  0.376740  0.156491
# soil        0.202  0.6055  0.701  0.7750  0.949    5299.0  0.487889  0.168935
#
#                                               Ellipse Ratio            \
#               min    25%    50%    75%    max         count      mean
# type_micro
# lithic      0.037  0.257  0.361  0.482  0.885        5299.0  0.420723
# soil        0.041  0.367  0.492  0.600  0.900        5299.0  0.533460
#
#                                                         Circularity            \
#                  std    min     25%    50%     75%  max       count      mean
# type_micro
# lithic      0.182279  0.043  0.2800  0.402  0.5485  1.0      5299.0  0.638278
# soil        0.201748  0.065  0.3815  0.557  0.6740  1.0      5299.0  0.728098
#
#                                                         Solidity            \
#                  std    min    25%    50%    75%    max    count      mean
# type_micro
# lithic      0.172553  0.051  0.527  0.660  0.776  0.962   5299.0  0.943644
# soil        0.162752  0.078  0.637  0.771  0.851  0.973   5299.0  0.957236
#
#                                                       Concavity            \
#                  std    min    25%    50%    75%  max     count      mean
# type_micro
# lithic      0.080178  0.111  0.936  0.971  0.988  1.0    5299.0  0.056356
# soil        0.074579  0.294  0.957  0.983  0.996  1.0    5299.0  0.042764
#
#                                                       Convexity            \
#                  std  min    25%    50%    75%    max     count      mean
# type_micro
# lithic      0.080179  0.0  0.012  0.029  0.064  0.889    5299.0  0.991046
# soil        0.074579  0.0  0.004  0.017  0.043  0.706    5299.0  0.993925
#
#                                                        Extent            \
#                  std    min    25%    50%    75%  max   count      mean
# type_micro
# lithic      0.018609  0.530  0.991  0.997  0.999  1.0  5299.0  0.730798
# soil        0.015042  0.735  0.996  0.998  1.000  1.0  5299.0  0.733590
#
#                                                         Transparency  \
#                  std    min    25%    50%    75%    max        count
# type_micro
# lithic      0.187890  0.071  0.653  0.711  0.764  3.002       5299.0
# soil        0.097568  0.175  0.694  0.742  0.783  1.343       5299.0
#
#                                                                 Curvature  \
#                 mean       std  min    25%    50%    75%    max     count
# type_micro
# lithic      0.456355  0.162607  0.0  0.424  0.512  0.551  0.832    5299.0
# soil        0.262279  0.169050  0.0  0.000  0.320  0.372  0.860    5299.0
#
#                                                           Surface Area  \
#                 mean       std  min  25%  50%  75%    max        count
# type_micro
# lithic      0.075975  0.320574  0.0  0.0  0.0  0.0  6.108       5299.0
# soil        0.071126  0.373312  0.0  0.0  0.0  0.0  5.063       5299.0
#
#                                                                         \
#                 mean         std    min    25%    50%    75%       max
# type_micro
# lithic      8.859449  100.504014  0.005  0.082  0.117  0.198  2998.247
# soil        0.568549    4.327217  0.005  0.073  0.099  0.178    95.698
#
#            L/W Ratio                                                          \
#                count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic        5299.0  2.614261  1.261189  1.084  1.756  2.269  3.102  18.300
# soil          5299.0  2.161223  1.040313  1.081  1.489  1.825  2.446  13.038
#
#            W/L Ratio                                                         \
#                count      mean       std    min    25%    50%    75%    max
# type_micro
# lithic        5299.0  0.451302  0.166853  0.055  0.322  0.441  0.569  0.922
# soil          5299.0  0.539056  0.180986  0.077  0.409  0.548  0.672  0.925
#
#            W/T Ratio                                                T/W Ratio  \
#                count      mean       std  min  25%  50%  75%    max     count
# type_micro
# lithic        5299.0  1.175189  0.565394  1.0  1.0  1.0  1.0  6.841    5299.0
# soil          5299.0  1.033104  0.131263  1.0  1.0  1.0  1.0  2.787    5299.0
#
#                                                           CHull Surface Area  \
#                 mean       std    min  25%  50%  75%  max              count
# type_micro
# lithic      0.930623  0.179607  0.146  1.0  1.0  1.0  1.0             5299.0
# soil        0.977785  0.079301  0.359  1.0  1.0  1.0  1.0             5299.0
#
#                                                                         \
#                 mean         std    min    25%    50%    75%       max
# type_micro
# lithic      9.611345  108.890588  0.006  0.086  0.125  0.210  3211.655
# soil        0.630098    4.800284  0.006  0.074  0.102  0.188   109.036
#
#              Sieve                                                           \
#              count      mean       std    min    25%    50%     75%     max
# type_micro
# lithic      5299.0  0.285732  1.145785  0.021  0.107  0.137  0.1835  23.529
# soil        5299.0  0.180215  0.308921  0.021  0.112  0.139  0.1790   4.629
#
#            Angularity                                                        \
#                 count       mean        std  min     25%   50%   75%    max
# type_micro
# lithic         5299.0  69.491435  27.561298  0.0  63.333  70.0  85.0  120.0
# soil           5299.0  54.915548  34.913647  0.0   0.000  68.0  85.0  120.0
#
#            Ellipticity                                                         \
#                  count      mean       std  min    25%    50%     75%     max
# type_micro
# lithic          5299.0  3.009928  1.868712  1.0  1.824  2.489  3.5765  23.322
# soil            5299.0  2.293220  1.310686  1.0  1.483  1.794  2.6210  15.400
#
#            Fiber Length                                                      \
#                   count      mean       std  min  25%    50%    75%     max
# type_micro
# lithic           5299.0  0.648506  3.047920  0.0  0.0  0.272  0.396  52.384
# soil             5299.0  0.276681  0.690494  0.0  0.0  0.114  0.301  14.196
#
#            Fiber Width
#                  count      mean       std  min  25%    50%    75%     max
# type_micro
# lithic          5299.0  0.193938  0.937805  0.0  0.0  0.084  0.126  22.823
# soil            5299.0  0.103143  0.292917  0.0  0.0  0.029  0.126   3.878

# %%
# # Separate majority and minority classes
# df_majority = micro1[micro1.type_micro=='soil']
# df_minority = micro1[micro1.type_micro=='lithic']

# # Downsample majority class
# df_majority_downsampled = resample(df_majority, 
#                                  replace=False,    # sample without replacement
#                                  n_samples=5299,     # to match minority class
#                                  random_state=123) # reproducible results
 
# # Combine minority class with downsampled majority class
# df_downsampled = pd.concat([df_majority_downsampled, df_minority])

# %% [markdown]
# ### Selected features

# %%
# micro1_selected = micro1[["Transparency","FLength","FWidth","FThickness","W/L Ratio", "L/W Ratio", 'Sphericity', 'Circularity', 'Convexity',"type_micro"]]

# %% [markdown]
# ### Hold-out data

# %%
# from sklearn.model_selection import train_test_split
# import numpy as np

# # X is your feature data
# # y is your target data
# X_train, X_holdout, y_train, y_holdout = train_test_split(X, y, test_size=0.1, stratify=y, random_state=42)

# # Now you can perform the train-test split on X_train and y_train
# X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.1, stratify=y_train, random_state=42)

# %% [markdown]
# ## Models

# %% [markdown]
# ### Lazy predict

# %%
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# %%
class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|███████████████████████████████████████████| 29/29 [00:31<00:00,  1.08s/it]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.89               0.89    None      0.89
# RandomForestClassifier             0.88               0.88    None      0.88
# BaggingClassifier                  0.88               0.88    None      0.88
# ExtraTreesClassifier               0.87               0.87    None      0.87
# SVC                                0.87               0.87    None      0.87
# NuSVC                              0.86               0.86    None      0.86
# KNeighborsClassifier               0.86               0.86    None      0.86
# LabelSpreading                     0.85               0.85    None      0.85
# LabelPropagation                   0.85               0.85    None      0.85
# AdaBoostClassifier                 0.85               0.85    None      0.85
# LinearSVC                          0.85               0.85    None      0.85
# RidgeClassifier                    0.85               0.85    None      0.85
# RidgeClassifierCV                  0.85               0.85    None      0.85
# CalibratedClassifierCV             0.84               0.84    None      0.84
# LinearDiscriminantAnalysis         0.84               0.84    None      0.84
# DecisionTreeClassifier             0.84               0.84    None      0.84
# LogisticRegression                 0.84               0.84    None      0.84
# SGDClassifier                      0.83               0.83    None      0.83
# Perceptron                         0.83               0.83    None      0.83
# ExtraTreeClassifier                0.82               0.82    None      0.82
# PassiveAggressiveClassifier        0.80               0.80    None      0.80
# NearestCentroid                    0.67               0.67    None      0.67
# BernoulliNB                        0.66               0.66    None      0.66
# QuadraticDiscriminantAnalysis      0.55               0.55    None      0.47
# GaussianNB                         0.53               0.53    None      0.41
# DummyClassifier                    0.50               0.50    None      0.33
#
#                                Time Taken
# Model
# LGBMClassifier                       0.97
# RandomForestClassifier               2.30
# BaggingClassifier                    1.16
# ExtraTreesClassifier                 0.97
# SVC                                  3.70
# NuSVC                                6.20
# KNeighborsClassifier                 0.49
# LabelSpreading                       3.77
# LabelPropagation                     2.22
# AdaBoostClassifier                   1.30
# LinearSVC                            1.41
# RidgeClassifier                      0.08
# RidgeClassifierCV                    0.11
# CalibratedClassifierCV               5.25
# LinearDiscriminantAnalysis           0.12
# DecisionTreeClassifier               0.25
# LogisticRegression                   0.18
# SGDClassifier                        0.15
# Perceptron                           0.08
# ExtraTreeClassifier                  0.05
# PassiveAggressiveClassifier          0.07
# NearestCentroid                      0.07
# BernoulliNB                          0.08
# QuadraticDiscriminantAnalysis        0.09
# GaussianNB                           0.05
# DummyClassifier                      0.04

# %% [markdown]
# ### LightBGM

# %% [markdown]
# #### train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

lgbm = LGBMClassifier(random_state=random_seed)
lgbm.fit(X_train_transformed, y_train_transformed)
print('Accuracy of LGBM classifier on training set: {:.4f}'.format(lgbm.score(X_train_transformed, y_train_transformed)))
print('Accuracy of LGBM classifier on test set: {:.4f}'.format(lgbm.score(X_test_transformed, y_test_transformed)))

pred = lgbm.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, lgbm.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=lgbm.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of LGBM classifier on training set: 0.9483
# Accuracy of LGBM classifier on test set: 0.8868
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88      1060
#            1       0.86      0.93      0.89      1060
#
#     accuracy                           0.89      2120
#    macro avg       0.89      0.89      0.89      2120
# weighted avg       0.89      0.89      0.89      2120

# %%
acc_train1_LBGM = lgbm.score(X_train_transformed, y_train_transformed)
acc_test1_LBGM = lgbm.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Cross validation for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'num_leaves': [31, 63, 127],
              'learning_rate': [0.1, 0.01, 0.001],
              'n_estimators': [100, 500, 1000]
             }

# %%
grid_search = GridSearchCV(lgbm, param_grid, cv=5)
grid_search.fit(X_train_transformed, y_train_transformed)
# Out:
# GridSearchCV(cv=5, estimator=LGBMClassifier(random_state=42),
#              param_grid={'learning_rate': [0.1, 0.01, 0.001],
#                          'n_estimators': [100, 500, 1000],
#                          'num_leaves': [31, 63, 127]})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'learning_rate': 0.1, 'n_estimators': 100, 'num_leaves': 31}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0            1.11          0.07             0.01            0.00
# 15           2.39          0.03             0.04            0.00
# 16           4.09          0.20             0.06            0.01
#
#    param_learning_rate param_n_estimators param_num_leaves  \
# 0                  0.1                100               31
# 15                0.01               1000               31
# 16                0.01               1000               63
#
#                                                params  split0_test_score  \
# 0   {'learning_rate': 0.1, 'n_estimators': 100, 'n...               0.88
# 15  {'learning_rate': 0.01, 'n_estimators': 1000, ...               0.89
# 16  {'learning_rate': 0.01, 'n_estimators': 1000, ...               0.88
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                0.89               0.88               0.90
# 15               0.89               0.89               0.89
# 16               0.89               0.89               0.89
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                0.89             0.89            0.01                1
# 15               0.89             0.89            0.00                2
# 16               0.89             0.89            0.00                3

# %%
# grid_search.predict(x_test)

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of LBGM classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of LBGM classifier on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of LBGM classifier on training set: 0.9483
# Accuracy of LBGM classifier on test set: 0.8868
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88      1060
#            1       0.86      0.93      0.89      1060
#
#     accuracy                           0.89      2120
#    macro avg       0.89      0.89      0.89      2120
# weighted avg       0.89      0.89      0.89      2120

# %%
acc_train2_LBGM = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_LBGM = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
importances = lgbm.feature_importances_

# Sort the feature importances in descending order
indices = np.argsort(importances)[::-1]
feature_names = data_resampled.columns[1:]
names = [feature_names[i] for i in indices]

importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# Sort the dataframe by importance
importance_df.sort_values(by='importance', ascending=False, inplace=True)

# Print the top 10 features
print(importance_df.head(10))

fi_LGBM = importance_df
# Out:
#     feature_name  importance
# 24     Curvature         441
# 23  Transparency         197
# 20     Concavity         174
# 35   Fiber Width         171
# 36    type_micro         164
# 33   Ellipticity         146
# 21     Convexity         137
# 13     L/T Ratio         129
# 3     FThickness         121
# 5     EThickness         100

# %%
# Create plot
plt.figure()

# Create plot title
plt.title("Feature Importance")

# Add bars
plt.bar(range(X_train.shape[1]), importances[indices])

# Add feature names as x-axis labels
plt.xticks(range(X_train.shape[1]), names, rotation=90)

# Show plot
plt.show()

# %% [markdown]
# ### AdaBoost (Adaptive Boosting)

# %% [markdown]
# #### Train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

ada = AdaBoostClassifier(random_state=random_seed)
ada.fit(X_train_transformed, y_train_transformed)
print('Accuracy of LGBM classifier on training set: {:.4f}'.format(ada.score(X_train_transformed, y_train_transformed)))
print('Accuracy of LGBM classifier on test set: {:.4f}'.format(ada.score(X_test_transformed, y_test_transformed)))

pred = ada.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, ada.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=ada.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of LGBM classifier on training set: 0.8642
# Accuracy of LGBM classifier on test set: 0.8505
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84      1060
#            1       0.82      0.90      0.86      1060
#
#     accuracy                           0.85      2120
#    macro avg       0.85      0.85      0.85      2120
# weighted avg       0.85      0.85      0.85      2120

# %%
acc_train1_ada = ada.score(X_train_transformed, y_train_transformed)
acc_test1_ada = ada.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Cross validation for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_estimators': [50, 100, 150],
              'learning_rate': [0.1, 0.5, 1.0],
              'algorithm': ['SAMME', 'SAMME.R']}

# %%
grid_search = GridSearchCV(ada, param_grid, cv=5)
grid_search.fit(X_train_transformed, y_train_transformed)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(random_state=42),
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.1, 0.5, 1.0],
#                          'n_estimators': [50, 100, 150]})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'algorithm': 'SAMME.R', 'learning_rate': 1.0, 'n_estimators': 150}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 17           2.08          0.02             0.05            0.00
# 14           2.08          0.02             0.05            0.00
# 16           1.39          0.01             0.03            0.00
#
#    param_algorithm param_learning_rate param_n_estimators  \
# 17         SAMME.R                 1.0                150
# 14         SAMME.R                 0.5                150
# 16         SAMME.R                 1.0                100
#
#                                                params  split0_test_score  \
# 17  {'algorithm': 'SAMME.R', 'learning_rate': 1.0,...               0.85
# 14  {'algorithm': 'SAMME.R', 'learning_rate': 0.5,...               0.85
# 16  {'algorithm': 'SAMME.R', 'learning_rate': 1.0,...               0.85
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 17               0.87               0.86               0.89
# 14               0.87               0.86               0.88
# 16               0.86               0.86               0.88
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 17               0.86             0.87            0.01                1
# 14               0.87             0.87            0.01                2
# 16               0.86             0.86            0.01                3

# %%
# grid_search.predict(x_test)

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of AdaBoost classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of AdaBoost classifier on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of AdaBoost classifier on training set: 0.8817
# Accuracy of AdaBoost classifier on test set: 0.8627
#               precision    recall  f1-score   support
#
#            0       0.89      0.82      0.86      1060
#            1       0.84      0.90      0.87      1060
#
#     accuracy                           0.86      2120
#    macro avg       0.86      0.86      0.86      2120
# weighted avg       0.86      0.86      0.86      2120

# %%
acc_train2_ada = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_ada = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
importances = ada.feature_importances_

# Sort the feature importances in descending order
indices = np.argsort(importances)[::-1]
feature_names = data_resampled.columns[1:]
names = [feature_names[i] for i in indices]

importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# Sort the dataframe by importance
importance_df.sort_values(by='importance', ascending=False, inplace=True)

# Print the top 10 features
print(importance_df.head(10))

fi_ada = importance_df
# Out:
#     feature_name  importance
# 24     Curvature        0.36
# 23  Transparency        0.08
# 20     Concavity        0.08
# 35   Fiber Width        0.06
# 7         Volume        0.04
# 25  Surface Area        0.04
# 33   Ellipticity        0.04
# 36    type_micro        0.04
# 5     EThickness        0.04
# 34  Fiber Length        0.02

# %%
# Create plot
plt.figure()

# Create plot title
plt.title("Feature Importance")

# Add bars
plt.bar(range(X_train.shape[1]), importances[indices])

# Add feature names as x-axis labels
plt.xticks(range(X_train.shape[1]), names, rotation=90)

# Show plot
plt.show()

# %% [markdown]
# ### Random forest

# %% [markdown]
# #### Train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

X_holdout = X_test
y_holdout = y_test

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

rf = RandomForestClassifier(random_state=random_seed)
rf.fit(X_train_transformed, y_train_transformed)
print('Accuracy of RF classifier on training set: {:.4f}'.format(rf.score(X_train_transformed, y_train_transformed)))
print('Accuracy of RF classifier on test set: {:.4f}'.format(rf.score(X_test_transformed, y_test_transformed)))

pred = rf.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, rf.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=rf.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of RF classifier on training set: 0.9884
# Accuracy of RF classifier on test set: 0.8792
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.87      1060
#            1       0.85      0.92      0.88      1060
#
#     accuracy                           0.88      2120
#    macro avg       0.88      0.88      0.88      2120
# weighted avg       0.88      0.88      0.88      2120

# %%
acc_train1_rf = rf.score(X_train_transformed, y_train_transformed)
acc_test1_rf = rf.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Cross validation for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_estimators': [10, 50, 100],
              'max_depth': [None, 5, 10],
              'min_samples_split': [2, 5, 10]}
#               'min_samples_leaf': [1, 2, 4],
#               'max_features': ['auto', 'sqrt', 'log2'],
#               'max_leaf_nodes': [10, 20, 30],
#               'class_weight':[None, 'balanced'],
#               'criterion': ['gini', 'entropy']}

# %%
grid_search = GridSearchCV(rf, param_grid, cv=5)
grid_search.fit(X_test_transformed, y_test_transformed)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'max_depth': [None, 5, 10],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 50, 100]})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 50}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 7            0.21          0.00             0.01            0.00
# 20           0.39          0.00             0.01            0.00
# 2            0.42          0.00             0.02            0.00
#
#    param_max_depth param_min_samples_split param_n_estimators  \
# 7             None                      10                 50
# 20              10                       2                100
# 2             None                       2                100
#
#                                                params  split0_test_score  \
# 7   {'max_depth': None, 'min_samples_split': 10, '...               0.83
# 20  {'max_depth': 10, 'min_samples_split': 2, 'n_e...               0.81
# 2   {'max_depth': None, 'min_samples_split': 2, 'n...               0.82
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 7                0.85               0.88               0.89
# 20               0.86               0.89               0.88
# 2                0.87               0.88               0.87
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 7                0.86             0.86            0.02                1
# 20               0.85             0.86            0.03                2
# 2                0.85             0.86            0.02                3

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of Random Forest classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of Random Forest classifier on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of Random Forest classifier on training set: 0.8605
# Accuracy of Random Forest classifier on test set: 0.9642
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96      1060
#            1       0.95      0.98      0.96      1060
#
#     accuracy                           0.96      2120
#    macro avg       0.96      0.96      0.96      2120
# weighted avg       0.96      0.96      0.96      2120

# %%
acc_train2_rf = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_rf = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
importances = rf.feature_importances_

# Sort the feature importances in descending order
indices = np.argsort(importances)[::-1]
feature_names = data_resampled.columns[1:]
names = [feature_names[i] for i in indices]

importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# Sort the dataframe by importance
importance_df.sort_values(by='importance', ascending=False, inplace=True)

# Print the top 10 features
print(importance_df.head(10))

fi_rf = importance_df
# Out:
#      feature_name  importance
# 24      Curvature        0.36
# 35    Fiber Width        0.04
# 36     type_micro        0.04
# 16      Roundness        0.03
# 23   Transparency        0.03
# 17  Ellipse Ratio        0.03
# 3      FThickness        0.02
# 13      L/T Ratio        0.02
# 34   Fiber Length        0.02
# 20      Concavity        0.02

# %%
# Create plot
plt.figure()

# Create plot title
plt.title("Feature Importance")

# Add bars
plt.bar(range(X_train.shape[1]), importances[indices])

# Add feature names as x-axis labels
plt.xticks(range(X_train.shape[1]), names, rotation=90)

# Show plot
plt.show()

# %% [markdown]
# ### Bagging (Bootstrapped Aggregation)

# %% [markdown]
# #### Train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

base_estimator = DecisionTreeClassifier(max_depth=4, random_state=random_seed)
bagging = BaggingClassifier(base_estimator=base_estimator, random_state=random_seed)
bagging.fit(X_train_transformed, y_train_transformed)
print('Accuracy of LGBM classifier on training set: {:.4f}'.format(bagging.score(X_train_transformed, y_train_transformed)))
print('Accuracy of LGBM classifier on test set: {:.4f}'.format(bagging.score(X_test_transformed, y_test_transformed)))

pred = bagging.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, bagging.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=bagging.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of LGBM classifier on training set: 0.8573
# Accuracy of LGBM classifier on test set: 0.8462
#               precision    recall  f1-score   support
#
#            0       0.90      0.78      0.84      1060
#            1       0.81      0.91      0.86      1060
#
#     accuracy                           0.85      2120
#    macro avg       0.85      0.85      0.85      2120
# weighted avg       0.85      0.85      0.85      2120

# %%
acc_train1_bagging = bagging.score(X_train_transformed, y_train_transformed)
acc_test1_bagging = bagging.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Cross validation for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_estimators': [50, 100, 150],
              'max_samples': [0.5, 1.0, 2.0],
              'max_features': [0.5, 1.0, 2.0]}

# %%
grid_search = GridSearchCV(bagging, param_grid, cv=5)
grid_search.fit(X_train_transformed, y_train_transformed)
# Out:
# GridSearchCV(cv=5,
#              estimator=BaggingClassifier(base_estimator=DecisionTreeClassifier(max_depth=4,
#                                                                                random_state=42),
#                                          random_state=42),
#              param_grid={'max_features': [0.5, 1.0, 2.0],
#                          'max_samples': [0.5, 1.0, 2.0],
#                          'n_estimators': [50, 100, 150]})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 150}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 11           3.18          0.01             0.05            0.00
# 10           2.13          0.02             0.03            0.00
# 9            1.08          0.02             0.02            0.00
#
#    param_max_features param_max_samples param_n_estimators  \
# 11                1.0               0.5                150
# 10                1.0               0.5                100
# 9                 1.0               0.5                 50
#
#                                                params  split0_test_score  \
# 11  {'max_features': 1.0, 'max_samples': 0.5, 'n_e...               0.84
# 10  {'max_features': 1.0, 'max_samples': 0.5, 'n_e...               0.84
# 9   {'max_features': 1.0, 'max_samples': 0.5, 'n_e...               0.85
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 11               0.86               0.84               0.87
# 10               0.86               0.84               0.86
# 9                0.86               0.84               0.86
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 11               0.85             0.85            0.01                1
# 10               0.85             0.85            0.01                2
# 9                0.85             0.85            0.01                3

# %%
# grid_search.predict(x_test)

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of Bagging classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of Bagging classifie on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of Bagging classifier on training set: 0.8573
# Accuracy of Bagging classifie on test set: 0.8420
#               precision    recall  f1-score   support
#
#            0       0.89      0.78      0.83      1060
#            1       0.80      0.91      0.85      1060
#
#     accuracy                           0.84      2120
#    macro avg       0.85      0.84      0.84      2120
# weighted avg       0.85      0.84      0.84      2120

# %%
acc_train2_bagging = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_bagging = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
# importances = bagging.feature_importances_

# # Sort the feature importances in descending order
# indices = np.argsort(importances)[::-1]
# feature_names = data_resampled.columns[1:]
# names = [feature_names[i] for i in indices]

# importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# # Sort the dataframe by importance
# importance_df.sort_values(by='importance', ascending=False, inplace=True)

# # Print the top 10 features
# print(importance_df.head(10))

# fi_bagging = importance_df

# %%
# # Create plot
# plt.figure()

# # Create plot title
# plt.title("Feature Importance")

# # Add bars
# plt.bar(range(X_train.shape[1]), importances[indices])

# # Add feature names as x-axis labels
# plt.xticks(range(X_train.shape[1]), names, rotation=90)

# # Show plot
# plt.show()

# %% [markdown]
# ### Extra trees

# %% [markdown]
# #### Train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

X_holdout = X_test
y_holdout = y_test

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

etree = ExtraTreesClassifier(random_state=random_seed)
etree.fit(X_train_transformed, y_train_transformed)
print('Accuracy of Extra Trees classifier on training set: {:.4f}'.format(etree.score(X_train_transformed, y_train_transformed)))
print('Accuracy of Extra Trees classifier on test set: {:.4f}'.format(etree.score(X_test_transformed, y_test_transformed)))

pred = etree.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, etree.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=etree.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of Extra Trees classifier on training set: 0.9886
# Accuracy of Extra Trees classifier on test set: 0.8745
#               precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87      1060
#            1       0.85      0.90      0.88      1060
#
#     accuracy                           0.87      2120
#    macro avg       0.88      0.87      0.87      2120
# weighted avg       0.88      0.87      0.87      2120

# %%
acc_train1_etree = etree.score(X_train_transformed, y_train_transformed)
acc_test1_etree = etree.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Cross validation for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_estimators': [10, 50, 100, 150],
              'max_depth': [None, 5, 10, 20],
              'min_samples_split': [2, 5, 10]}

# %%
grid_search = GridSearchCV(etree, param_grid, cv=5)
grid_search.fit(X_test_transformed, y_test_transformed)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesClassifier(random_state=42),
#              param_grid={'max_depth': [None, 5, 10, 20],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 50, 100, 150]})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'max_depth': 20, 'min_samples_split': 5, 'n_estimators': 100}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 42           0.20          0.00             0.02            0.00
# 43           0.31          0.02             0.03            0.00
# 10           0.19          0.00             0.02            0.00
#
#    param_max_depth param_min_samples_split param_n_estimators  \
# 42              20                       5                100
# 43              20                       5                150
# 10            None                      10                100
#
#                                                params  split0_test_score  \
# 42  {'max_depth': 20, 'min_samples_split': 5, 'n_e...               0.82
# 43  {'max_depth': 20, 'min_samples_split': 5, 'n_e...               0.81
# 10  {'max_depth': None, 'min_samples_split': 10, '...               0.82
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 42               0.86               0.88               0.89
# 43               0.85               0.88               0.89
# 10               0.85               0.87               0.88
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 42               0.82             0.85            0.03                1
# 43               0.83             0.85            0.03                2
# 10               0.83             0.85            0.02                3

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of Extra Trees classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of Extra Trees classifier on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of Extra Trees classifier on training set: 0.8576
# Accuracy of Extra Trees classifier on test set: 0.9797
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98      1060
#            1       0.97      0.99      0.98      1060
#
#     accuracy                           0.98      2120
#    macro avg       0.98      0.98      0.98      2120
# weighted avg       0.98      0.98      0.98      2120

# %%
acc_train2_etree = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_etree = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
importances = etree.feature_importances_

# Sort the feature importances in descending order
indices = np.argsort(importances)[::-1]
feature_names = data_resampled.columns[1:]
names = [feature_names[i] for i in indices]

importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# Sort the dataframe by importance
importance_df.sort_values(by='importance', ascending=False, inplace=True)

# Print the top 10 features
print(importance_df.head(10))

fi_etree = importance_df
# Out:
#      feature_name  importance
# 24      Curvature        0.29
# 35    Fiber Width        0.05
# 36     type_micro        0.04
# 33    Ellipticity        0.03
# 17  Ellipse Ratio        0.03
# 16      Roundness        0.03
# 18    Circularity        0.03
# 15    Compactness        0.03
# 23   Transparency        0.03
# 19       Solidity        0.02

# %%
# Create plot
plt.figure()

# Create plot title
plt.title("Feature Importance")

# Add bars
plt.bar(range(X_train.shape[1]), importances[indices])

# Add feature names as x-axis labels
plt.xticks(range(X_train.shape[1]), names, rotation=90)

# Show plot
plt.show()

# %% [markdown]
# ### SVC (Support Vector Classification)

# %% [markdown]
# #### Train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

svc = SVC(random_state=random_seed)
svc.fit(X_train_transformed, y_train_transformed)
print('Accuracy of LR classifier on training set: {:.4f}'.format(svc.score(X_train_transformed, y_train_transformed)))
print('Accuracy of LR classifier on test set: {:.4f}'.format(svc.score(X_test_transformed, y_test_transformed)))

pred = svc.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, svc.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svc.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of LR classifier on training set: 0.8806
# Accuracy of LR classifier on test set: 0.8708
#               precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86      1060
#            1       0.83      0.93      0.88      1060
#
#     accuracy                           0.87      2120
#    macro avg       0.88      0.87      0.87      2120
# weighted avg       0.88      0.87      0.87      2120

# %%
acc_train1_svc = svc.score(X_train_transformed, y_train_transformed)
acc_test1_svc = svc.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Cross validation for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C': [0.1, 1, 10],
              'kernel': ['linear', 'rbf', 'poly'],
              'gamma': [0.01, 0.1, 1]}

# %%
grid_search = GridSearchCV(svc, param_grid, cv=5)
grid_search.fit(X_test_transformed, y_test_transformed)
# Out:
# GridSearchCV(cv=5, estimator=SVC(random_state=42),
#              param_grid={'C': [0.1, 1, 10], 'gamma': [0.01, 0.1, 1],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 19           0.08          0.00             0.05            0.00      10
# 22           0.08          0.00             0.05            0.00      10
# 13           0.09          0.01             0.05            0.00       1
#
#    param_gamma param_kernel                                     params  \
# 19        0.01          rbf  {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 22         0.1          rbf   {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 13         0.1          rbf    {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 19               0.84               0.88               0.88
# 22               0.83               0.87               0.87
# 13               0.82               0.87               0.87
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 19               0.88               0.85             0.87            0.02
# 22               0.88               0.86             0.86            0.02
# 13               0.86               0.86             0.86            0.02
#
#     rank_test_score
# 19                1
# 22                2
# 13                3

# %%
# grid_search.predict(x_test)

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of SV classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of SV classifie on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of SV classifier on training set: 0.8715
# Accuracy of SV classifie on test set: 0.8783
#               precision    recall  f1-score   support
#
#            0       0.92      0.82      0.87      1060
#            1       0.84      0.93      0.88      1060
#
#     accuracy                           0.88      2120
#    macro avg       0.88      0.88      0.88      2120
# weighted avg       0.88      0.88      0.88      2120

# %%
acc_train2_svc = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_svc = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
# importances = svc.feature_importances_

# # Sort the feature importances in descending order
# indices = np.argsort(importances)[::-1]
# feature_names = data_resampled.columns[1:]
# names = [feature_names[i] for i in indices]

# importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# # Sort the dataframe by importance
# importance_df.sort_values(by='importance', ascending=False, inplace=True)

# # Print the top 10 features
# print(importance_df.head(10))

# fi_svc = importance_df

# %%
# # Create plot
# plt.figure()

# # Create plot title
# plt.title("Feature Importance")

# # Add bars
# plt.bar(range(X_train.shape[1]), importances[indices])

# # Add feature names as x-axis labels
# plt.xticks(range(X_train.shape[1]), names, rotation=90)

# # Show plot
# plt.show()

# %%
### XGBoost

# %%
### Gradient Boosting

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ### Model accuracies

# %%
df = {'model': ['LightGBM', 'AdaBoost', 'Random Forest', 'Bagging', 'Extra Trees', 'SVC'], 
            'train_accuracy': [acc_train1_LBGM, acc_train1_ada, acc_train1_rf, acc_train1_bagging, acc_train1_etree, acc_train1_svc], 
            'test_accuracy': [acc_test1_LBGM, acc_test1_ada, acc_test1_rf, acc_test1_bagging, acc_test1_etree, acc_test1_svc],
            'train_accuracy_CV': [acc_train2_LBGM, acc_train2_ada, acc_train2_rf, acc_train2_bagging, acc_train2_etree, acc_train2_svc], 
            'test_accuracy_CV': [acc_test2_LBGM, acc_test2_ada, acc_test2_rf, acc_test2_bagging, acc_test1_etree, acc_test2_svc]}

accuracy = pd.DataFrame(df)

# %%
df = pd.DataFrame(df)
df
# Out:
#            model  train_accuracy  test_accuracy  train_accuracy_CV  \
# 0       LightGBM            0.95           0.89               0.95
# 1       AdaBoost            0.86           0.85               0.88
# 2  Random Forest            0.99           0.88               0.86
# 3        Bagging            0.86           0.85               0.86
# 4    Extra Trees            0.99           0.87               0.86
# 5            SVC            0.88           0.87               0.87
#
#    test_accuracy_CV
# 0              0.89
# 1              0.86
# 2              0.96
# 3              0.84
# 4              0.87
# 5              0.88

# %%
bar_width = 0.35

models = np.arange(len(df['model']))

plt.bar(models - bar_width/2, df['test_accuracy'], bar_width, 
        color='#FF8F45', label='test accuracy', alpha=0.9)
plt.bar(models + bar_width/2, df['test_accuracy_CV'], bar_width, 
        color='#7CF3A0', label='test accuracy after CV', alpha=0.9)

# for i, v in enumerate(df['test_accuracy']):
#     plt.text(i - bar_width/2, v + 0.01, format(v, '.4f'), ha='center', va='bottom')

# for i, v in enumerate(df['test_accuracy_CV']):
#     plt.text(i + bar_width/2, v + 0.01, format(v, '.4f'), ha='center', va='bottom')

plt.xticks(models, df['model'])
plt.xticks(rotation = 45)
plt.ylim(0.8, 1)
plt.legend()
plt.show()

# %%
# acc_train1_LBGM
# acc_test1_LBGM

# acc_train1_ada
# acc_test1_ada

# acc_train1_rf
# acc_test1_rf

# acc_train1_bagging
# acc_test1_bagging

# acc_train1_svc 
# acc_test1_svc

# acc_train2_LBGM
# acc_test2_LBGM

# acc_train2_ada 
# acc_test2_ada 

# acc_train2_rf
# acc_test2_rf

# acc_train2_bagging 
# acc_test2_bagging

# acc_train2_svc
# acc_test2_svc

# %% [markdown]
# ### Overall feature importance

# %%
fi_LGBM['importance'] = fi_LGBM['importance'] / fi_LGBM['importance'].sum()

# %%
fi_LGBM['rank'] = range(1, fi_LGBM.shape[0]+1)

# %%
fi_LGBM.head(5)
# Out:
#     feature_name  importance  rank
# 24     Curvature        0.15     1
# 23  Transparency        0.07     2
# 20     Concavity        0.06     3
# 35   Fiber Width        0.06     4
# 36    type_micro        0.05     5

# %%
fi_LGBM = fi_LGBM[['feature_name','importance']]
fi_LGBM = fi_LGBM.reset_index(drop=True)

# %%
fi_ada['rank'] = range(1, fi_ada.shape[0]+1)

# %%
fi_ada.head(5)
# Out:
#     feature_name  importance  rank
# 24     Curvature        0.36     1
# 23  Transparency        0.08     2
# 20     Concavity        0.08     3
# 35   Fiber Width        0.06     4
# 7         Volume        0.04     5

# %%
fi_ada = fi_ada[['feature_name','importance']]
fi_ada = fi_ada.reset_index(drop=True)

# %%
fi_rf['rank'] = range(1, fi_rf.shape[0]+1)

# %%
fi_rf.head()
# Out:
#     feature_name  importance  rank
# 24     Curvature        0.36     1
# 35   Fiber Width        0.04     2
# 36    type_micro        0.04     3
# 16     Roundness        0.03     4
# 23  Transparency        0.03     5

# %%
fi_rf = fi_rf[['feature_name','importance']]
fi_rf = fi_rf.reset_index(drop=True)

# %%
fi_etree['rank'] = range(1, fi_etree.shape[0]+1)

# %%
fi_etree = fi_etree[['feature_name','importance']]
fi_etree = fi_etree.reset_index(drop=True)

# %%
fi = pd.concat([fi_LGBM, fi_ada, fi_rf, fi_etree])

# %%
mean_rank = fi.groupby('feature_name').mean()
mean_rank.sort_values(by='importance', ascending=False, inplace=True)

# %%
mean_rank.head(10)
# Out:
#               importance
# feature_name
# Curvature           0.29
# Fiber Width         0.05
# Transparency        0.05
# Concavity           0.05
# type_micro          0.04
# Ellipticity         0.03
# EThickness          0.03
# Convexity           0.03
# Roundness           0.03
# FThickness          0.03

# %%
import matplotlib.pyplot as plt

mean_rank.reset_index(inplace=True)
mean_rank.head(15).plot(kind='bar', x='feature_name', y='importance')
plt.xlabel('Feature name')
plt.xticks(rotation = 90)
plt.ylabel('Feature importance')
plt.title('Overall feature importance')
plt.show()
