# %% [markdown]
# ## load package

# %%
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.utils import resample

# %%
import lazypredict

# %% [markdown]
# ## import data

# %%
# !pwd
# Out:
# /Users/ricky/Desktop/sp23-ancient-artifacts-team8/3_ml

# %%
master_micro = pd.read_csv("../0_data/master.csv")

# %%
master_micro
# Out:
#         Unnamed: 0   Id  Img Id      Da      Dp  FWidth  FLength  FThickness  \
# 0                0  104   10708  30.893  38.251  36.878   46.822      10.179
# 1                1   19    5682  27.727  33.375  35.149   40.001       9.029
# 2                2   14    4826  26.726  36.061  30.199   46.332       8.025
# 3                3    1    2812  24.408  36.198  25.039   57.353       5.086
# 4                4   83    9441  22.869  29.388  24.044   39.820       4.390
# ...            ...  ...     ...     ...     ...     ...      ...         ...
# 483648         600  591   13305   0.146   0.155   0.129    0.168       0.129
# 483649         601  464   10826   0.137   0.141   0.128    0.155       0.128
# 483650         602  236    8388   0.144   0.149   0.128    0.163       0.128
# 483651         603  369    9727   0.148   0.154   0.126    0.179       0.126
# 483652         604  481   11134   0.142   0.154   0.126    0.186       0.126
#
#         ELength  EThickness  ...  T/W Ratio  CHull Surface Area   Sieve  \
# 0        44.168      10.102  ...      0.276            3211.655  23.529
# 1        39.022       7.978  ...      0.257            2547.278  22.089
# 2        47.365       7.753  ...      0.266            2571.497  19.112
# 3        50.536       4.904  ...      0.203            2001.165  15.063
# 4        38.568       3.948  ...      0.183            1745.237  14.217
# ...         ...         ...  ...        ...                 ...     ...
# 483648    0.166       0.131  ...      1.000               0.069   0.129
# 483649    0.147       0.127  ...      1.000               0.060   0.128
# 483650    0.156       0.132  ...      1.000               0.065   0.128
# 483651    0.174       0.126  ...      1.000               0.069   0.126
# 483652    0.173       0.119  ...      1.000               0.065   0.126
#
#         Angularity  Ellipticity  Fiber Length  Fiber Width  Krumbein Rnd  \
# 0           19.392        4.372        49.768       22.823         0.214
# 1           20.688        4.891        37.445        5.128         0.214
# 2           21.250        6.110        52.384       17.379         0.219
# 3           18.233       10.304        51.467       17.096         0.251
# 4           17.086        9.769        36.426        3.135         0.276
# ...            ...          ...           ...          ...           ...
# 483648      55.000        1.271         0.000        0.000           NaN
# 483649      63.750        1.164         0.000        0.000           NaN
# 483650      56.667        1.180         0.000        0.000           NaN
# 483651      56.667        1.383         0.000        0.000           NaN
# 483652      55.714        1.450         0.000        0.000           NaN
#
#         size_micro  type_micro
# 0          unknown      lithic
# 1          unknown      lithic
# 2          unknown      lithic
# 3          unknown      lithic
# 4          unknown      lithic
# ...            ...         ...
# 483648         4mm        soil
# 483649         4mm        soil
# 483650         4mm        soil
# 483651         4mm        soil
# 483652         4mm        soil
#
# [483653 rows x 51 columns]

# %%
micro = master_micro[(master_micro['size_micro']=="2mm") | (master_micro['size_micro']=="4mm") | (master_micro['type_micro']=="lithic")].iloc[: , 3:]

# %%
pd.set_option('display.max_columns', None)
micro
# Out:
#             Da      Dp  FWidth  FLength  FThickness  ELength  EThickness  \
# 0       30.893  38.251  36.878   46.822      10.179   44.168      10.102
# 1       27.727  33.375  35.149   40.001       9.029   39.022       7.978
# 2       26.726  36.061  30.199   46.332       8.025   47.365       7.753
# 3       24.408  36.198  25.039   57.353       5.086   50.536       4.904
# 4       22.869  29.388  24.044   39.820       4.390   38.568       3.948
# ...        ...     ...     ...      ...         ...      ...         ...
# 483648   0.146   0.155   0.129    0.168       0.129    0.166       0.131
# 483649   0.137   0.141   0.128    0.155       0.128    0.147       0.127
# 483650   0.144   0.149   0.128    0.163       0.128    0.156       0.132
# 483651   0.148   0.154   0.126    0.179       0.126    0.174       0.126
# 483652   0.142   0.154   0.126    0.186       0.126    0.173       0.119
#
#         EWidth    Volume     Area  Perimeter  CHull  Area  CHull Perimeter  \
# 0       34.444  9202.973  749.562    120.170      802.914          108.399
# 1       34.108  6646.859  603.785    104.849      636.820           99.590
# 2       28.230  5879.233  560.995    113.290      642.874          100.583
# 3       23.943  3824.409  467.900    113.719      500.291          108.846
# 4       22.535  2200.862  410.744     92.327      436.309           89.254
# ...        ...       ...      ...        ...          ...              ...
# 483648   0.131     0.001    0.017      0.486        0.017            0.484
# 483649   0.127     0.001    0.015      0.443        0.015            0.442
# 483650   0.132     0.001    0.016      0.469        0.016            0.468
# 483651   0.126     0.001    0.017      0.485        0.017            0.485
# 483652   0.119     0.002    0.016      0.484        0.016            0.482
#
#         Sphericity  L/T Ratio  T/L Aspect Ratio  Compactness  Roundness  \
# 0            0.808      4.600             0.217        0.660      0.435
# 1            0.831      4.430             0.226        0.693      0.480
# 2            0.741      5.774             0.173        0.577      0.333
# 3            0.674     11.276             0.089        0.426      0.181
# 4            0.778      9.070             0.110        0.574      0.330
# ...            ...        ...               ...          ...        ...
# 483648       0.945      1.297             0.771        0.871      0.759
# 483649       0.970      1.208             0.828        0.886      0.784
# 483650       0.965      1.274             0.785        0.885      0.783
# 483651       0.962      1.415             0.707        0.829      0.688
# 483652       0.920      1.475             0.678        0.760      0.578
#
#         Ellipse Ratio  Circularity  Solidity  Concavity  Convexity  Extent  \
# 0               0.229        0.652     0.934      0.066      0.902   1.573
# 1               0.204        0.690     0.948      0.052      0.950   1.672
# 2               0.164        0.549     0.873      0.127      0.888   1.509
# 3               0.097        0.455     0.935      0.065      0.957   1.604
# 4               0.102        0.606     0.941      0.059      0.967   2.350
# ...               ...          ...       ...        ...        ...     ...
# 483648          0.787        0.893     0.976      0.024      0.996   0.773
# 483649          0.859        0.942     0.989      0.011      0.996   0.744
# 483650          0.847        0.931     0.995      0.005      1.000   0.783
# 483651          0.723        0.926     1.000      0.000      1.000   0.764
# 483652          0.690        0.847     0.974      0.026      0.996   0.670
#
#         hash  Transparency  Curvature  Surface Area Filter0 Filter1 Filter2  \
# 0          0         0.081        0.0      2998.247  Reject  Reject  Reject
# 1          0         0.126        0.0      2415.141  Reject  Reject  Reject
# 2          0         0.096        0.0      2243.981  Reject  Reject  Reject
# 3          0         0.088        0.0      1871.602  Reject  Reject  Reject
# 4          0         0.077        0.0      1642.977  Reject  Reject  Reject
# ...      ...           ...        ...           ...     ...     ...     ...
# 483648     0         0.333        0.0         0.067  Reject  Reject  Reject
# 483649     0         0.350        0.0         0.059  Reject  Reject  Reject
# 483650     0         0.442        0.0         0.065  Reject  Reject  Reject
# 483651     0         0.276        0.0         0.069  Reject  Reject  Reject
# 483652     0         0.278        0.0         0.063  Reject  Reject  Reject
#
#        Filter3 Filter4 Filter5 Filter6  L/W Ratio  W/L Ratio  W/T Ratio  \
# 0       Reject  Reject  Reject  Reject      1.270      0.788      3.623
# 1       Reject  Reject  Reject  Reject      1.138      0.879      3.893
# 2       Reject  Reject  Reject  Reject      1.534      0.652      3.763
# 3       Reject  Reject  Reject  Reject      2.291      0.437      4.923
# 4       Reject  Reject  Reject  Reject      1.656      0.604      5.477
# ...        ...     ...     ...     ...        ...        ...        ...
# 483648  Reject  Reject  Reject  Reject      1.297      0.771      1.000
# 483649  Reject  Reject  Reject  Reject      1.208      0.828      1.000
# 483650  Reject  Reject  Reject  Reject      1.274      0.785      1.000
# 483651  Reject  Reject  Reject  Reject      1.415      0.707      1.000
# 483652  Reject  Reject  Reject  Reject      1.475      0.678      1.000
#
#         T/W Ratio  CHull Surface Area   Sieve  Angularity  Ellipticity  \
# 0           0.276            3211.655  23.529      19.392        4.372
# 1           0.257            2547.278  22.089      20.688        4.891
# 2           0.266            2571.497  19.112      21.250        6.110
# 3           0.203            2001.165  15.063      18.233       10.304
# 4           0.183            1745.237  14.217      17.086        9.769
# ...           ...                 ...     ...         ...          ...
# 483648      1.000               0.069   0.129      55.000        1.271
# 483649      1.000               0.060   0.128      63.750        1.164
# 483650      1.000               0.065   0.128      56.667        1.180
# 483651      1.000               0.069   0.126      56.667        1.383
# 483652      1.000               0.065   0.126      55.714        1.450
#
#         Fiber Length  Fiber Width  Krumbein Rnd size_micro type_micro
# 0             49.768       22.823         0.214    unknown     lithic
# 1             37.445        5.128         0.214    unknown     lithic
# 2             52.384       17.379         0.219    unknown     lithic
# 3             51.467       17.096         0.251    unknown     lithic
# 4             36.426        3.135         0.276    unknown     lithic
# ...              ...          ...           ...        ...        ...
# 483648         0.000        0.000           NaN        4mm       soil
# 483649         0.000        0.000           NaN        4mm       soil
# 483650         0.000        0.000           NaN        4mm       soil
# 483651         0.000        0.000           NaN        4mm       soil
# 483652         0.000        0.000           NaN        4mm       soil
#
# [10244 rows x 48 columns]

# %% [markdown]
# ## data processing

# %% [markdown]
# ### Other processing

# %%
# Drop the columns (filter1, filter2, ...)
to_drop = micro.filter(regex='^Filter').columns
micro = micro.drop(columns=to_drop)
micro
# Out:
#             Da      Dp  FWidth  FLength  FThickness  ELength  EThickness  \
# 0       30.893  38.251  36.878   46.822      10.179   44.168      10.102
# 1       27.727  33.375  35.149   40.001       9.029   39.022       7.978
# 2       26.726  36.061  30.199   46.332       8.025   47.365       7.753
# 3       24.408  36.198  25.039   57.353       5.086   50.536       4.904
# 4       22.869  29.388  24.044   39.820       4.390   38.568       3.948
# ...        ...     ...     ...      ...         ...      ...         ...
# 483648   0.146   0.155   0.129    0.168       0.129    0.166       0.131
# 483649   0.137   0.141   0.128    0.155       0.128    0.147       0.127
# 483650   0.144   0.149   0.128    0.163       0.128    0.156       0.132
# 483651   0.148   0.154   0.126    0.179       0.126    0.174       0.126
# 483652   0.142   0.154   0.126    0.186       0.126    0.173       0.119
#
#         EWidth    Volume     Area  Perimeter  CHull  Area  CHull Perimeter  \
# 0       34.444  9202.973  749.562    120.170      802.914          108.399
# 1       34.108  6646.859  603.785    104.849      636.820           99.590
# 2       28.230  5879.233  560.995    113.290      642.874          100.583
# 3       23.943  3824.409  467.900    113.719      500.291          108.846
# 4       22.535  2200.862  410.744     92.327      436.309           89.254
# ...        ...       ...      ...        ...          ...              ...
# 483648   0.131     0.001    0.017      0.486        0.017            0.484
# 483649   0.127     0.001    0.015      0.443        0.015            0.442
# 483650   0.132     0.001    0.016      0.469        0.016            0.468
# 483651   0.126     0.001    0.017      0.485        0.017            0.485
# 483652   0.119     0.002    0.016      0.484        0.016            0.482
#
#         Sphericity  L/T Ratio  T/L Aspect Ratio  Compactness  Roundness  \
# 0            0.808      4.600             0.217        0.660      0.435
# 1            0.831      4.430             0.226        0.693      0.480
# 2            0.741      5.774             0.173        0.577      0.333
# 3            0.674     11.276             0.089        0.426      0.181
# 4            0.778      9.070             0.110        0.574      0.330
# ...            ...        ...               ...          ...        ...
# 483648       0.945      1.297             0.771        0.871      0.759
# 483649       0.970      1.208             0.828        0.886      0.784
# 483650       0.965      1.274             0.785        0.885      0.783
# 483651       0.962      1.415             0.707        0.829      0.688
# 483652       0.920      1.475             0.678        0.760      0.578
#
#         Ellipse Ratio  Circularity  Solidity  Concavity  Convexity  Extent  \
# 0               0.229        0.652     0.934      0.066      0.902   1.573
# 1               0.204        0.690     0.948      0.052      0.950   1.672
# 2               0.164        0.549     0.873      0.127      0.888   1.509
# 3               0.097        0.455     0.935      0.065      0.957   1.604
# 4               0.102        0.606     0.941      0.059      0.967   2.350
# ...               ...          ...       ...        ...        ...     ...
# 483648          0.787        0.893     0.976      0.024      0.996   0.773
# 483649          0.859        0.942     0.989      0.011      0.996   0.744
# 483650          0.847        0.931     0.995      0.005      1.000   0.783
# 483651          0.723        0.926     1.000      0.000      1.000   0.764
# 483652          0.690        0.847     0.974      0.026      0.996   0.670
#
#         hash  Transparency  Curvature  Surface Area  L/W Ratio  W/L Ratio  \
# 0          0         0.081        0.0      2998.247      1.270      0.788
# 1          0         0.126        0.0      2415.141      1.138      0.879
# 2          0         0.096        0.0      2243.981      1.534      0.652
# 3          0         0.088        0.0      1871.602      2.291      0.437
# 4          0         0.077        0.0      1642.977      1.656      0.604
# ...      ...           ...        ...           ...        ...        ...
# 483648     0         0.333        0.0         0.067      1.297      0.771
# 483649     0         0.350        0.0         0.059      1.208      0.828
# 483650     0         0.442        0.0         0.065      1.274      0.785
# 483651     0         0.276        0.0         0.069      1.415      0.707
# 483652     0         0.278        0.0         0.063      1.475      0.678
#
#         W/T Ratio  T/W Ratio  CHull Surface Area   Sieve  Angularity  \
# 0           3.623      0.276            3211.655  23.529      19.392
# 1           3.893      0.257            2547.278  22.089      20.688
# 2           3.763      0.266            2571.497  19.112      21.250
# 3           4.923      0.203            2001.165  15.063      18.233
# 4           5.477      0.183            1745.237  14.217      17.086
# ...           ...        ...                 ...     ...         ...
# 483648      1.000      1.000               0.069   0.129      55.000
# 483649      1.000      1.000               0.060   0.128      63.750
# 483650      1.000      1.000               0.065   0.128      56.667
# 483651      1.000      1.000               0.069   0.126      56.667
# 483652      1.000      1.000               0.065   0.126      55.714
#
#         Ellipticity  Fiber Length  Fiber Width  Krumbein Rnd size_micro  \
# 0             4.372        49.768       22.823         0.214    unknown
# 1             4.891        37.445        5.128         0.214    unknown
# 2             6.110        52.384       17.379         0.219    unknown
# 3            10.304        51.467       17.096         0.251    unknown
# 4             9.769        36.426        3.135         0.276    unknown
# ...             ...           ...          ...           ...        ...
# 483648        1.271         0.000        0.000           NaN        4mm
# 483649        1.164         0.000        0.000           NaN        4mm
# 483650        1.180         0.000        0.000           NaN        4mm
# 483651        1.383         0.000        0.000           NaN        4mm
# 483652        1.450         0.000        0.000           NaN        4mm
#
#        type_micro
# 0          lithic
# 1          lithic
# 2          lithic
# 3          lithic
# 4          lithic
# ...           ...
# 483648       soil
# 483649       soil
# 483650       soil
# 483651       soil
# 483652       soil
#
# [10244 rows x 41 columns]

# %%
micro = micro.drop(columns=['hash', 'size_micro', 'Krumbein Rnd']) #'Krumbein Rnd'
micro
# Out:
#             Da      Dp  FWidth  FLength  FThickness  ELength  EThickness  \
# 0       30.893  38.251  36.878   46.822      10.179   44.168      10.102
# 1       27.727  33.375  35.149   40.001       9.029   39.022       7.978
# 2       26.726  36.061  30.199   46.332       8.025   47.365       7.753
# 3       24.408  36.198  25.039   57.353       5.086   50.536       4.904
# 4       22.869  29.388  24.044   39.820       4.390   38.568       3.948
# ...        ...     ...     ...      ...         ...      ...         ...
# 483648   0.146   0.155   0.129    0.168       0.129    0.166       0.131
# 483649   0.137   0.141   0.128    0.155       0.128    0.147       0.127
# 483650   0.144   0.149   0.128    0.163       0.128    0.156       0.132
# 483651   0.148   0.154   0.126    0.179       0.126    0.174       0.126
# 483652   0.142   0.154   0.126    0.186       0.126    0.173       0.119
#
#         EWidth    Volume     Area  Perimeter  CHull  Area  CHull Perimeter  \
# 0       34.444  9202.973  749.562    120.170      802.914          108.399
# 1       34.108  6646.859  603.785    104.849      636.820           99.590
# 2       28.230  5879.233  560.995    113.290      642.874          100.583
# 3       23.943  3824.409  467.900    113.719      500.291          108.846
# 4       22.535  2200.862  410.744     92.327      436.309           89.254
# ...        ...       ...      ...        ...          ...              ...
# 483648   0.131     0.001    0.017      0.486        0.017            0.484
# 483649   0.127     0.001    0.015      0.443        0.015            0.442
# 483650   0.132     0.001    0.016      0.469        0.016            0.468
# 483651   0.126     0.001    0.017      0.485        0.017            0.485
# 483652   0.119     0.002    0.016      0.484        0.016            0.482
#
#         Sphericity  L/T Ratio  T/L Aspect Ratio  Compactness  Roundness  \
# 0            0.808      4.600             0.217        0.660      0.435
# 1            0.831      4.430             0.226        0.693      0.480
# 2            0.741      5.774             0.173        0.577      0.333
# 3            0.674     11.276             0.089        0.426      0.181
# 4            0.778      9.070             0.110        0.574      0.330
# ...            ...        ...               ...          ...        ...
# 483648       0.945      1.297             0.771        0.871      0.759
# 483649       0.970      1.208             0.828        0.886      0.784
# 483650       0.965      1.274             0.785        0.885      0.783
# 483651       0.962      1.415             0.707        0.829      0.688
# 483652       0.920      1.475             0.678        0.760      0.578
#
#         Ellipse Ratio  Circularity  Solidity  Concavity  Convexity  Extent  \
# 0               0.229        0.652     0.934      0.066      0.902   1.573
# 1               0.204        0.690     0.948      0.052      0.950   1.672
# 2               0.164        0.549     0.873      0.127      0.888   1.509
# 3               0.097        0.455     0.935      0.065      0.957   1.604
# 4               0.102        0.606     0.941      0.059      0.967   2.350
# ...               ...          ...       ...        ...        ...     ...
# 483648          0.787        0.893     0.976      0.024      0.996   0.773
# 483649          0.859        0.942     0.989      0.011      0.996   0.744
# 483650          0.847        0.931     0.995      0.005      1.000   0.783
# 483651          0.723        0.926     1.000      0.000      1.000   0.764
# 483652          0.690        0.847     0.974      0.026      0.996   0.670
#
#         Transparency  Curvature  Surface Area  L/W Ratio  W/L Ratio  \
# 0              0.081        0.0      2998.247      1.270      0.788
# 1              0.126        0.0      2415.141      1.138      0.879
# 2              0.096        0.0      2243.981      1.534      0.652
# 3              0.088        0.0      1871.602      2.291      0.437
# 4              0.077        0.0      1642.977      1.656      0.604
# ...              ...        ...           ...        ...        ...
# 483648         0.333        0.0         0.067      1.297      0.771
# 483649         0.350        0.0         0.059      1.208      0.828
# 483650         0.442        0.0         0.065      1.274      0.785
# 483651         0.276        0.0         0.069      1.415      0.707
# 483652         0.278        0.0         0.063      1.475      0.678
#
#         W/T Ratio  T/W Ratio  CHull Surface Area   Sieve  Angularity  \
# 0           3.623      0.276            3211.655  23.529      19.392
# 1           3.893      0.257            2547.278  22.089      20.688
# 2           3.763      0.266            2571.497  19.112      21.250
# 3           4.923      0.203            2001.165  15.063      18.233
# 4           5.477      0.183            1745.237  14.217      17.086
# ...           ...        ...                 ...     ...         ...
# 483648      1.000      1.000               0.069   0.129      55.000
# 483649      1.000      1.000               0.060   0.128      63.750
# 483650      1.000      1.000               0.065   0.128      56.667
# 483651      1.000      1.000               0.069   0.126      56.667
# 483652      1.000      1.000               0.065   0.126      55.714
#
#         Ellipticity  Fiber Length  Fiber Width type_micro
# 0             4.372        49.768       22.823     lithic
# 1             4.891        37.445        5.128     lithic
# 2             6.110        52.384       17.379     lithic
# 3            10.304        51.467       17.096     lithic
# 4             9.769        36.426        3.135     lithic
# ...             ...           ...          ...        ...
# 483648        1.271         0.000        0.000       soil
# 483649        1.164         0.000        0.000       soil
# 483650        1.180         0.000        0.000       soil
# 483651        1.383         0.000        0.000       soil
# 483652        1.450         0.000        0.000       soil
#
# [10244 rows x 38 columns]

# %% [markdown]
# ### Redersampling

# %% [markdown]
# https://machinelearningmastery.com/undersampling-algorithms-for-imbalanced-classification/
# https://www.analyticsvidhya.com/blog/2020/07/10-techniques-to-deal-with-class-imbalance-in-machine-learning/
# https://towardsdatascience.com/imbalanced-classification-in-python-smote-tomek-links-method-6e48dfe69bbc

# %%
# !pip install imblearn

# %%
# from imblearn.combine import SMOTETomek
from imblearn.under_sampling import TomekLinks
from imblearn.combine import SMOTETomek
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import CondensedNearestNeighbour

# %%
micro.groupby('type_micro').describe()
# Out:
#                 Da                                                         \
#              count      mean       std   min    25%    50%    75%     max
# type_micro
# lithic      5299.0  0.408032  1.629126  0.04  0.161  0.193  0.251  30.893
# soil        4945.0  2.147519  1.287821  0.12  0.738  2.411  2.807   7.571
#
#                 Dp                                                         \
#              count      mean       std    min    25%   50%    75%     max
# type_micro
# lithic      5299.0  0.533303  2.193727  0.058  0.198  0.25  0.330  38.251
# soil        4945.0  2.407316  1.469805  0.137  0.832  2.64  3.142   9.314
#
#             FWidth                                                          \
#              count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic      5299.0  0.351058  1.685466  0.021  0.107  0.138  0.194  36.878
# soil        4945.0  2.088539  1.271590  0.125  0.713  2.347  2.748   8.311
#
#            FLength                                                          \
#              count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic      5299.0  0.731248  3.023436  0.074  0.254  0.339  0.458  57.353
# soil        4945.0  3.090683  1.949345  0.148  1.031  3.310  4.079  12.830
#
#            FThickness                                                          \
#                 count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic         5299.0  0.220404  0.661258  0.021  0.102  0.130  0.170  16.445
# soil           4945.0  1.390273  0.873212  0.125  0.466  1.519  1.931   5.431
#
#            ELength                                                           \
#              count      mean       std    min    25%    50%     75%     max
# type_micro
# lithic      5299.0  0.700690  2.950370  0.041  0.238  0.315  0.4315  50.536
# soil        4945.0  3.057537  1.946877  0.141  1.008  3.270  4.0370  13.347
#
#            EThickness                                                          \
#                 count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic         5299.0  0.208487  0.623842  0.015  0.096  0.122  0.163  16.227
# soil           4945.0  1.369794  0.864878  0.072  0.451  1.498  1.910   5.438
#
#             EWidth                                                          \
#              count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic      5299.0  0.336963  1.629089  0.015  0.100  0.130  0.186  34.444
# soil        4945.0  2.066905  1.260413  0.072  0.689  2.334  2.729   7.942
#
#             Volume                                                      \
#              count       mean         std    min    25%    50%     75%
# type_micro
# lithic      5299.0  16.602042  236.156080  0.000  0.002  0.003   0.007
# soil        4945.0   9.597160   15.585326  0.001  0.190  6.530  10.054
#
#                         Area                                                   \
#                  max   count      mean        std    min    25%    50%    75%
# type_micro
# lithic      9202.973  5299.0  2.214862  25.126003  0.001  0.020  0.029  0.049
# soil         188.638  4945.0  4.924435   4.978660  0.011  0.428  4.566  6.189
#
#                     Perimeter                                                  \
#                 max     count      mean       std    min    25%    50%    75%
# type_micro
# lithic      749.562    5299.0  1.675445  6.891800  0.183  0.623  0.785  1.036
# soil         45.017    4945.0  7.562811  4.617518  0.430  2.615  8.295  9.872
#
#                     CHull  Area                                            \
#                 max       count      mean        std    min    25%    50%
# type_micro
# lithic      120.170      5299.0  2.402839  27.222648  0.001  0.021  0.031
# soil         29.261      4945.0  5.099360   5.168249  0.014  0.440  4.697
#
#                            CHull Perimeter                                    \
#               75%      max           count      mean       std    min    25%
# type_micro
# lithic      0.052  802.914          5299.0  1.632610  6.573565  0.183  0.622
# soil        6.387   47.443          4945.0  7.373236  4.455980  0.430  2.538
#
#                                   Sphericity                             \
#               50%    75%      max      count      mean       std    min
# type_micro
# lithic      0.779  1.026  108.846     5299.0  0.790303  0.117014  0.226
# soil        8.146  9.612   26.285     4945.0  0.900846  0.059990  0.382
#
#                                        L/T Ratio                             \
#               25%    50%    75%    max     count      mean       std    min
# type_micro
# lithic      0.726  0.813  0.881  0.981    5299.0  2.962653  1.638428  1.084
# soil        0.879  0.915  0.940  0.992    4945.0  2.296821  0.949908  1.073
#
#                                         T/L Aspect Ratio                      \
#               25%    50%    75%     max            count      mean       std
# type_micro
# lithic      1.908  2.535  3.524  19.069           5299.0  0.413635  0.168698
# soil        1.714  2.032  2.551  12.947           4945.0  0.485331  0.138569
#
#                                               Compactness                      \
#               min    25%    50%    75%    max       count      mean       std
# type_micro
# lithic      0.052  0.284  0.394  0.524  0.922      5299.0  0.599855  0.130086
# soil        0.077  0.392  0.492  0.583  0.932      4945.0  0.715072  0.088761
#
#                                                Roundness                      \
#               min    25%    50%     75%    max     count      mean       std
# type_micro
# lithic      0.194  0.507  0.601  0.6945  0.941    5299.0  0.376740  0.156491
# soil        0.213  0.665  0.725  0.7760  0.933    4945.0  0.519209  0.121500
#
#                                               Ellipse Ratio            \
#               min    25%    50%    75%    max         count      mean
# type_micro
# lithic      0.037  0.257  0.361  0.482  0.885        5299.0  0.420723
# soil        0.045  0.442  0.526  0.602  0.871        4945.0  0.486513
#
#                                                         Circularity            \
#                  std    min    25%    50%     75%   max       count      mean
# type_micro
# lithic      0.182279  0.043  0.280  0.402  0.5485  1.00      5299.0  0.638278
# soil        0.147118  0.067  0.387  0.490  0.5900  0.97      4945.0  0.815119
#
#                                                         Solidity            \
#                  std    min    25%    50%    75%    max    count      mean
# type_micro
# lithic      0.172553  0.051  0.527  0.660  0.776  0.962   5299.0  0.943644
# soil        0.099938  0.146  0.772  0.837  0.884  0.984   4945.0  0.966234
#
#                                                       Concavity            \
#                  std    min    25%    50%    75%  max     count      mean
# type_micro
# lithic      0.080178  0.111  0.936  0.971  0.988  1.0    5299.0  0.056356
# soil        0.034755  0.353  0.959  0.975  0.985  1.0    4945.0  0.033766
#
#                                                       Convexity            \
#                  std  min    25%    50%    75%    max     count      mean
# type_micro
# lithic      0.080179  0.0  0.012  0.029  0.064  0.889    5299.0  0.991046
# soil        0.034755  0.0  0.015  0.025  0.041  0.647    4945.0  0.978718
#
#                                                        Extent            \
#                  std    min    25%    50%    75%  max   count      mean
# type_micro
# lithic      0.018609  0.530  0.991  0.997  0.999  1.0  5299.0  0.730798
# soil        0.025860  0.556  0.974  0.987  0.993  1.0  4945.0  0.874114
#
#                                                        Transparency            \
#                 std    min    25%    50%    75%    max        count      mean
# type_micro
# lithic      0.18789  0.071  0.653  0.711  0.764  3.002       5299.0  0.456355
# soil        0.21702  0.227  0.749  0.821  0.939  3.287       4945.0  0.222917
#
#                                                         Curvature            \
#                  std    min    25%    50%    75%    max     count      mean
# type_micro
# lithic      0.162607  0.000  0.424  0.512  0.551  0.832    5299.0  0.075975
# soil        0.111357  0.085  0.162  0.173  0.231  0.694    4945.0  0.079590
#
#                                                 Surface Area             \
#                  std  min  25%  50%  75%    max        count       mean
# type_micro
# lithic      0.320574  0.0  0.0  0.0  0.0  6.108       5299.0   8.859449
# soil        0.250232  0.0  0.0  0.0  0.0  2.953       4945.0  19.697729
#
#                                                                L/W Ratio  \
#                    std    min    25%     50%     75%       max     count
# type_micro
# lithic      100.504014  0.005  0.082   0.117   0.198  2998.247    5299.0
# soil         19.914620  0.046  1.711  18.265  24.755   180.066    4945.0
#
#                                                                    W/L Ratio  \
#                 mean       std    min    25%    50%    75%     max     count
# type_micro
# lithic      2.614261  1.261189  1.084  1.756  2.269  3.102  18.300    5299.0
# soil        1.488373  0.379489  1.056  1.272  1.395  1.588   7.697    4945.0
#
#                                                                   W/T Ratio  \
#                 mean       std    min    25%    50%    75%    max     count
# type_micro
# lithic      0.451302  0.166853  0.055  0.322  0.441  0.569  0.922    5299.0
# soil        0.699458  0.120380  0.130  0.630  0.717  0.786  0.947    4945.0
#
#                                                                 T/W Ratio  \
#                 mean       std  min    25%    50%    75%    max     count
# type_micro
# lithic      1.175189  0.565394  1.0  1.000  1.000  1.000  6.841    5299.0
# soil        1.549774  0.535044  1.0  1.218  1.399  1.691  8.345    4945.0
#
#                                                                  \
#                 mean       std    min    25%    50%    75%  max
# type_micro
# lithic      0.930623  0.179607  0.146  1.000  1.000  1.000  1.0
# soil        0.695774  0.162911  0.120  0.591  0.715  0.821  1.0
#
#            CHull Surface Area                                               \
#                         count       mean         std    min    25%     50%
# type_micro
# lithic                 5299.0   9.611345  108.890588  0.006  0.086   0.125
# soil                   4945.0  20.397416   20.673009  0.057  1.759  18.786
#
#                                Sieve                                           \
#                75%       max   count      mean       std    min    25%    50%
# type_micro
# lithic       0.210  3211.655  5299.0  0.285732  1.145785  0.021  0.107  0.137
# soil        25.547   189.773  4945.0  1.739411  1.040525  0.125  0.594  1.976
#
#                            Angularity                                     \
#                75%     max      count       mean        std  min     25%
# type_micro
# lithic      0.1835  23.529     5299.0  69.491435  27.561298  0.0  63.333
# soil        2.2810   6.240     4945.0  29.845364  13.158775  7.4  20.244
#
#                                 Ellipticity                                    \
#                50%   75%    max       count      mean       std    min    25%
# type_micro
# lithic      70.000  85.0  120.0      5299.0  3.009928  1.868712  1.000  1.824
# soil        25.082  37.5   87.5      4945.0  2.327549  1.063183  1.031  1.695
#
#                                   Fiber Length                                \
#               50%     75%     max        count      mean       std  min  25%
# type_micro
# lithic      2.489  3.5765  23.322       5299.0  0.648506  3.047920  0.0  0.0
# soil        2.039  2.5860  14.874       4945.0  1.761619  2.017319  0.0  0.0
#
#                                  Fiber Width                                \
#               50%    75%     max       count      mean       std  min  25%
# type_micro
# lithic      0.272  0.396  52.384      5299.0  0.193938  0.937805  0.0  0.0
# soil        0.813  3.102  18.373      4945.0  0.811935  0.924680  0.0  0.0
#
#
#               50%    75%     max
# type_micro
# lithic      0.084  0.126  22.823
# soil        0.342  1.533   6.715

# %%
# define the undersampling method
# undersample = SMOTE(sampling_strategy='minority')
# undersample = TomekLinks(sampling_strategy='majority')
undersample = SMOTETomek(tomek=TomekLinks(sampling_strategy='majority'))
# undersample = CondensedNearestNeighbour(n_neighbors=1)

# Separate majority and minority classes
class_column = ['type_micro']
X = micro.drop(columns=class_column)
y = micro[class_column]

X_resampled, y_resampled = undersample.fit_resample(X, y)

# %%
data_resampled = pd.concat([X_resampled, y_resampled], axis=1)

# %%
data_resampled.columns = X.columns.tolist() + ['type_micro']

# %%
data_resampled
# Out:
#               Da         Dp     FWidth    FLength  FThickness    ELength  \
# 0      30.893000  38.251000  36.878000  46.822000   10.179000  44.168000
# 1      27.727000  33.375000  35.149000  40.001000    9.029000  39.022000
# 2      26.726000  36.061000  30.199000  46.332000    8.025000  47.365000
# 3      24.408000  36.198000  25.039000  57.353000    5.086000  50.536000
# 4      22.869000  29.388000  24.044000  39.820000    4.390000  38.568000
# ...          ...        ...        ...        ...         ...        ...
# 10539   2.300763   2.559972   2.257980   3.459279    1.183275   3.472526
# 10540   0.248323   0.259805   0.229841   0.311841    0.194250   0.307841
# 10541   2.192409   2.399818   2.152416   3.226845    1.358079   3.278964
# 10542   2.992422   3.284137   2.539420   4.511947    2.016576   4.629417
# 10543   3.130098   3.341764   3.036815   4.150598    2.144800   4.018180
#
#        EThickness     EWidth       Volume        Area   Perimeter  \
# 0       10.102000  34.444000  9202.973000  749.562000  120.170000
# 1        7.978000  34.108000  6646.859000  603.785000  104.849000
# 2        7.753000  28.230000  5879.233000  560.995000  113.290000
# 3        4.904000  23.943000  3824.409000  467.900000  113.719000
# 4        3.948000  22.535000  2200.862000  410.744000   92.327000
# ...           ...        ...          ...         ...         ...
# 10539    1.172171   2.265640     4.837066    4.158319    8.043134
# 10540    0.190732   0.223542     0.007073    0.048811    0.815524
# 10541    1.366409   2.187313     4.940029    3.774093    7.537699
# 10542    1.976113   2.544727    12.027079    7.032827   10.316837
# 10543    2.109216   3.048595    14.152589    7.696028   10.497292
#
#        CHull  Area  CHull Perimeter  Sphericity  L/T Ratio  T/L Aspect Ratio  \
# 0       802.914000       108.399000    0.808000   4.600000          0.217000
# 1       636.820000        99.590000    0.831000   4.430000          0.226000
# 2       642.874000       100.583000    0.741000   5.774000          0.173000
# 3       500.291000       108.846000    0.674000  11.276000          0.089000
# 4       436.309000        89.254000    0.778000   9.070000          0.110000
# ...            ...              ...         ...        ...               ...
# 10539     4.198752         7.992701    0.899182   2.922016          0.342481
# 10540     0.049329         0.814042    0.955701   1.612135          0.621213
# 10541     3.824368         7.493668    0.913323   2.376318          0.421883
# 10542     7.257007        10.160259    0.911285   2.274853          0.450621
# 10543     7.833896        10.317376    0.936854   1.937020          0.517270
#
#        Compactness  Roundness  Ellipse Ratio  Circularity  Solidity  \
# 0         0.660000   0.435000       0.229000     0.652000  0.934000
# 1         0.693000   0.480000       0.204000     0.690000  0.948000
# 2         0.577000   0.333000       0.164000     0.549000  0.873000
# 3         0.426000   0.181000       0.097000     0.455000  0.935000
# 4         0.574000   0.330000       0.102000     0.606000  0.941000
# ...            ...        ...            ...          ...       ...
# 10539     0.665908   0.444066       0.338371     0.808231  0.990189
# 10540     0.794994   0.632286       0.619695     0.913366  0.990555
# 10541     0.680096   0.463010       0.416725     0.834457  0.987134
# 10542     0.665312   0.443748       0.429180     0.830285  0.969281
# 10543     0.754407   0.569343       0.524416     0.877553  0.982699
#
#        Concavity  Convexity    Extent  Transparency  Curvature  Surface Area  \
# 0       0.066000   0.902000  1.573000      0.081000   0.000000   2998.247000
# 1       0.052000   0.950000  1.672000      0.126000   0.000000   2415.141000
# 2       0.127000   0.888000  1.509000      0.096000   0.000000   2243.981000
# 3       0.065000   0.957000  1.604000      0.088000   0.000000   1871.602000
# 4       0.059000   0.967000  2.350000      0.077000   0.000000   1642.977000
# ...          ...        ...       ...           ...        ...           ...
# 10539   0.009811   0.994000  1.017468      0.180677   0.000000     16.633464
# 10540   0.009445   0.998000  0.799073      0.303676   0.058566      0.195280
# 10541   0.012866   0.994378  0.862474      0.181409   0.000000     15.096373
# 10542   0.030719   0.984571  0.778683      0.159717   0.000000     28.132595
# 10543   0.017301   0.982854  0.864528      0.152081   0.000000     30.783421
#
#        L/W Ratio  W/L Ratio  W/T Ratio  T/W Ratio  CHull Surface Area  \
# 0       1.270000   0.788000   3.623000   0.276000         3211.655000
# 1       1.138000   0.879000   3.893000   0.257000         2547.278000
# 2       1.534000   0.652000   3.763000   0.266000         2571.497000
# 3       2.291000   0.437000   4.923000   0.203000         2001.165000
# 4       1.656000   0.604000   5.477000   0.183000         1745.237000
# ...          ...        ...        ...        ...                 ...
# 10539   1.533473   0.654846   1.908705   0.524196           16.795196
# 10540   1.359647   0.735732   1.185299   0.843628            0.196762
# 10541   1.498589   0.667639   1.584983   0.631158           15.299285
# 10542   1.776787   0.564307   1.273036   0.794489           29.028887
# 10543   1.366950   0.731798   1.416568   0.705871           31.334584
#
#            Sieve  Angularity  Ellipticity  Fiber Length  Fiber Width  \
# 0      23.529000   19.392000     4.372000     49.768000    22.823000
# 1      22.089000   20.688000     4.891000     37.445000     5.128000
# 2      19.112000   21.250000     6.110000     52.384000    17.379000
# 3      15.063000   18.233000    10.304000     51.467000    17.096000
# 4      14.217000   17.086000     9.769000     36.426000     3.135000
# ...          ...         ...          ...           ...          ...
# 10539   1.721127   23.178736     2.961139      2.648271     1.236580
# 10540   0.212286   55.000000     1.615171      0.000000     0.000000
# 10541   1.755653   18.992737     2.400541      2.255304     1.573203
# 10542   2.277640   18.129508     2.365199      3.184230     2.518726
# 10543   2.591230   22.754493     1.907663      0.000000     0.000000
#
#       type_micro
# 0         lithic
# 1         lithic
# 2         lithic
# 3         lithic
# 4         lithic
# ...          ...
# 10539       soil
# 10540       soil
# 10541       soil
# 10542       soil
# 10543       soil
#
# [10544 rows x 38 columns]

# %%
data_resampled.groupby('type_micro').describe()
# Out:
#                 Da                                                          \
#              count      mean       std   min     25%    50%    75%     max
# type_micro
# lithic      5245.0  0.403625  1.633920  0.04  0.1610  0.192  0.249  30.893
# soil        5299.0  2.143006  1.289214  0.12  0.7285  2.409  2.800   7.571
#
#                 Dp                                                      \
#              count      mean       std    min       25%    50%     75%
# type_micro
# lithic      5245.0  0.528284  2.201166  0.058  0.198000  0.249  0.3270
# soil        5299.0  2.400661  1.468525  0.137  0.821916  2.635  3.1335
#
#                     FWidth                                                  \
#                max   count      mean       std    min    25%    50%    75%
# type_micro
# lithic      38.251  5245.0  0.347113  1.690198  0.021  0.107  0.137  0.191
# soil         9.314  5299.0  2.084874  1.272598  0.125  0.697  2.348  2.741
#
#                    FLength                                                   \
#                max   count      mean       std    min     25%    50%    75%
# type_micro
# lithic      36.878  5245.0  0.724392  3.032785  0.074  0.2540  0.337  0.455
# soil         8.311  5299.0  3.080682  1.946443  0.148  1.0215  3.304  4.063
#
#                    FThickness                                           \
#                max      count      mean       std    min    25%    50%
# type_micro
# lithic      57.353     5245.0  0.217363  0.662484  0.021  0.102  0.129
# soil        12.830     5299.0  1.387961  0.874282  0.125  0.460  1.518
#
#                            ELength                                           \
#                75%     max   count      mean       std    min    25%    50%
# type_micro
# lithic      0.1690  16.445  5245.0  0.693831  2.959015  0.041  0.238  0.314
# soil        1.9265   5.431  5299.0  3.047281  1.942328  0.141  1.001  3.263
#
#                           EThickness                                           \
#               75%     max      count      mean       std    min    25%    50%
# type_micro
# lithic      0.427  50.536     5245.0  0.205547  0.624931  0.015  0.096  0.122
# soil        4.028  13.347     5299.0  1.367439  0.865804  0.072  0.447  1.493
#
#                            EWidth                                            \
#               75%     max   count      mean       std    min     25%    50%
# type_micro
# lithic      0.162  16.227  5245.0  0.333090  1.633202  0.015  0.1000  0.129
# soil        1.904   5.438  5299.0  2.063393  1.261689  0.072  0.6845  2.333
#
#                            Volume                                        \
#               75%     max   count       mean         std    min     25%
# type_micro
# lithic      0.183  34.444  5245.0  16.749938  237.360829  0.000  0.0020
# soil        2.721   7.942  5299.0   9.584158   15.710548  0.001  0.1755
#
#                                        Area                              \
#               50%     75%       max   count      mean        std    min
# type_micro
# lithic      0.003  0.0060  9202.973  5245.0  2.224330  25.249640  0.001
# soil        6.504  9.9865   188.638  5299.0  4.912098   4.994126  0.011
#
#                                            Perimeter                      \
#                25%    50%     75%      max     count      mean       std
# type_micro
# lithic      0.0200  0.029  0.0490  749.562    5245.0  1.659678  6.915169
# soil        0.4165  4.558  6.1575   45.017    5299.0  7.541901  4.613496
#
#                                                    CHull  Area            \
#               min       25%    50%    75%      max       count      mean
# type_micro
# lithic      0.183  0.623000  0.781  1.026  120.170      5245.0  2.413597
# soil        0.430  2.581707  8.280  9.844   29.261      5299.0  5.084779
#
#                                                               CHull Perimeter  \
#                   std    min    25%    50%       75%      max           count
# type_micro
# lithic      27.357031  0.001  0.021  0.031  0.051000  802.914          5245.0
# soil         5.180528  0.014  0.435  4.687  6.347601   47.443          5299.0
#
#                                                                        \
#                 mean       std    min     25%    50%     75%      max
# type_micro
# lithic      1.617013  6.595341  0.183  0.6210  0.776  1.0190  108.846
# soil        7.354548  4.455649  0.430  2.5245  8.134  9.5895   26.285
#
#            Sphericity                                                         \
#                 count      mean       std    min    25%    50%    75%    max
# type_micro
# lithic         5245.0  0.789785  0.117210  0.226  0.726  0.812  0.881  0.981
# soil           5299.0  0.901248  0.059884  0.382  0.880  0.915  0.940  0.992
#
#            L/T Ratio                                                          \
#                count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic        5245.0  2.964975  1.637166  1.084  1.913  2.538  3.524  19.069
# soil          5299.0  2.292232  0.940844  1.073  1.713  2.031  2.549  12.947
#
#            T/L Aspect Ratio                                                    \
#                       count      mean      std    min       25%    50%    75%
# type_micro
# lithic               5245.0  0.412944  0.16802  0.052  0.284000  0.394  0.523
# soil                 5299.0  0.485922  0.13814  0.077  0.392069  0.492  0.584
#
#                   Compactness                                                  \
#               max       count      mean       std    min    25%    50%    75%
# type_micro
# lithic      0.922      5245.0  0.599256  0.129909  0.194  0.506  0.600  0.694
# soil        0.932      5299.0  0.715722  0.088433  0.213  0.666  0.726  0.777
#
#                   Roundness                                                  \
#               max     count      mean       std    min    25%    50%    75%
# type_micro
# lithic      0.941    5245.0  0.375976  0.156079  0.037  0.256  0.360  0.481
# soil        0.933    5299.0  0.520121  0.120940  0.045  0.444  0.527  0.603
#
#                   Ellipse Ratio                                             \
#               max         count      mean       std    min      25%    50%
# type_micro
# lithic      0.885        5245.0  0.420087  0.181618  0.043  0.27900  0.401
# soil        0.871        5299.0  0.487077  0.146674  0.067  0.38719  0.491
#
#                         Circularity                                           \
#               75%   max       count      mean       std    min    25%    50%
# type_micro
# lithic      0.547  1.00      5245.0  0.637504  0.172745  0.051  0.527  0.659
# soil        0.591  0.97      5299.0  0.815847  0.099534  0.146  0.774  0.838
#
#                             Solidity                                       \
#                  75%    max    count      mean       std    min       25%
# type_micro
# lithic      0.775000  0.962   5245.0  0.943508  0.080499  0.111  0.936000
# soil        0.884445  0.984   5299.0  0.966370  0.035165  0.353  0.959792
#
#                               Concavity                                  \
#               50%    75%  max     count      mean       std  min    25%
# type_micro
# lithic      0.971  0.988  1.0    5245.0  0.056492  0.080499  0.0  0.012
# soil        0.975  0.985  1.0    5299.0  0.033630  0.035165  0.0  0.015
#
#                                    Convexity                             \
#               50%       75%    max     count      mean       std    min
# type_micro
# lithic      0.029  0.064000  0.889    5245.0  0.991088  0.018618  0.530
# soil        0.025  0.040208  0.647    5299.0  0.978861  0.025512  0.556
#
#                                          Extent                             \
#                  25%    50%    75%  max   count      mean       std    min
# type_micro
# lithic      0.991000  0.997  0.999  1.0  5245.0  0.730198  0.187236  0.071
# soil        0.974691  0.987  0.993  1.0  5299.0  0.874079  0.214113  0.227
#
#                                         Transparency                      \
#               25%    50%     75%    max        count      mean       std
# type_micro
# lithic      0.653  0.711  0.7640  3.002       5245.0  0.456867  0.162806
# soil        0.750  0.822  0.9395  3.287       5299.0  0.223128  0.111539
#
#                                               Curvature                      \
#               min    25%    50%    75%    max     count      mean       std
# type_micro
# lithic      0.000  0.426  0.513  0.552  0.832    5245.0  0.075801  0.321271
# soil        0.085  0.162  0.173  0.231  0.694    5299.0  0.080206  0.249885
#
#                                       Surface Area                         \
#             min  25%  50%  75%    max        count       mean         std
# type_micro
# lithic      0.0  0.0  0.0  0.0  6.108       5245.0   8.897324  100.998561
# soil        0.0  0.0  0.0  0.0  2.953       5299.0  19.648383   19.976478
#
#                                                      L/W Ratio            \
#               min     25%     50%      75%       max     count      mean
# type_micro
# lithic      0.005  0.0820   0.116   0.1950  2998.247    5245.0  2.620408
# soil        0.046  1.6675  18.231  24.6295   180.066    5299.0  1.486645
#
#                                                          W/L Ratio            \
#                  std    min    25%    50%    75%     max     count      mean
# type_micro
# lithic      1.263600  1.084  1.762  2.275  3.116  18.300    5245.0  0.450179
# soil        0.377951  1.056  1.272  1.394  1.584   7.697    5299.0  0.700230
#
#                                                         W/T Ratio            \
#                  std    min    25%    50%    75%    max     count      mean
# type_micro
# lithic      0.166363  0.055  0.321  0.440  0.567  0.922    5245.0  1.173283
# soil        0.119684  0.130  0.631  0.718  0.786  0.947    5299.0  1.548156
#
#                                                     T/W Ratio            \
#                  std  min    25%  50%    75%    max     count      mean
# type_micro
# lithic      0.563074  1.0  1.000  1.0  1.000  6.841    5245.0  0.931438
# soil        0.526974  1.0  1.219  1.4  1.691  8.345    5299.0  0.695758
#
#                                                       CHull Surface Area  \
#                  std    min     25%    50%   75%  max              count
# type_micro
# lithic      0.178817  0.146  1.0000  1.000  1.00  1.0             5245.0
# soil        0.161728  0.120  0.5915  0.714  0.82  1.0             5299.0
#
#                                                                               \
#                  mean         std    min    25%     50%        75%       max
# type_micro
# lithic       9.654375  109.428120  0.006  0.086   0.124   0.206000  3211.655
# soil        20.339093   20.722125  0.057  1.740  18.747  25.391334   189.773
#
#              Sieve                                                            \
#              count      mean       std    min    25%    50%      75%     max
# type_micro
# lithic      5245.0  0.282240  1.148926  0.021  0.106  0.136  0.18200  23.529
# soil        5299.0  1.736423  1.042209  0.125  0.583  1.975  2.27782   6.240
#
#            Angularity                                                      \
#                 count       mean        std  min     25%     50%      75%
# type_micro
# lithic         5245.0  69.728392  27.572779  0.0  65.000  70.000  85.0000
# soil           5299.0  29.848137  13.167254  7.4  20.233  25.082  37.5425
#
#                   Ellipticity                                                  \
#               max       count      mean       std    min    25%    50%    75%
# type_micro
# lithic      120.0      5245.0  3.012024  1.868346  1.000  1.828  2.491  3.579
# soil         87.5      5299.0  2.323343  1.055367  1.031  1.693  2.037  2.582
#
#                    Fiber Length                                              \
#                max        count      mean       std  min  25%    50%    75%
# type_micro
# lithic      23.322       5245.0  0.644279  3.058904  0.0  0.0  0.272  0.394
# soil        14.874       5299.0  1.748136  2.002325  0.0  0.0  0.785  3.091
#
#                    Fiber Width                                              \
#                max       count      mean       std  min  25%    50%    75%
# type_micro
# lithic      52.384      5245.0  0.191374  0.937965  0.0  0.0  0.084  0.125
# soil        18.373      5299.0  0.809206  0.922608  0.0  0.0  0.334  1.533
#
#
#                max
# type_micro
# lithic      22.823
# soil         6.715

# %%
# # Separate majority and minority classes
# df_majority = micro1[micro1.type_micro=='soil']
# df_minority = micro1[micro1.type_micro=='lithic']

# # Downsample majority class
# df_majority_downsampled = resample(df_majority, 
#                                  replace=False,    # sample without replacement
#                                  n_samples=5299,     # to match minority class
#                                  random_state=123) # reproducible results
 
# # Combine minority class with downsampled majority class
# df_downsampled = pd.concat([df_majority_downsampled, df_minority])

# %% [markdown]
# ### Selected features

# %%
# micro1_selected = micro1[["Transparency","FLength","FWidth","FThickness","W/L Ratio", "L/W Ratio", 'Sphericity', 'Circularity', 'Convexity',"type_micro"]]

# %% [markdown]
# ### Hold-out data

# %%
# from sklearn.model_selection import train_test_split
# import numpy as np

# # X is your feature data
# # y is your target data
# X_train, X_holdout, y_train, y_holdout = train_test_split(X, y, test_size=0.1, stratify=y, random_state=42)

# # Now you can perform the train-test split on X_train and y_train
# X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.1, stratify=y_train, random_state=42)

# %% [markdown]
# ## Models

# %% [markdown]
# ### Lazy predict

# %%
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# %%
class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|███████████████████████████████████████████| 29/29 [00:21<00:00,  1.37it/s]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.99               0.99    None      0.99
# AdaBoostClassifier                 0.99               0.99    None      0.99
# RandomForestClassifier             0.99               0.99    None      0.99
# ExtraTreesClassifier               0.99               0.99    None      0.99
# BaggingClassifier                  0.99               0.99    None      0.99
# SVC                                0.99               0.99    None      0.99
# KNeighborsClassifier               0.98               0.98    None      0.98
# DecisionTreeClassifier             0.98               0.98    None      0.98
# LabelPropagation                   0.98               0.98    None      0.98
# LabelSpreading                     0.98               0.98    None      0.98
# LogisticRegression                 0.97               0.97    None      0.97
# CalibratedClassifierCV             0.97               0.97    None      0.97
# LinearSVC                          0.97               0.97    None      0.97
# SGDClassifier                      0.97               0.97    None      0.97
# ExtraTreeClassifier                0.97               0.97    None      0.97
# RidgeClassifier                    0.96               0.96    None      0.96
# RidgeClassifierCV                  0.96               0.96    None      0.96
# LinearDiscriminantAnalysis         0.96               0.96    None      0.96
# Perceptron                         0.94               0.94    None      0.94
# PassiveAggressiveClassifier        0.94               0.94    None      0.94
# GaussianNB                         0.92               0.92    None      0.92
# NuSVC                              0.91               0.91    None      0.91
# QuadraticDiscriminantAnalysis      0.90               0.90    None      0.90
# NearestCentroid                    0.90               0.90    None      0.90
# BernoulliNB                        0.85               0.85    None      0.85
# DummyClassifier                    0.50               0.50    None      0.34
#
#                                Time Taken
# Model
# LGBMClassifier                       0.24
# AdaBoostClassifier                   1.59
# RandomForestClassifier               1.76
# ExtraTreesClassifier                 0.53
# BaggingClassifier                    0.97
# SVC                                  0.80
# KNeighborsClassifier                 0.51
# DecisionTreeClassifier               0.19
# LabelPropagation                     2.60
# LabelSpreading                       3.63
# LogisticRegression                   0.16
# CalibratedClassifierCV               1.40
# LinearSVC                            0.34
# SGDClassifier                        0.09
# ExtraTreeClassifier                  0.05
# RidgeClassifier                      0.08
# RidgeClassifierCV                    0.10
# LinearDiscriminantAnalysis           0.11
# Perceptron                           0.07
# PassiveAggressiveClassifier          0.07
# GaussianNB                           0.05
# NuSVC                                5.55
# QuadraticDiscriminantAnalysis        0.10
# NearestCentroid                      0.06
# BernoulliNB                          0.07
# DummyClassifier                      0.04

# %% [markdown]
# ### LightBGM

# %% [markdown]
# #### train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

lgbm = LGBMClassifier(random_state=random_seed)
lgbm.fit(X_train_transformed, y_train_transformed)
print('Accuracy of LGBM classifier on training set: {:.4f}'.format(lgbm.score(X_train_transformed, y_train_transformed)))
print('Accuracy of LGBM classifier on test set: {:.4f}'.format(lgbm.score(X_test_transformed, y_test_transformed)))

pred = lgbm.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, lgbm.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=lgbm.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of LGBM classifier on training set: 1.0000
# Accuracy of LGBM classifier on test set: 0.9948
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1049
#            1       0.99      1.00      0.99      1060
#
#     accuracy                           0.99      2109
#    macro avg       0.99      0.99      0.99      2109
# weighted avg       0.99      0.99      0.99      2109

# %%
acc_train1_LBGM = lgbm.score(X_train_transformed, y_train_transformed)
acc_test1_LBGM = lgbm.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Cross validation for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'num_leaves': [31, 63, 127],
              'learning_rate': [0.1, 0.01, 0.001],
              'n_estimators': [100, 500, 1000]
             }

# %%
grid_search = GridSearchCV(lgbm, param_grid, cv=5)
grid_search.fit(X_train_transformed, y_train_transformed)
# Out:
# GridSearchCV(cv=5, estimator=LGBMClassifier(random_state=42),
#              param_grid={'learning_rate': [0.1, 0.01, 0.001],
#                          'n_estimators': [100, 500, 1000],
#                          'num_leaves': [31, 63, 127]})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'learning_rate': 0.1, 'n_estimators': 1000, 'num_leaves': 31}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 6           0.60          0.01             0.02            0.00
# 3           0.51          0.04             0.01            0.00
# 5           0.92          0.06             0.01            0.00
#
#   param_learning_rate param_n_estimators param_num_leaves  \
# 6                 0.1               1000               31
# 3                 0.1                500               31
# 5                 0.1                500              127
#
#                                               params  split0_test_score  \
# 6  {'learning_rate': 0.1, 'n_estimators': 1000, '...               1.00
# 3  {'learning_rate': 0.1, 'n_estimators': 500, 'n...               0.99
# 5  {'learning_rate': 0.1, 'n_estimators': 500, 'n...               0.99
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 6               1.00               0.99               0.99               0.99
# 3               1.00               0.99               0.99               0.99
# 5               1.00               0.99               0.99               0.99
#
#    mean_test_score  std_test_score  rank_test_score
# 6             0.99            0.00                1
# 3             0.99            0.00                2
# 5             0.99            0.00                3

# %%
# grid_search.predict(x_test)

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of LBGM classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of LBGM classifier on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of LBGM classifier on training set: 1.0000
# Accuracy of LBGM classifier on test set: 0.9957
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      1049
#            1       0.99      1.00      1.00      1060
#
#     accuracy                           1.00      2109
#    macro avg       1.00      1.00      1.00      2109
# weighted avg       1.00      1.00      1.00      2109

# %%
acc_train2_LBGM = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_LBGM = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
importances = lgbm.feature_importances_

# Sort the feature importances in descending order
indices = np.argsort(importances)[::-1]
feature_names = data_resampled.columns[1:]
names = [feature_names[i] for i in indices]

importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# Sort the dataframe by importance
importance_df.sort_values(by='importance', ascending=False, inplace=True)

# Print the top 10 features
print(importance_df.head(10))

fi_LGBM = importance_df
# Out:
#           feature_name  importance
# 33         Ellipticity         455
# 22              Extent         336
# 24           Curvature         276
# 0                   Dp         130
# 30  CHull Surface Area         126
# 25        Surface Area         100
# 4              ELength          98
# 35         Fiber Width          90
# 13           L/T Ratio          88
# 3           FThickness          88

# %%
# Create plot
plt.figure()

# Create plot title
plt.title("Feature Importance")

# Add bars
plt.bar(range(X_train.shape[1]), importances[indices])

# Add feature names as x-axis labels
plt.xticks(range(X_train.shape[1]), names, rotation=90)

# Show plot
plt.show()

# %% [markdown]
# ### AdaBoost (Adaptive Boosting)

# %% [markdown]
# #### Train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

ada = AdaBoostClassifier(random_state=random_seed)
ada.fit(X_train_transformed, y_train_transformed)
print('Accuracy of LGBM classifier on training set: {:.4f}'.format(ada.score(X_train_transformed, y_train_transformed)))
print('Accuracy of LGBM classifier on test set: {:.4f}'.format(ada.score(X_test_transformed, y_test_transformed)))

pred = ada.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, ada.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=ada.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of LGBM classifier on training set: 0.9937
# Accuracy of LGBM classifier on test set: 0.9934
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1049
#            1       0.99      1.00      0.99      1060
#
#     accuracy                           0.99      2109
#    macro avg       0.99      0.99      0.99      2109
# weighted avg       0.99      0.99      0.99      2109

# %%
acc_train1_ada = ada.score(X_train_transformed, y_train_transformed)
acc_test1_ada = ada.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Cross validation for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_estimators': [50, 100, 150],
              'learning_rate': [0.1, 0.5, 1.0],
              'algorithm': ['SAMME', 'SAMME.R']}

# %%
grid_search = GridSearchCV(ada, param_grid, cv=5)
grid_search.fit(X_train_transformed, y_train_transformed)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(random_state=42),
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.1, 0.5, 1.0],
#                          'n_estimators': [50, 100, 150]})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'algorithm': 'SAMME.R', 'learning_rate': 1.0, 'n_estimators': 150}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 17           2.70          0.17             0.05            0.00
# 16           1.72          0.00             0.03            0.00
# 14           2.60          0.04             0.04            0.00
#
#    param_algorithm param_learning_rate param_n_estimators  \
# 17         SAMME.R                 1.0                150
# 16         SAMME.R                 1.0                100
# 14         SAMME.R                 0.5                150
#
#                                                params  split0_test_score  \
# 17  {'algorithm': 'SAMME.R', 'learning_rate': 1.0,...               0.99
# 16  {'algorithm': 'SAMME.R', 'learning_rate': 1.0,...               0.99
# 14  {'algorithm': 'SAMME.R', 'learning_rate': 0.5,...               0.99
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 17               1.00               0.99               0.99
# 16               1.00               0.99               0.99
# 14               1.00               0.99               0.99
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 17               0.99             0.99            0.00                1
# 16               0.99             0.99            0.00                2
# 14               0.99             0.99            0.00                3

# %%
# grid_search.predict(x_test)

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of AdaBoost classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of AdaBoost classifier on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of AdaBoost classifier on training set: 0.9995
# Accuracy of AdaBoost classifier on test set: 0.9957
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      1049
#            1       0.99      1.00      1.00      1060
#
#     accuracy                           1.00      2109
#    macro avg       1.00      1.00      1.00      2109
# weighted avg       1.00      1.00      1.00      2109

# %%
acc_train2_ada = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_ada = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
importances = lgbm.feature_importances_

# Sort the feature importances in descending order
indices = np.argsort(importances)[::-1]
feature_names = data_resampled.columns[1:]
names = [feature_names[i] for i in indices]

importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# Sort the dataframe by importance
importance_df.sort_values(by='importance', ascending=False, inplace=True)

# Print the top 10 features
print(importance_df.head(10))

fi_ada = importance_df
# Out:
#           feature_name  importance
# 33         Ellipticity         455
# 22              Extent         336
# 24           Curvature         276
# 0                   Dp         130
# 30  CHull Surface Area         126
# 25        Surface Area         100
# 4              ELength          98
# 35         Fiber Width          90
# 13           L/T Ratio          88
# 3           FThickness          88

# %%
# Create plot
plt.figure()

# Create plot title
plt.title("Feature Importance")

# Add bars
plt.bar(range(X_train.shape[1]), importances[indices])

# Add feature names as x-axis labels
plt.xticks(range(X_train.shape[1]), names, rotation=90)

# Show plot
plt.show()

# %% [markdown]
# ### Extra tree

# %% [markdown]
# #### Train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

X_holdout = X_test
y_holdout = y_test

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

etree = ExtraTreesClassifier(random_state=random_seed)
etree.fit(X_train_transformed, y_train_transformed)
print('Accuracy of Extra Trees classifier on training set: {:.4f}'.format(etree.score(X_train_transformed, y_train_transformed)))
print('Accuracy of Extra Trees classifier on test set: {:.4f}'.format(etree.score(X_test_transformed, y_test_transformed)))

pred = etree.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, etree.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=etree.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of Extra Trees classifier on training set: 1.0000
# Accuracy of Extra Trees classifier on test set: 0.9915
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1049
#            1       0.99      0.99      0.99      1060
#
#     accuracy                           0.99      2109
#    macro avg       0.99      0.99      0.99      2109
# weighted avg       0.99      0.99      0.99      2109

# %%
acc_train1_etree = etree.score(X_train_transformed, y_train_transformed)
acc_test1_etree = etree.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Cross validation for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_estimators': [10, 50, 100, 150],
              'max_depth': [None, 5, 10, 20],
              'min_samples_split': [2, 5, 10]}

# %%
grid_search = GridSearchCV(etree, param_grid, cv=5)
grid_search.fit(X_test_transformed, y_test_transformed)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesClassifier(random_state=42),
#              param_grid={'max_depth': [None, 5, 10, 20],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 50, 100, 150]})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 100}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 34           0.12          0.00             0.01            0.00
# 1            0.08          0.00             0.01            0.00
# 37           0.07          0.00             0.01            0.00
#
#    param_max_depth param_min_samples_split param_n_estimators  \
# 34              10                      10                100
# 1             None                       2                 50
# 37              20                       2                 50
#
#                                                params  split0_test_score  \
# 34  {'max_depth': 10, 'min_samples_split': 10, 'n_...               0.98
# 1   {'max_depth': None, 'min_samples_split': 2, 'n...               0.98
# 37  {'max_depth': 20, 'min_samples_split': 2, 'n_e...               0.98
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 34               0.98               0.99               0.98
# 1                0.98               0.98               0.99
# 37               0.98               0.98               0.99
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 34               0.99             0.98            0.00                1
# 1                0.99             0.98            0.00                2
# 37               0.99             0.98            0.00                2

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of Extra Trees classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of Extra Trees classifier on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of Extra Trees classifier on training set: 0.9782
# Accuracy of Extra Trees classifier on test set: 0.9938
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1049
#            1       0.99      1.00      0.99      1060
#
#     accuracy                           0.99      2109
#    macro avg       0.99      0.99      0.99      2109
# weighted avg       0.99      0.99      0.99      2109

# %%
acc_train2_etree = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_etree = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
importances = etree.feature_importances_

# Sort the feature importances in descending order
indices = np.argsort(importances)[::-1]
feature_names = data_resampled.columns[1:]
names = [feature_names[i] for i in indices]

importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# Sort the dataframe by importance
importance_df.sort_values(by='importance', ascending=False, inplace=True)

# Print the top 10 features
print(importance_df.head(10))

fi_etree = importance_df
# Out:
#           feature_name  importance
# 30  CHull Surface Area        0.11
# 33         Ellipticity        0.10
# 24           Curvature        0.07
# 28           W/T Ratio        0.06
# 29           T/W Ratio        0.06
# 2              FLength        0.04
# 19            Solidity        0.04
# 1               FWidth        0.03
# 32          Angularity        0.03
# 4              ELength        0.03

# %%
# Create plot
plt.figure()

# Create plot title
plt.title("Feature Importance")

# Add bars
plt.bar(range(X_train.shape[1]), importances[indices])

# Add feature names as x-axis labels
plt.xticks(range(X_train.shape[1]), names, rotation=90)

# Show plot
plt.show()

# %% [markdown]
# ### Random forest

# %% [markdown]
# #### Train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

X_holdout = X_test
y_holdout = y_test

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

rf = RandomForestClassifier(random_state=random_seed)
rf.fit(X_train_transformed, y_train_transformed)
print('Accuracy of RF classifier on training set: {:.4f}'.format(rf.score(X_train_transformed, y_train_transformed)))
print('Accuracy of RF classifier on test set: {:.4f}'.format(rf.score(X_test_transformed, y_test_transformed)))

pred = rf.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, rf.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=rf.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of RF classifier on training set: 1.0000
# Accuracy of RF classifier on test set: 0.9919
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1049
#            1       0.99      0.99      0.99      1060
#
#     accuracy                           0.99      2109
#    macro avg       0.99      0.99      0.99      2109
# weighted avg       0.99      0.99      0.99      2109

# %%
acc_train1_rf = rf.score(X_train_transformed, y_train_transformed)
acc_test1_rf = rf.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Cross validation for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_estimators': [10, 50, 100],
              'max_depth': [None, 5, 10],
              'min_samples_split': [2, 5, 10]}
#               'min_samples_leaf': [1, 2, 4],
#               'max_features': ['auto', 'sqrt', 'log2'],
#               'max_leaf_nodes': [10, 20, 30],
#               'class_weight':[None, 'balanced'],
#               'criterion': ['gini', 'entropy']}

# %%
grid_search = GridSearchCV(rf, param_grid, cv=5)
grid_search.fit(X_test_transformed, y_test_transformed)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'max_depth': [None, 5, 10],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 50, 100]})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 2            0.33          0.01             0.01            0.00
# 5            0.37          0.01             0.01            0.00
# 23           0.33          0.01             0.01            0.00
#
#    param_max_depth param_min_samples_split param_n_estimators  \
# 2             None                       2                100
# 5             None                       5                100
# 23              10                       5                100
#
#                                                params  split0_test_score  \
# 2   {'max_depth': None, 'min_samples_split': 2, 'n...               0.97
# 5   {'max_depth': None, 'min_samples_split': 5, 'n...               0.98
# 23  {'max_depth': 10, 'min_samples_split': 5, 'n_e...               0.98
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 2                0.98               0.98               0.98
# 5                0.98               0.98               0.98
# 23               0.98               0.98               0.98
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 2                0.99             0.98            0.00                1
# 5                0.99             0.98            0.00                1
# 23               0.99             0.98            0.00                1

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of Random Forest classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of Random Forest classifier on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of Random Forest classifier on training set: 0.9814
# Accuracy of Random Forest classifier on test set: 1.0000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1049
#            1       1.00      1.00      1.00      1060
#
#     accuracy                           1.00      2109
#    macro avg       1.00      1.00      1.00      2109
# weighted avg       1.00      1.00      1.00      2109

# %%
acc_train2_rf = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_rf = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
importances = rf.feature_importances_

# Sort the feature importances in descending order
indices = np.argsort(importances)[::-1]
feature_names = data_resampled.columns[1:]
names = [feature_names[i] for i in indices]

importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# Sort the dataframe by importance
importance_df.sort_values(by='importance', ascending=False, inplace=True)

# Print the top 10 features
print(importance_df.head(10))

fi_rf = importance_df
# Out:
#           feature_name  importance
# 30  CHull Surface Area        0.15
# 29           T/W Ratio        0.12
# 2              FLength        0.10
# 7               Volume        0.10
# 33         Ellipticity        0.08
# 32          Angularity        0.07
# 6               EWidth        0.06
# 4              ELength        0.04
# 9            Perimeter        0.03
# 0                   Dp        0.02

# %%
# Create plot
plt.figure()

# Create plot title
plt.title("Feature Importance")

# Add bars
plt.bar(range(X_train.shape[1]), importances[indices])

# Add feature names as x-axis labels
plt.xticks(range(X_train.shape[1]), names, rotation=90)

# Show plot
plt.show()

# %% [markdown]
# ### Bagging (Bootstrapped Aggregation)

# %% [markdown]
# #### Train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

base_estimator = DecisionTreeClassifier(max_depth=4, random_state=random_seed)
bagging = BaggingClassifier(base_estimator=base_estimator, random_state=random_seed)
bagging.fit(X_train_transformed, y_train_transformed)
print('Accuracy of LGBM classifier on training set: {:.4f}'.format(bagging.score(X_train_transformed, y_train_transformed)))
print('Accuracy of LGBM classifier on test set: {:.4f}'.format(bagging.score(X_test_transformed, y_test_transformed)))

pred = bagging.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, bagging.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=bagging.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of LGBM classifier on training set: 0.9772
# Accuracy of LGBM classifier on test set: 0.9720
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      1049
#            1       0.96      0.98      0.97      1060
#
#     accuracy                           0.97      2109
#    macro avg       0.97      0.97      0.97      2109
# weighted avg       0.97      0.97      0.97      2109

# %%
acc_train1_bagging = bagging.score(X_train_transformed, y_train_transformed)
acc_test1_bagging = bagging.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Cross validation for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_estimators': [50, 100, 150],
              'max_samples': [0.5, 1.0, 2.0],
              'max_features': [0.5, 1.0, 2.0]}

# %%
grid_search = GridSearchCV(bagging, param_grid, cv=5)
grid_search.fit(X_train_transformed, y_train_transformed)
# Out:
# GridSearchCV(cv=5,
#              estimator=BaggingClassifier(base_estimator=DecisionTreeClassifier(max_depth=4,
#                                                                                random_state=42),
#                                          random_state=42),
#              param_grid={'max_features': [0.5, 1.0, 2.0],
#                          'max_samples': [0.5, 1.0, 2.0],
#                          'n_estimators': [50, 100, 150]})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 50}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 9            1.32          0.07             0.01            0.00
# 10           2.67          0.13             0.03            0.00
# 11           4.16          0.25             0.05            0.00
#
#    param_max_features param_max_samples param_n_estimators  \
# 9                 1.0               0.5                 50
# 10                1.0               0.5                100
# 11                1.0               0.5                150
#
#                                                params  split0_test_score  \
# 9   {'max_features': 1.0, 'max_samples': 0.5, 'n_e...               0.97
# 10  {'max_features': 1.0, 'max_samples': 0.5, 'n_e...               0.97
# 11  {'max_features': 1.0, 'max_samples': 0.5, 'n_e...               0.97
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 9                0.98               0.97               0.98
# 10               0.98               0.97               0.98
# 11               0.98               0.97               0.98
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 9                0.98             0.98            0.00                1
# 10               0.98             0.98            0.01                2
# 11               0.98             0.98            0.01                3

# %%
# grid_search.predict(x_test)

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of Bagging classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of Bagging classifie on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of Bagging classifier on training set: 0.9774
# Accuracy of Bagging classifie on test set: 0.9744
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      1049
#            1       0.97      0.98      0.97      1060
#
#     accuracy                           0.97      2109
#    macro avg       0.97      0.97      0.97      2109
# weighted avg       0.97      0.97      0.97      2109

# %%
acc_train2_bagging = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_bagging = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
# importances = lgbm.feature_importances_

# # Sort the feature importances in descending order
# indices = np.argsort(importances)[::-1]
# feature_names = data_resampled.columns[1:]
# names = [feature_names[i] for i in indices]

# importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# # Sort the dataframe by importance
# importance_df.sort_values(by='importance', ascending=False, inplace=True)

# # Print the top 10 features
# print(importance_df.head(10))

# fi_bagging = importance_df

# %%
# # Create plot
# plt.figure()

# # Create plot title
# plt.title("Feature Importance")

# # Add bars
# plt.bar(range(X_train.shape[1]), importances[indices])

# # Add feature names as x-axis labels
# plt.xticks(range(X_train.shape[1]), names, rotation=90)

# # Show plot
# plt.show()

# %% [markdown]
# ### SVC (Support Vector Classification)

# %% [markdown]
# #### Train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

svc = SVC(random_state=random_seed)
svc.fit(X_train_transformed, y_train_transformed)
print('Accuracy of LR classifier on training set: {:.4f}'.format(svc.score(X_train_transformed, y_train_transformed)))
print('Accuracy of LR classifier on test set: {:.4f}'.format(svc.score(X_test_transformed, y_test_transformed)))

pred = svc.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, svc.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svc.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of LR classifier on training set: 0.9867
# Accuracy of LR classifier on test set: 0.9872
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1049
#            1       0.99      0.98      0.99      1060
#
#     accuracy                           0.99      2109
#    macro avg       0.99      0.99      0.99      2109
# weighted avg       0.99      0.99      0.99      2109

# %%
acc_train1_svc = svc.score(X_train_transformed, y_train_transformed)
acc_test1_svc = svc.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Cross validation for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C': [0.1, 1, 10],
              'kernel': ['linear', 'rbf', 'poly'],
              'gamma': [0.01, 0.1, 1]}

# %%
grid_search = GridSearchCV(svc, param_grid, cv=5)
grid_search.fit(X_test_transformed, y_test_transformed)
# Out:
# GridSearchCV(cv=5, estimator=SVC(random_state=42),
#              param_grid={'C': [0.1, 1, 10], 'gamma': [0.01, 0.1, 1],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 22           0.03          0.00             0.02            0.00      10
# 19           0.02          0.00             0.01            0.00      10
# 23           0.03          0.00             0.00            0.00      10
#
#    param_gamma param_kernel                                     params  \
# 22         0.1          rbf   {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 19        0.01          rbf  {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 23         0.1         poly  {'C': 10, 'gamma': 0.1, 'kernel': 'poly'}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 22               0.98               0.99               0.97
# 19               0.98               0.99               0.98
# 23               0.98               0.97               0.98
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 22               0.98               0.98             0.98            0.00
# 19               0.98               0.98             0.98            0.00
# 23               0.99               0.98             0.98            0.01
#
#     rank_test_score
# 22                1
# 19                2
# 23                3

# %%
# grid_search.predict(x_test)

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of SV classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of SV classifie on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of SV classifier on training set: 0.9836
# Accuracy of SV classifie on test set: 0.9991
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1049
#            1       1.00      1.00      1.00      1060
#
#     accuracy                           1.00      2109
#    macro avg       1.00      1.00      1.00      2109
# weighted avg       1.00      1.00      1.00      2109

# %%
acc_train2_svc = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_svc = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
# importances = lgbm.feature_importances_

# # Sort the feature importances in descending order
# indices = np.argsort(importances)[::-1]
# feature_names = data_resampled.columns[1:]
# names = [feature_names[i] for i in indices]

# importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# # Sort the dataframe by importance
# importance_df.sort_values(by='importance', ascending=False, inplace=True)

# # Print the top 10 features
# print(importance_df.head(10))

# fi_svc = importance_df

# %%
# # Create plot
# plt.figure()

# # Create plot title
# plt.title("Feature Importance")

# # Add bars
# plt.bar(range(X_train.shape[1]), importances[indices])

# # Add feature names as x-axis labels
# plt.xticks(range(X_train.shape[1]), names, rotation=90)

# # Show plot
# plt.show()

# %%
### XGBoost

# %%
### Gradient Boosting

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ### Model accuracies

# %%
df = {'model': ['LightGBM', 'AdaBoost', 'Random Forest', 'Bagging', 'Extra Trees', 'SVC'], 
            'train_accuracy': [acc_train1_LBGM, acc_train1_ada, acc_train1_rf, acc_train1_bagging, acc_train1_etree, acc_train1_svc], 
            'test_accuracy': [acc_test1_LBGM, acc_test1_ada, acc_test1_rf, acc_test1_bagging, acc_test1_etree, acc_test1_svc],
            'train_accuracy_CV': [acc_train2_LBGM, acc_train2_ada, acc_train2_rf, acc_train2_bagging, acc_train2_etree, acc_train2_svc], 
            'test_accuracy_CV': [acc_test2_LBGM, acc_test2_ada, acc_test2_rf, acc_test2_bagging, acc_test1_etree, acc_test2_svc]}

accuracy = pd.DataFrame(df)

# %%
df = pd.DataFrame(df)
df
# Out:
#            model  train_accuracy  test_accuracy  train_accuracy_CV  \
# 0       LightGBM            1.00           0.99               1.00
# 1       AdaBoost            0.99           0.99               1.00
# 2  Random Forest            1.00           0.99               0.98
# 3        Bagging            0.98           0.97               0.98
# 4    Extra Trees            1.00           0.99               0.98
# 5            SVC            0.99           0.99               0.98
#
#    test_accuracy_CV
# 0              1.00
# 1              1.00
# 2              1.00
# 3              0.97
# 4              0.99
# 5              1.00

# %%
bar_width = 0.35

models = np.arange(len(df['model']))

plt.bar(models - bar_width/2, df['test_accuracy'], bar_width, 
        color='#FF8F45', label='test accuracy', alpha=0.9)
plt.bar(models + bar_width/2, df['test_accuracy_CV'], bar_width, 
        color='#7CF3A0', label='test accuracy after CV', alpha=0.9)

# for i, v in enumerate(df['test_accuracy']):
#     plt.text(i - bar_width/2, v + 0.01, format(v, '.4f'), ha='center', va='bottom')

# for i, v in enumerate(df['test_accuracy_CV']):
#     plt.text(i + bar_width/2, v + 0.01, format(v, '.4f'), ha='center', va='bottom')

plt.xticks(models, df['model'])
plt.ylim(0.97, 1)
plt.legend()
plt.show()

# %%
df.to_csv("accuracy_2_4mm_smotetomek.csv")

# %% [markdown]
# ### Overall feature importance

# %%
fi_LGBM['importance'] = fi_LGBM['importance'] / fi_LGBM['importance'].sum()
fi_LGBM['rank'] = range(1, fi_LGBM.shape[0]+1)
fi_LGBM = fi_LGBM[['feature_name','importance']]
fi_LGBM = fi_LGBM.reset_index(drop=True)

fi_ada['importance'] = fi_ada['importance'] / fi_ada['importance'].sum()
fi_ada['rank'] = range(1, fi_ada.shape[0]+1)
fi_ada = fi_ada[['feature_name','importance']]
fi_ada = fi_ada.reset_index(drop=True)

fi_rf['rank'] = range(1, fi_rf.shape[0]+1)
fi_rf = fi_rf[['feature_name','importance']]
fi_rf = fi_rf.reset_index(drop=True)

fi_etree['rank'] = range(1, fi_etree.shape[0]+1)
fi_etree = fi_etree[['feature_name','importance']]
fi_etree = fi_etree.reset_index(drop=True)

fi = pd.concat([fi_LGBM, fi_ada, fi_rf, fi_etree])

mean_rank = fi.groupby('feature_name').mean()
mean_rank.sort_values(by='importance', ascending=False, inplace=True)

mean_rank.head(10)
# Out:
#                     importance
# feature_name
# Ellipticity               0.12
# CHull Surface Area        0.09
# Curvature                 0.07
# Extent                    0.06
# T/W Ratio                 0.06
# FLength                   0.05
# Volume                    0.04
# Dp                        0.04
# ELength                   0.03
# Angularity                0.03

# %%
import matplotlib.pyplot as plt

mean_rank.reset_index(inplace=True)
mean_rank.head(15).plot(kind='bar', x='feature_name', y='importance')
plt.xlabel('Feature name')
plt.ylabel('Feature importance')
plt.title('Overall feature importance')
plt.show()

# %%
mean_rank[['feature_name','importance']]
