# %% [markdown]
# ## load package

# %%
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.utils import resample

# %%
import lazypredict

# %% [markdown]
# ## import data

# %%
# !pwd
# Out:
# /Users/ricky/Desktop/sp23-ancient-artifacts-team8/3_ml

# %%
master_micro = pd.read_csv("../0_data/master.csv")

# %%
master_micro
# Out:
#         Unnamed: 0   Id  Img Id      Da      Dp  FWidth  FLength  FThickness  \
# 0                0  104   10708  30.893  38.251  36.878   46.822      10.179
# 1                1   19    5682  27.727  33.375  35.149   40.001       9.029
# 2                2   14    4826  26.726  36.061  30.199   46.332       8.025
# 3                3    1    2812  24.408  36.198  25.039   57.353       5.086
# 4                4   83    9441  22.869  29.388  24.044   39.820       4.390
# ...            ...  ...     ...     ...     ...     ...      ...         ...
# 483648         600  591   13305   0.146   0.155   0.129    0.168       0.129
# 483649         601  464   10826   0.137   0.141   0.128    0.155       0.128
# 483650         602  236    8388   0.144   0.149   0.128    0.163       0.128
# 483651         603  369    9727   0.148   0.154   0.126    0.179       0.126
# 483652         604  481   11134   0.142   0.154   0.126    0.186       0.126
#
#         ELength  EThickness  ...  T/W Ratio  CHull Surface Area   Sieve  \
# 0        44.168      10.102  ...      0.276            3211.655  23.529
# 1        39.022       7.978  ...      0.257            2547.278  22.089
# 2        47.365       7.753  ...      0.266            2571.497  19.112
# 3        50.536       4.904  ...      0.203            2001.165  15.063
# 4        38.568       3.948  ...      0.183            1745.237  14.217
# ...         ...         ...  ...        ...                 ...     ...
# 483648    0.166       0.131  ...      1.000               0.069   0.129
# 483649    0.147       0.127  ...      1.000               0.060   0.128
# 483650    0.156       0.132  ...      1.000               0.065   0.128
# 483651    0.174       0.126  ...      1.000               0.069   0.126
# 483652    0.173       0.119  ...      1.000               0.065   0.126
#
#         Angularity  Ellipticity  Fiber Length  Fiber Width  Krumbein Rnd  \
# 0           19.392        4.372        49.768       22.823         0.214
# 1           20.688        4.891        37.445        5.128         0.214
# 2           21.250        6.110        52.384       17.379         0.219
# 3           18.233       10.304        51.467       17.096         0.251
# 4           17.086        9.769        36.426        3.135         0.276
# ...            ...          ...           ...          ...           ...
# 483648      55.000        1.271         0.000        0.000           NaN
# 483649      63.750        1.164         0.000        0.000           NaN
# 483650      56.667        1.180         0.000        0.000           NaN
# 483651      56.667        1.383         0.000        0.000           NaN
# 483652      55.714        1.450         0.000        0.000           NaN
#
#         size_micro  type_micro
# 0          unknown      lithic
# 1          unknown      lithic
# 2          unknown      lithic
# 3          unknown      lithic
# 4          unknown      lithic
# ...            ...         ...
# 483648         4mm        soil
# 483649         4mm        soil
# 483650         4mm        soil
# 483651         4mm        soil
# 483652         4mm        soil
#
# [483653 rows x 51 columns]

# %%
micro = master_micro[(master_micro['size_micro']!="unknown") | (master_micro['type_micro']=="lithic")].iloc[: , 3:]

# %%
pd.set_option('display.max_columns', None)
micro
# Out:
#             Da      Dp  FWidth  FLength  FThickness  ELength  EThickness  \
# 0       30.893  38.251  36.878   46.822      10.179   44.168      10.102
# 1       27.727  33.375  35.149   40.001       9.029   39.022       7.978
# 2       26.726  36.061  30.199   46.332       8.025   47.365       7.753
# 3       24.408  36.198  25.039   57.353       5.086   50.536       4.904
# 4       22.869  29.388  24.044   39.820       4.390   38.568       3.948
# ...        ...     ...     ...      ...         ...      ...         ...
# 483648   0.146   0.155   0.129    0.168       0.129    0.166       0.131
# 483649   0.137   0.141   0.128    0.155       0.128    0.147       0.127
# 483650   0.144   0.149   0.128    0.163       0.128    0.156       0.132
# 483651   0.148   0.154   0.126    0.179       0.126    0.174       0.126
# 483652   0.142   0.154   0.126    0.186       0.126    0.173       0.119
#
#         EWidth    Volume     Area  Perimeter  CHull  Area  CHull Perimeter  \
# 0       34.444  9202.973  749.562    120.170      802.914          108.399
# 1       34.108  6646.859  603.785    104.849      636.820           99.590
# 2       28.230  5879.233  560.995    113.290      642.874          100.583
# 3       23.943  3824.409  467.900    113.719      500.291          108.846
# 4       22.535  2200.862  410.744     92.327      436.309           89.254
# ...        ...       ...      ...        ...          ...              ...
# 483648   0.131     0.001    0.017      0.486        0.017            0.484
# 483649   0.127     0.001    0.015      0.443        0.015            0.442
# 483650   0.132     0.001    0.016      0.469        0.016            0.468
# 483651   0.126     0.001    0.017      0.485        0.017            0.485
# 483652   0.119     0.002    0.016      0.484        0.016            0.482
#
#         Sphericity  L/T Ratio  T/L Aspect Ratio  Compactness  Roundness  \
# 0            0.808      4.600             0.217        0.660      0.435
# 1            0.831      4.430             0.226        0.693      0.480
# 2            0.741      5.774             0.173        0.577      0.333
# 3            0.674     11.276             0.089        0.426      0.181
# 4            0.778      9.070             0.110        0.574      0.330
# ...            ...        ...               ...          ...        ...
# 483648       0.945      1.297             0.771        0.871      0.759
# 483649       0.970      1.208             0.828        0.886      0.784
# 483650       0.965      1.274             0.785        0.885      0.783
# 483651       0.962      1.415             0.707        0.829      0.688
# 483652       0.920      1.475             0.678        0.760      0.578
#
#         Ellipse Ratio  Circularity  Solidity  Concavity  Convexity  Extent  \
# 0               0.229        0.652     0.934      0.066      0.902   1.573
# 1               0.204        0.690     0.948      0.052      0.950   1.672
# 2               0.164        0.549     0.873      0.127      0.888   1.509
# 3               0.097        0.455     0.935      0.065      0.957   1.604
# 4               0.102        0.606     0.941      0.059      0.967   2.350
# ...               ...          ...       ...        ...        ...     ...
# 483648          0.787        0.893     0.976      0.024      0.996   0.773
# 483649          0.859        0.942     0.989      0.011      0.996   0.744
# 483650          0.847        0.931     0.995      0.005      1.000   0.783
# 483651          0.723        0.926     1.000      0.000      1.000   0.764
# 483652          0.690        0.847     0.974      0.026      0.996   0.670
#
#         hash  Transparency  Curvature  Surface Area Filter0 Filter1 Filter2  \
# 0          0         0.081        0.0      2998.247  Reject  Reject  Reject
# 1          0         0.126        0.0      2415.141  Reject  Reject  Reject
# 2          0         0.096        0.0      2243.981  Reject  Reject  Reject
# 3          0         0.088        0.0      1871.602  Reject  Reject  Reject
# 4          0         0.077        0.0      1642.977  Reject  Reject  Reject
# ...      ...           ...        ...           ...     ...     ...     ...
# 483648     0         0.333        0.0         0.067  Reject  Reject  Reject
# 483649     0         0.350        0.0         0.059  Reject  Reject  Reject
# 483650     0         0.442        0.0         0.065  Reject  Reject  Reject
# 483651     0         0.276        0.0         0.069  Reject  Reject  Reject
# 483652     0         0.278        0.0         0.063  Reject  Reject  Reject
#
#        Filter3 Filter4 Filter5 Filter6  L/W Ratio  W/L Ratio  W/T Ratio  \
# 0       Reject  Reject  Reject  Reject      1.270      0.788      3.623
# 1       Reject  Reject  Reject  Reject      1.138      0.879      3.893
# 2       Reject  Reject  Reject  Reject      1.534      0.652      3.763
# 3       Reject  Reject  Reject  Reject      2.291      0.437      4.923
# 4       Reject  Reject  Reject  Reject      1.656      0.604      5.477
# ...        ...     ...     ...     ...        ...        ...        ...
# 483648  Reject  Reject  Reject  Reject      1.297      0.771      1.000
# 483649  Reject  Reject  Reject  Reject      1.208      0.828      1.000
# 483650  Reject  Reject  Reject  Reject      1.274      0.785      1.000
# 483651  Reject  Reject  Reject  Reject      1.415      0.707      1.000
# 483652  Reject  Reject  Reject  Reject      1.475      0.678      1.000
#
#         T/W Ratio  CHull Surface Area   Sieve  Angularity  Ellipticity  \
# 0           0.276            3211.655  23.529      19.392        4.372
# 1           0.257            2547.278  22.089      20.688        4.891
# 2           0.266            2571.497  19.112      21.250        6.110
# 3           0.203            2001.165  15.063      18.233       10.304
# 4           0.183            1745.237  14.217      17.086        9.769
# ...           ...                 ...     ...         ...          ...
# 483648      1.000               0.069   0.129      55.000        1.271
# 483649      1.000               0.060   0.128      63.750        1.164
# 483650      1.000               0.065   0.128      56.667        1.180
# 483651      1.000               0.069   0.126      56.667        1.383
# 483652      1.000               0.065   0.126      55.714        1.450
#
#         Fiber Length  Fiber Width  Krumbein Rnd size_micro type_micro
# 0             49.768       22.823         0.214    unknown     lithic
# 1             37.445        5.128         0.214    unknown     lithic
# 2             52.384       17.379         0.219    unknown     lithic
# 3             51.467       17.096         0.251    unknown     lithic
# 4             36.426        3.135         0.276    unknown     lithic
# ...              ...          ...           ...        ...        ...
# 483648         0.000        0.000           NaN        4mm       soil
# 483649         0.000        0.000           NaN        4mm       soil
# 483650         0.000        0.000           NaN        4mm       soil
# 483651         0.000        0.000           NaN        4mm       soil
# 483652         0.000        0.000           NaN        4mm       soil
#
# [410340 rows x 48 columns]

# %% [markdown]
# ## data processing

# %% [markdown]
# ### Other processing

# %%
# Drop the columns (filter1, filter2, ...)
to_drop = micro.filter(regex='^Filter').columns
micro = micro.drop(columns=to_drop)
micro
# Out:
#             Da      Dp  FWidth  FLength  FThickness  ELength  EThickness  \
# 0       30.893  38.251  36.878   46.822      10.179   44.168      10.102
# 1       27.727  33.375  35.149   40.001       9.029   39.022       7.978
# 2       26.726  36.061  30.199   46.332       8.025   47.365       7.753
# 3       24.408  36.198  25.039   57.353       5.086   50.536       4.904
# 4       22.869  29.388  24.044   39.820       4.390   38.568       3.948
# ...        ...     ...     ...      ...         ...      ...         ...
# 483648   0.146   0.155   0.129    0.168       0.129    0.166       0.131
# 483649   0.137   0.141   0.128    0.155       0.128    0.147       0.127
# 483650   0.144   0.149   0.128    0.163       0.128    0.156       0.132
# 483651   0.148   0.154   0.126    0.179       0.126    0.174       0.126
# 483652   0.142   0.154   0.126    0.186       0.126    0.173       0.119
#
#         EWidth    Volume     Area  Perimeter  CHull  Area  CHull Perimeter  \
# 0       34.444  9202.973  749.562    120.170      802.914          108.399
# 1       34.108  6646.859  603.785    104.849      636.820           99.590
# 2       28.230  5879.233  560.995    113.290      642.874          100.583
# 3       23.943  3824.409  467.900    113.719      500.291          108.846
# 4       22.535  2200.862  410.744     92.327      436.309           89.254
# ...        ...       ...      ...        ...          ...              ...
# 483648   0.131     0.001    0.017      0.486        0.017            0.484
# 483649   0.127     0.001    0.015      0.443        0.015            0.442
# 483650   0.132     0.001    0.016      0.469        0.016            0.468
# 483651   0.126     0.001    0.017      0.485        0.017            0.485
# 483652   0.119     0.002    0.016      0.484        0.016            0.482
#
#         Sphericity  L/T Ratio  T/L Aspect Ratio  Compactness  Roundness  \
# 0            0.808      4.600             0.217        0.660      0.435
# 1            0.831      4.430             0.226        0.693      0.480
# 2            0.741      5.774             0.173        0.577      0.333
# 3            0.674     11.276             0.089        0.426      0.181
# 4            0.778      9.070             0.110        0.574      0.330
# ...            ...        ...               ...          ...        ...
# 483648       0.945      1.297             0.771        0.871      0.759
# 483649       0.970      1.208             0.828        0.886      0.784
# 483650       0.965      1.274             0.785        0.885      0.783
# 483651       0.962      1.415             0.707        0.829      0.688
# 483652       0.920      1.475             0.678        0.760      0.578
#
#         Ellipse Ratio  Circularity  Solidity  Concavity  Convexity  Extent  \
# 0               0.229        0.652     0.934      0.066      0.902   1.573
# 1               0.204        0.690     0.948      0.052      0.950   1.672
# 2               0.164        0.549     0.873      0.127      0.888   1.509
# 3               0.097        0.455     0.935      0.065      0.957   1.604
# 4               0.102        0.606     0.941      0.059      0.967   2.350
# ...               ...          ...       ...        ...        ...     ...
# 483648          0.787        0.893     0.976      0.024      0.996   0.773
# 483649          0.859        0.942     0.989      0.011      0.996   0.744
# 483650          0.847        0.931     0.995      0.005      1.000   0.783
# 483651          0.723        0.926     1.000      0.000      1.000   0.764
# 483652          0.690        0.847     0.974      0.026      0.996   0.670
#
#         hash  Transparency  Curvature  Surface Area  L/W Ratio  W/L Ratio  \
# 0          0         0.081        0.0      2998.247      1.270      0.788
# 1          0         0.126        0.0      2415.141      1.138      0.879
# 2          0         0.096        0.0      2243.981      1.534      0.652
# 3          0         0.088        0.0      1871.602      2.291      0.437
# 4          0         0.077        0.0      1642.977      1.656      0.604
# ...      ...           ...        ...           ...        ...        ...
# 483648     0         0.333        0.0         0.067      1.297      0.771
# 483649     0         0.350        0.0         0.059      1.208      0.828
# 483650     0         0.442        0.0         0.065      1.274      0.785
# 483651     0         0.276        0.0         0.069      1.415      0.707
# 483652     0         0.278        0.0         0.063      1.475      0.678
#
#         W/T Ratio  T/W Ratio  CHull Surface Area   Sieve  Angularity  \
# 0           3.623      0.276            3211.655  23.529      19.392
# 1           3.893      0.257            2547.278  22.089      20.688
# 2           3.763      0.266            2571.497  19.112      21.250
# 3           4.923      0.203            2001.165  15.063      18.233
# 4           5.477      0.183            1745.237  14.217      17.086
# ...           ...        ...                 ...     ...         ...
# 483648      1.000      1.000               0.069   0.129      55.000
# 483649      1.000      1.000               0.060   0.128      63.750
# 483650      1.000      1.000               0.065   0.128      56.667
# 483651      1.000      1.000               0.069   0.126      56.667
# 483652      1.000      1.000               0.065   0.126      55.714
#
#         Ellipticity  Fiber Length  Fiber Width  Krumbein Rnd size_micro  \
# 0             4.372        49.768       22.823         0.214    unknown
# 1             4.891        37.445        5.128         0.214    unknown
# 2             6.110        52.384       17.379         0.219    unknown
# 3            10.304        51.467       17.096         0.251    unknown
# 4             9.769        36.426        3.135         0.276    unknown
# ...             ...           ...          ...           ...        ...
# 483648        1.271         0.000        0.000           NaN        4mm
# 483649        1.164         0.000        0.000           NaN        4mm
# 483650        1.180         0.000        0.000           NaN        4mm
# 483651        1.383         0.000        0.000           NaN        4mm
# 483652        1.450         0.000        0.000           NaN        4mm
#
#        type_micro
# 0          lithic
# 1          lithic
# 2          lithic
# 3          lithic
# 4          lithic
# ...           ...
# 483648       soil
# 483649       soil
# 483650       soil
# 483651       soil
# 483652       soil
#
# [410340 rows x 41 columns]

# %%
micro = micro.drop(columns=['hash', 'size_micro', 'Krumbein Rnd']) #'Krumbein Rnd'
micro
# Out:
#             Da      Dp  FWidth  FLength  FThickness  ELength  EThickness  \
# 0       30.893  38.251  36.878   46.822      10.179   44.168      10.102
# 1       27.727  33.375  35.149   40.001       9.029   39.022       7.978
# 2       26.726  36.061  30.199   46.332       8.025   47.365       7.753
# 3       24.408  36.198  25.039   57.353       5.086   50.536       4.904
# 4       22.869  29.388  24.044   39.820       4.390   38.568       3.948
# ...        ...     ...     ...      ...         ...      ...         ...
# 483648   0.146   0.155   0.129    0.168       0.129    0.166       0.131
# 483649   0.137   0.141   0.128    0.155       0.128    0.147       0.127
# 483650   0.144   0.149   0.128    0.163       0.128    0.156       0.132
# 483651   0.148   0.154   0.126    0.179       0.126    0.174       0.126
# 483652   0.142   0.154   0.126    0.186       0.126    0.173       0.119
#
#         EWidth    Volume     Area  Perimeter  CHull  Area  CHull Perimeter  \
# 0       34.444  9202.973  749.562    120.170      802.914          108.399
# 1       34.108  6646.859  603.785    104.849      636.820           99.590
# 2       28.230  5879.233  560.995    113.290      642.874          100.583
# 3       23.943  3824.409  467.900    113.719      500.291          108.846
# 4       22.535  2200.862  410.744     92.327      436.309           89.254
# ...        ...       ...      ...        ...          ...              ...
# 483648   0.131     0.001    0.017      0.486        0.017            0.484
# 483649   0.127     0.001    0.015      0.443        0.015            0.442
# 483650   0.132     0.001    0.016      0.469        0.016            0.468
# 483651   0.126     0.001    0.017      0.485        0.017            0.485
# 483652   0.119     0.002    0.016      0.484        0.016            0.482
#
#         Sphericity  L/T Ratio  T/L Aspect Ratio  Compactness  Roundness  \
# 0            0.808      4.600             0.217        0.660      0.435
# 1            0.831      4.430             0.226        0.693      0.480
# 2            0.741      5.774             0.173        0.577      0.333
# 3            0.674     11.276             0.089        0.426      0.181
# 4            0.778      9.070             0.110        0.574      0.330
# ...            ...        ...               ...          ...        ...
# 483648       0.945      1.297             0.771        0.871      0.759
# 483649       0.970      1.208             0.828        0.886      0.784
# 483650       0.965      1.274             0.785        0.885      0.783
# 483651       0.962      1.415             0.707        0.829      0.688
# 483652       0.920      1.475             0.678        0.760      0.578
#
#         Ellipse Ratio  Circularity  Solidity  Concavity  Convexity  Extent  \
# 0               0.229        0.652     0.934      0.066      0.902   1.573
# 1               0.204        0.690     0.948      0.052      0.950   1.672
# 2               0.164        0.549     0.873      0.127      0.888   1.509
# 3               0.097        0.455     0.935      0.065      0.957   1.604
# 4               0.102        0.606     0.941      0.059      0.967   2.350
# ...               ...          ...       ...        ...        ...     ...
# 483648          0.787        0.893     0.976      0.024      0.996   0.773
# 483649          0.859        0.942     0.989      0.011      0.996   0.744
# 483650          0.847        0.931     0.995      0.005      1.000   0.783
# 483651          0.723        0.926     1.000      0.000      1.000   0.764
# 483652          0.690        0.847     0.974      0.026      0.996   0.670
#
#         Transparency  Curvature  Surface Area  L/W Ratio  W/L Ratio  \
# 0              0.081        0.0      2998.247      1.270      0.788
# 1              0.126        0.0      2415.141      1.138      0.879
# 2              0.096        0.0      2243.981      1.534      0.652
# 3              0.088        0.0      1871.602      2.291      0.437
# 4              0.077        0.0      1642.977      1.656      0.604
# ...              ...        ...           ...        ...        ...
# 483648         0.333        0.0         0.067      1.297      0.771
# 483649         0.350        0.0         0.059      1.208      0.828
# 483650         0.442        0.0         0.065      1.274      0.785
# 483651         0.276        0.0         0.069      1.415      0.707
# 483652         0.278        0.0         0.063      1.475      0.678
#
#         W/T Ratio  T/W Ratio  CHull Surface Area   Sieve  Angularity  \
# 0           3.623      0.276            3211.655  23.529      19.392
# 1           3.893      0.257            2547.278  22.089      20.688
# 2           3.763      0.266            2571.497  19.112      21.250
# 3           4.923      0.203            2001.165  15.063      18.233
# 4           5.477      0.183            1745.237  14.217      17.086
# ...           ...        ...                 ...     ...         ...
# 483648      1.000      1.000               0.069   0.129      55.000
# 483649      1.000      1.000               0.060   0.128      63.750
# 483650      1.000      1.000               0.065   0.128      56.667
# 483651      1.000      1.000               0.069   0.126      56.667
# 483652      1.000      1.000               0.065   0.126      55.714
#
#         Ellipticity  Fiber Length  Fiber Width type_micro
# 0             4.372        49.768       22.823     lithic
# 1             4.891        37.445        5.128     lithic
# 2             6.110        52.384       17.379     lithic
# 3            10.304        51.467       17.096     lithic
# 4             9.769        36.426        3.135     lithic
# ...             ...           ...          ...        ...
# 483648        1.271         0.000        0.000       soil
# 483649        1.164         0.000        0.000       soil
# 483650        1.180         0.000        0.000       soil
# 483651        1.383         0.000        0.000       soil
# 483652        1.450         0.000        0.000       soil
#
# [410340 rows x 38 columns]

# %% [markdown]
# ### Redersampling

# %% [markdown]
# https://machinelearningmastery.com/undersampling-algorithms-for-imbalanced-classification/
# https://www.analyticsvidhya.com/blog/2020/07/10-techniques-to-deal-with-class-imbalance-in-machine-learning/
# https://towardsdatascience.com/imbalanced-classification-in-python-smote-tomek-links-method-6e48dfe69bbc

# %%
# !pip install imblearn

# %%
# from imblearn.combine import SMOTETomek
from imblearn.under_sampling import TomekLinks
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTETomek
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import CondensedNearestNeighbour

# %%
micro.groupby('type_micro').describe()
# Out:
#                   Da                                                         \
#                count      mean       std   min    25%    50%    75%     max
# type_micro
# lithic        5299.0  0.408032  1.629126  0.04  0.161  0.193  0.251  30.893
# soil        405041.0  0.323588  0.296991  0.07  0.223  0.264  0.336   7.571
#
#                   Dp                                                          \
#                count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic        5299.0  0.533303  2.193727  0.058  0.198  0.250  0.330  38.251
# soil        405041.0  0.358344  0.332895  0.130  0.243  0.293  0.373   9.314
#
#               FWidth                                                          \
#                count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic        5299.0  0.351058  1.685466  0.021  0.107  0.138  0.194  36.878
# soil        405041.0  0.331481  0.293112  0.125  0.224  0.272  0.353   8.311
#
#              FLength                                                          \
#                count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic        5299.0  0.731248  3.023436  0.074  0.254  0.339  0.458  57.353
# soil        405041.0  0.506064  0.440910  0.134  0.327  0.422  0.553  12.830
#
#            FThickness                                                         \
#                 count      mean       std    min    25%    50%   75%     max
# type_micro
# lithic         5299.0  0.220404  0.661258  0.021  0.102  0.130  0.17  16.445
# soil         405041.0  0.222832  0.199711  0.125  0.148  0.179  0.23   5.431
#
#              ELength                                                           \
#                count      mean       std    min    25%    50%     75%     max
# type_micro
# lithic        5299.0  0.700690  2.950370  0.041  0.238  0.315  0.4315  50.536
# soil        405041.0  0.511377  0.442701  0.127  0.323  0.423  0.5680  13.347
#
#            EThickness                                                          \
#                 count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic         5299.0  0.208487  0.623842  0.015  0.096  0.122  0.163  16.227
# soil         405041.0  0.219185  0.197976  0.017  0.145  0.176  0.227   5.438
#
#               EWidth                                                          \
#                count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic        5299.0  0.336963  1.629089  0.015  0.100  0.130  0.186  34.444
# soil        405041.0  0.323762  0.290434  0.017  0.219  0.264  0.344   7.942
#
#               Volume                                                     \
#                count       mean         std    min    25%    50%    75%
# type_micro
# lithic        5299.0  16.602042  236.156080  0.000  0.002  0.003  0.007
# soil        405041.0   0.155468    2.027654  0.001  0.006  0.011  0.022
#
#                           Area                                            \
#                  max     count      mean        std    min    25%    50%
# type_micro
# lithic      9202.973    5299.0  2.214862  25.126003  0.001  0.020  0.029
# soil         188.638  405041.0  0.151513   0.790138  0.004  0.039  0.055
#
#                            Perimeter                                           \
#               75%      max     count      mean       std    min    25%    50%
# type_micro
# lithic      0.049  749.562    5299.0  1.675445  6.891800  0.183  0.623  0.785
# soil        0.089   45.017  405041.0  1.125770  1.045819  0.410  0.764  0.919
#
#                            CHull  Area                                     \
#               75%      max       count      mean        std    min    25%
# type_micro
# lithic      1.036  120.170      5299.0  2.402839  27.222648  0.001  0.021
# soil        1.172   29.261    405041.0  0.157977   0.818618  0.012  0.041
#
#                                   CHull Perimeter                             \
#               50%    75%      max           count      mean       std    min
# type_micro
# lithic      0.031  0.052  802.914          5299.0  1.632610  6.573565  0.183
# soil        0.058  0.093   47.443        405041.0  1.098819  1.017548  0.409
#
#                                          Sphericity                      \
#               25%    50%    75%      max      count      mean       std
# type_micro
# lithic      0.622  0.779  1.026  108.846     5299.0  0.790303  0.117014
# soil        0.752  0.898  1.141   26.285   405041.0  0.907854  0.061203
#
#                                               L/T Ratio                      \
#               min    25%    50%    75%    max     count      mean       std
# type_micro
# lithic      0.226  0.726  0.813  0.881  0.981    5299.0  2.962653  1.638428
# soil        0.239  0.887  0.924  0.946  1.000  405041.0  2.369150  0.891416
#
#                                                T/L Aspect Ratio            \
#               min    25%    50%    75%     max            count      mean
# type_micro
# lithic      1.084  1.908  2.535  3.524  19.069           5299.0  0.413635
# soil        1.032  1.746  2.123  2.775  12.947         405041.0  0.472329
#
#                                                         Compactness            \
#                  std    min    25%    50%    75%    max       count      mean
# type_micro
# lithic      0.168698  0.052  0.284  0.394  0.524  0.922      5299.0  0.599855
# soil        0.147034  0.077  0.360  0.471  0.573  0.969    405041.0  0.661483
#
#                                                          Roundness            \
#                  std    min    25%    50%     75%    max     count      mean
# type_micro
# lithic      0.130086  0.194  0.507  0.601  0.6945  0.941    5299.0  0.376740
# soil        0.127057  0.206  0.567  0.686  0.7590  0.977  405041.0  0.453704
#
#                                                         Ellipse Ratio  \
#                  std    min    25%    50%    75%    max         count
# type_micro
# lithic      0.156491  0.037  0.257  0.361  0.482  0.885        5299.0
# soil        0.161434  0.042  0.322  0.471  0.576  0.955      405041.0
#
#                                                                  Circularity  \
#                 mean       std    min    25%    50%     75%  max       count
# type_micro
# lithic      0.420723  0.182279  0.043  0.280  0.402  0.5485  1.0      5299.0
# soil        0.466610  0.159052  0.055  0.342  0.465  0.5740  1.0    405041.0
#
#                                                                    Solidity  \
#                 mean       std    min    25%    50%    75%    max     count
# type_micro
# lithic      0.638278  0.172553  0.051  0.527  0.660  0.776  0.962    5299.0
# soil        0.827946  0.101251  0.057  0.787  0.854  0.896  1.000  405041.0
#
#                                                                 Concavity  \
#                 mean       std    min    25%    50%    75%  max     count
# type_micro
# lithic      0.943644  0.080178  0.111  0.936  0.971  0.988  1.0    5299.0
# soil        0.951669  0.055871  0.159  0.938  0.972  0.984  1.0  405041.0
#
#                                                                 Convexity  \
#                 mean       std  min    25%    50%    75%    max     count
# type_micro
# lithic      0.056356  0.080179  0.0  0.012  0.029  0.064  0.889    5299.0
# soil        0.048331  0.055871  0.0  0.016  0.028  0.062  0.841  405041.0
#
#                                                                    Extent  \
#                 mean       std    min    25%    50%    75%  max     count
# type_micro
# lithic      0.991046  0.018609  0.530  0.991  0.997  0.999  1.0    5299.0
# soil        0.978325  0.033388  0.536  0.973  0.992  0.996  1.0  405041.0
#
#                                                                    \
#                 mean       std    min    25%    50%    75%    max
# type_micro
# lithic      0.730798  0.187890  0.071  0.653  0.711  0.764  3.002
# soil        0.750840  0.153197  0.107  0.667  0.748  0.822  3.287
#
#            Transparency                                                  \
#                   count      mean       std    min    25%    50%    75%
# type_micro
# lithic           5299.0  0.456355  0.162607  0.000  0.424  0.512  0.551
# soil           405041.0  0.431677  0.078386  0.085  0.397  0.445  0.482
#
#                   Curvature                                                \
#               max     count      mean       std  min    25%    50%    75%
# type_micro
# lithic      0.832    5299.0  0.075975  0.320574  0.0  0.000  0.000  0.000
# soil        0.806  405041.0  0.347784  0.398369  0.0  0.028  0.223  0.531
#
#                   Surface Area                                             \
#               max        count      mean         std    min    25%    50%
# type_micro
# lithic      6.108       5299.0  8.859449  100.504014  0.005  0.082  0.117
# soil        6.421     405041.0  0.606053    3.160548  0.016  0.156  0.219
#
#                             L/W Ratio                                    \
#               75%       max     count      mean       std    min    25%
# type_micro
# lithic      0.198  2998.247    5299.0  2.614261  1.261189  1.084  1.756
# soil        0.354   180.066  405041.0  1.540260  0.318457  1.032  1.308
#
#                                  W/L Ratio                                    \
#               50%    75%     max     count      mean       std    min    25%
# type_micro
# lithic      2.269  3.102  18.300    5299.0  0.451302  0.166853  0.055  0.322
# soil        1.461  1.695   7.697  405041.0  0.673070  0.119128  0.130  0.590
#
#                                 W/T Ratio                                  \
#               50%    75%    max     count      mean       std  min    25%
# type_micro
# lithic      0.441  0.569  0.922    5299.0  1.175189  0.565394  1.0  1.000
# soil        0.684  0.764  0.969  405041.0  1.528345  0.444866  1.0  1.234
#
#                                 T/W Ratio                                    \
#               50%    75%    max     count      mean       std    min    25%
# type_micro
# lithic      1.000  1.000  6.841    5299.0  0.930623  0.179607  0.146  1.000
# soil        1.415  1.691  8.415  405041.0  0.697271  0.158558  0.119  0.591
#
#                               CHull Surface Area                               \
#               50%    75%  max              count      mean         std    min
# type_micro
# lithic      1.000  1.000  1.0             5299.0  9.611345  108.890588  0.006
# soil        0.707  0.811  1.0           405041.0  0.631902    3.274472  0.049
#
#                                               Sieve                      \
#               25%    50%    75%       max     count      mean       std
# type_micro
# lithic      0.086  0.125  0.210  3211.655    5299.0  0.285732  1.145785
# soil        0.163  0.231  0.374   189.773  405041.0  0.277157  0.242147
#
#                                                 Angularity             \
#               min    25%    50%     75%     max      count       mean
# type_micro
# lithic      0.021  0.107  0.137  0.1835  23.529     5299.0  69.491435
# soil        0.125  0.191  0.227  0.2900   6.240   405041.0  55.906768
#
#                                                             Ellipticity  \
#                   std  min     25%     50%     75%      max       count
# type_micro
# lithic      27.561298  0.0  63.333  70.000  85.000  120.000      5299.0
# soil        10.475297  7.4  50.000  55.714  62.308  116.667    405041.0
#
#                                                                    \
#                 mean       std  min    25%    50%     75%     max
# type_micro
# lithic      3.009928  1.868712  1.0  1.824  2.489  3.5765  23.322
# soil        2.454637  1.020231  1.0  1.741  2.151  2.9210  18.267
#
#            Fiber Length                                                     \
#                   count      mean      std  min  25%    50%    75%     max
# type_micro
# lithic           5299.0  0.648506  3.04792  0.0  0.0  0.272  0.396  52.384
# soil           405041.0  0.322287  0.44718  0.0  0.0  0.254  0.519  18.373
#
#            Fiber Width
#                  count      mean       std  min  25%    50%    75%     max
# type_micro
# lithic          5299.0  0.193938  0.937805  0.0  0.0  0.084  0.126  22.823
# soil          405041.0  0.108555  0.175003  0.0  0.0  0.091  0.172   6.715

# %%
# define the undersampling method
# undersample = SMOTE(sampling_strategy='minority')
# undersample = TomekLinks(sampling_strategy='majority')
undersample = RandomUnderSampler(random_state=42, replacement=True)
# undersample = CondensedNearestNeighbour(n_neighbors=1)

# Separate majority and minority classes
class_column = ['type_micro']
X = micro.drop(columns=class_column)
y = micro[class_column]

X_resampled, y_resampled = undersample.fit_resample(X, y)

# %%
data_resampled = pd.concat([X_resampled, y_resampled], axis=1)

# %%
data_resampled.columns = X.columns.tolist() + ['type_micro']

# %%
data_resampled
# Out:
#            Da      Dp  FWidth  FLength  FThickness  ELength  EThickness  \
# 0      30.893  38.251  36.878   46.822      10.179   44.168      10.102
# 1      27.727  33.375  35.149   40.001       9.029   39.022       7.978
# 2      26.726  36.061  30.199   46.332       8.025   47.365       7.753
# 3      24.408  36.198  25.039   57.353       5.086   50.536       4.904
# 4      22.869  29.388  24.044   39.820       4.390   38.568       3.948
# ...       ...     ...     ...      ...         ...      ...         ...
# 10593   0.216   0.208   0.341    0.465       0.150    0.448       0.149
# 10594   0.434   0.514   0.475    0.603       0.248    0.613       0.241
# 10595   0.214   0.231   0.205    0.353       0.142    0.365       0.141
# 10596   0.231   0.249   0.251    0.309       0.131    0.316       0.132
# 10597   0.170   0.187   0.140    0.235       0.126    0.235       0.122
#
#        EWidth    Volume     Area  Perimeter  CHull  Area  CHull Perimeter  \
# 0      34.444  9202.973  749.562    120.170      802.914          108.399
# 1      34.108  6646.859  603.785    104.849      636.820           99.590
# 2      28.230  5879.233  560.995    113.290      642.874          100.583
# 3      23.943  3824.409  467.900    113.719      500.291          108.846
# 4      22.535  2200.862  410.744     92.327      436.309           89.254
# ...       ...       ...      ...        ...          ...              ...
# 10593   0.352     0.012    0.037      0.652        0.037            0.652
# 10594   0.467     0.037    0.148      1.615        0.158            1.507
# 10595   0.207     0.005    0.036      0.727        0.037            0.719
# 10596   0.252     0.005    0.042      0.782        0.042            0.781
# 10597   0.139     0.002    0.023      0.589        0.023            0.585
#
#        Sphericity  L/T Ratio  T/L Aspect Ratio  Compactness  Roundness  \
# 0           0.808      4.600             0.217        0.660      0.435
# 1           0.831      4.430             0.226        0.693      0.480
# 2           0.741      5.774             0.173        0.577      0.333
# 3           0.674     11.276             0.089        0.426      0.181
# 4           0.778      9.070             0.110        0.574      0.330
# ...           ...        ...               ...          ...        ...
# 10593       1.000      3.109             0.322        0.464      0.215
# 10594       0.845      2.433             0.411        0.720      0.519
# 10595       0.924      2.485             0.402        0.606      0.367
# 10596       0.927      2.362             0.423        0.747      0.559
# 10597       0.908      1.862             0.537        0.724      0.524
#
#        Ellipse Ratio  Circularity  Solidity  Concavity  Convexity  Extent  \
# 0              0.229        0.652     0.934      0.066      0.902   1.573
# 1              0.204        0.690     0.948      0.052      0.950   1.672
# 2              0.164        0.549     0.873      0.127      0.888   1.509
# 3              0.097        0.455     0.935      0.065      0.957   1.604
# 4              0.102        0.606     0.941      0.059      0.967   2.350
# ...              ...          ...       ...        ...        ...     ...
# 10593          0.333        1.000     0.994      0.006      0.999   0.526
# 10594          0.393        0.714     0.938      0.062      0.934   0.991
# 10595          0.387        0.853     0.966      0.034      0.988   0.716
# 10596          0.418        0.859     0.991      0.009      0.999   1.037
# 10597          0.521        0.824     0.974      0.026      0.995   0.767
#
#        Transparency  Curvature  Surface Area  L/W Ratio  W/L Ratio  W/T Ratio  \
# 0             0.081      0.000      2998.247      1.270      0.788      3.623
# 1             0.126      0.000      2415.141      1.138      0.879      3.893
# 2             0.096      0.000      2243.981      1.534      0.652      3.763
# 3             0.088      0.000      1871.602      2.291      0.437      4.923
# 4             0.077      0.000      1642.977      1.656      0.604      5.477
# ...             ...        ...           ...        ...        ...        ...
# 10593         0.412      0.000         0.147      1.367      0.732      2.274
# 10594         0.568      1.979         0.593      1.270      0.788      1.916
# 10595         0.469      0.588         0.144      1.720      0.581      1.445
# 10596         0.412      0.000         0.167      1.232      0.812      1.918
# 10597         0.481      0.000         0.091      1.681      0.595      1.107
#
#        T/W Ratio  CHull Surface Area   Sieve  Angularity  Ellipticity  \
# 0          0.276            3211.655  23.529      19.392        4.372
# 1          0.257            2547.278  22.089      20.688        4.891
# 2          0.266            2571.497  19.112      21.250        6.110
# 3          0.203            2001.165  15.063      18.233       10.304
# 4          0.183            1745.237  14.217      17.086        9.769
# ...          ...                 ...     ...         ...          ...
# 10593      0.440               0.147   0.245      60.000        3.007
# 10594      0.522               0.631   0.361      54.375        2.543
# 10595      0.692               0.149   0.174      62.857        2.582
# 10596      0.521               0.169   0.191      68.000        2.394
# 10597      0.903               0.093   0.133      56.667        1.918
#
#        Fiber Length  Fiber Width type_micro
# 0            49.768       22.823     lithic
# 1            37.445        5.128     lithic
# 2            52.384       17.379     lithic
# 3            51.467       17.096     lithic
# 4            36.426        3.135     lithic
# ...             ...          ...        ...
# 10593         0.000        0.000       soil
# 10594         0.712        0.194       soil
# 10595         0.299        0.152       soil
# 10596         0.246        0.133       soil
# 10597         0.000        0.000       soil
#
# [10598 rows x 38 columns]

# %%
data_resampled.groupby('type_micro').describe()
# Out:
#                 Da                                                          \
#              count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic      5299.0  0.408032  1.629126  0.040  0.161  0.193  0.251  30.893
# soil        5299.0  0.320498  0.300485  0.095  0.221  0.261  0.332   6.886
#
#                 Dp                                                          \
#              count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic      5299.0  0.533303  2.193727  0.058  0.198  0.250  0.330  38.251
# soil        5299.0  0.354639  0.336147  0.131  0.241  0.288  0.369   7.635
#
#             FWidth                                                          \
#              count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic      5299.0  0.351058  1.685466  0.021  0.107  0.138  0.194  36.878
# soil        5299.0  0.328094  0.300835  0.125  0.221  0.268  0.348   7.295
#
#            FLength                                                          \
#              count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic      5299.0  0.731248  3.023436  0.074  0.254  0.339  0.458  57.353
# soil        5299.0  0.497773  0.439498  0.137  0.321  0.414  0.545   9.421
#
#            FThickness                                                          \
#                 count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic         5299.0  0.220404  0.661258  0.021  0.102  0.130  0.170  16.445
# soil           5299.0  0.221908  0.204210  0.125  0.147  0.177  0.228   4.128
#
#            ELength                                                           \
#              count      mean       std    min    25%    50%     75%     max
# type_micro
# lithic      5299.0  0.700690  2.950370  0.041  0.238  0.315  0.4315  50.536
# soil        5299.0  0.502513  0.438825  0.129  0.315  0.415  0.5585   8.589
#
#            EThickness                                                          \
#                 count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic         5299.0  0.208487  0.623842  0.015  0.096  0.122  0.163  16.227
# soil           5299.0  0.218321  0.202477  0.042  0.144  0.174  0.225   3.999
#
#             EWidth                                                          \
#              count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic      5299.0  0.336963  1.629089  0.015  0.100  0.130  0.186  34.444
# soil        5299.0  0.320904  0.296726  0.042  0.217  0.262  0.340   7.251
#
#             Volume                                                     \
#              count       mean         std    min    25%    50%    75%
# type_micro
# lithic      5299.0  16.602042  236.156080  0.000  0.002  0.003  0.007
# soil        5299.0   0.167666    2.517804  0.001  0.006  0.010  0.021
#
#                         Area                                                   \
#                  max   count      mean        std    min    25%    50%    75%
# type_micro
# lithic      9202.973  5299.0  2.214862  25.126003  0.001  0.020  0.029  0.049
# soil         148.528  5299.0  0.151571   0.851178  0.007  0.038  0.054  0.087
#
#                     Perimeter                                            \
#                 max     count      mean       std    min     25%    50%
# type_micro
# lithic      749.562    5299.0  1.675445  6.891800  0.183  0.6230  0.785
# soil         37.239    5299.0  1.114148  1.056051  0.411  0.7575  0.905
#
#                             CHull  Area                                     \
#                75%      max       count      mean        std    min    25%
# type_micro
# lithic      1.0360  120.170      5299.0  2.402839  27.222648  0.001  0.021
# soil        1.1605   23.986      5299.0  0.158083   0.882008  0.013  0.040
#
#                                   CHull Perimeter                             \
#               50%    75%      max           count      mean       std    min
# type_micro
# lithic      0.031  0.052  802.914          5299.0  1.632610  6.573565  0.183
# soil        0.056  0.091   38.602          5299.0  1.087964  1.028747  0.410
#
#                                           Sphericity                      \
#               25%    50%     75%      max      count      mean       std
# type_micro
# lithic      0.622  0.779  1.0260  108.846     5299.0  0.790303  0.117014
# soil        0.744  0.885  1.1295   23.176     5299.0  0.908793  0.063287
#
#                                               L/T Ratio                      \
#               min    25%    50%    75%    max     count      mean       std
# type_micro
# lithic      0.226  0.726  0.813  0.881  0.981    5299.0  2.962653  1.638428
# soil        0.313  0.889  0.926  0.948  1.000    5299.0  2.335872  0.877025
#
#                                                T/L Aspect Ratio            \
#               min    25%    50%    75%     max            count      mean
# type_micro
# lithic      1.084  1.908  2.535  3.524  19.069           5299.0  0.413635
# soil        1.065  1.734  2.098  2.732  10.315           5299.0  0.478513
#
#                                                         Compactness            \
#                  std    min    25%    50%    75%    max       count      mean
# type_micro
# lithic      0.168698  0.052  0.284  0.394  0.524  0.922      5299.0  0.599855
# soil        0.148598  0.097  0.366  0.477  0.577  0.939      5299.0  0.666119
#
#                                                          Roundness            \
#                  std    min    25%    50%     75%    max     count      mean
# type_micro
# lithic      0.130086  0.194  0.507  0.601  0.6945  0.941    5299.0  0.376740
# soil        0.126105  0.236  0.573  0.690  0.7600  0.963    5299.0  0.459615
#
#                                                         Ellipse Ratio  \
#                  std    min    25%    50%    75%    max         count
# type_micro
# lithic      0.156491  0.037  0.257  0.361  0.482  0.885        5299.0
# soil        0.161561  0.056  0.328  0.476  0.578  0.927        5299.0
#
#                                                                     \
#                 mean       std    min    25%    50%     75%    max
# type_micro
# lithic      0.420723  0.182279  0.043  0.280  0.402  0.5485  1.000
# soil        0.472780  0.160183  0.092  0.348  0.471  0.5800  0.988
#
#            Circularity                                                         \
#                  count      mean       std    min    25%    50%    75%    max
# type_micro
# lithic          5299.0  0.638278  0.172553  0.051  0.527  0.660  0.776  0.962
# soil            5299.0  0.829921  0.103834  0.098  0.790  0.857  0.898  1.000
#
#            Solidity                                                       \
#               count      mean       std    min    25%    50%    75%  max
# type_micro
# lithic       5299.0  0.943644  0.080178  0.111  0.936  0.971  0.988  1.0
# soil         5299.0  0.952570  0.057416  0.291  0.940  0.973  0.985  1.0
#
#            Concavity                                                       \
#                count      mean       std  min    25%    50%    75%    max
# type_micro
# lithic        5299.0  0.056356  0.080179  0.0  0.012  0.029  0.064  0.889
# soil          5299.0  0.047430  0.057416  0.0  0.015  0.027  0.060  0.709
#
#            Convexity                                                       \
#                count      mean       std    min    25%    50%    75%  max
# type_micro
# lithic        5299.0  0.991046  0.018609  0.530  0.991  0.997  0.999  1.0
# soil          5299.0  0.978588  0.034339  0.618  0.975  0.992  0.996  1.0
#
#             Extent                                                         \
#              count      mean       std    min    25%    50%    75%    max
# type_micro
# lithic      5299.0  0.730798  0.187890  0.071  0.653  0.711  0.764  3.002
# soil        5299.0  0.751625  0.150126  0.182  0.668  0.748  0.822  2.371
#
#            Transparency                                                  \
#                   count      mean       std    min    25%    50%    75%
# type_micro
# lithic           5299.0  0.456355  0.162607  0.000  0.424  0.512  0.551
# soil             5299.0  0.430151  0.079665  0.087  0.393  0.443  0.482
#
#                   Curvature                                                \
#               max     count      mean       std  min    25%    50%    75%
# type_micro
# lithic      0.832    5299.0  0.075975  0.320574  0.0  0.000  0.000  0.000
# soil        0.787    5299.0  0.340613  0.404720  0.0  0.024  0.213  0.508
#
#                   Surface Area                                             \
#               max        count      mean         std    min    25%    50%
# type_micro
# lithic      6.108       5299.0  8.859449  100.504014  0.005  0.082  0.117
# soil        3.926       5299.0  0.606293    3.404722  0.028  0.153  0.214
#
#                             L/W Ratio                                    \
#               75%       max     count      mean       std    min    25%
# type_micro
# lithic      0.198  2998.247    5299.0  2.614261  1.261189  1.084  1.756
# soil        0.347   148.956    5299.0  1.530785  0.312412  1.065  1.309
#
#                                  W/L Ratio                                    \
#               50%    75%     max     count      mean       std    min    25%
# type_micro
# lithic      2.269  3.102  18.300    5299.0  0.451302  0.166853  0.055  0.322
# soil        1.452  1.682   3.766    5299.0  0.676398  0.117262  0.266  0.595
#
#                                 W/T Ratio                                  \
#               50%    75%    max     count      mean       std  min    25%
# type_micro
# lithic      0.441  0.569  0.922    5299.0  1.175189  0.565394  1.0  1.000
# soil        0.689  0.764  0.939    5299.0  1.516039  0.440540  1.0  1.222
#
#                                 T/W Ratio                                    \
#               50%    75%    max     count      mean       std    min    25%
# type_micro
# lithic      1.000  1.000  6.841    5299.0  0.930623  0.179607  0.146  1.000
# soil        1.409  1.678  5.398    5299.0  0.702794  0.159732  0.185  0.596
#
#                              CHull Surface Area                               \
#              50%    75%  max              count      mean         std    min
# type_micro
# lithic      1.00  1.000  1.0             5299.0  9.611345  108.890588  0.006
# soil        0.71  0.818  1.0             5299.0  0.632335    3.528003  0.050
#
#                                             Sieve                             \
#               25%    50%    75%       max   count      mean       std    min
# type_micro
# lithic      0.086  0.125  0.210  3211.655  5299.0  0.285732  1.145785  0.021
# soil        0.160  0.225  0.365   154.407  5299.0  0.275008  0.248681  0.125
#
#                                          Angularity                        \
#               25%    50%     75%     max      count       mean        std
# type_micro
# lithic      0.107  0.137  0.1835  23.529     5299.0  69.491435  27.561298
# soil        0.189  0.225  0.2860   5.711     5299.0  56.052829  10.561650
#
#                                                   Ellipticity            \
#                min     25%     50%     75%    max       count      mean
# type_micro
# lithic       0.000  63.333  70.000  85.000  120.0      5299.0  3.009928
# soil        14.222  50.000  55.833  62.857  100.0      5299.0  2.417717
#
#                                                           Fiber Length  \
#                  std    min    25%    50%     75%     max        count
# type_micro
# lithic      1.868712  1.000  1.824  2.489  3.5765  23.322       5299.0
# soil        1.000075  1.012  1.725  2.123  2.8765  10.817       5299.0
#
#                                                                Fiber Width  \
#                 mean       std  min  25%    50%    75%     max       count
# type_micro
# lithic      0.648506  3.047920  0.0  0.0  0.272  0.396  52.384      5299.0
# soil        0.314349  0.446397  0.0  0.0  0.241  0.508   6.451      5299.0
#
#
#                 mean       std  min  25%    50%    75%     max
# type_micro
# lithic      0.193938  0.937805  0.0  0.0  0.084  0.126  22.823
# soil        0.108043  0.189236  0.0  0.0  0.072  0.167   3.926

# %%
# # Separate majority and minority classes
# df_majority = micro1[micro1.type_micro=='soil']
# df_minority = micro1[micro1.type_micro=='lithic']

# # Downsample majority class
# df_majority_downsampled = resample(df_majority, 
#                                  replace=False,    # sample without replacement
#                                  n_samples=5299,     # to match minority class
#                                  random_state=123) # reproducible results
 
# # Combine minority class with downsampled majority class
# df_downsampled = pd.concat([df_majority_downsampled, df_minority])

# %% [markdown]
# ### Selected features

# %%
# micro1_selected = micro1[["Transparency","FLength","FWidth","FThickness","W/L Ratio", "L/W Ratio", 'Sphericity', 'Circularity', 'Convexity',"type_micro"]]

# %% [markdown]
# ### Hold-out data

# %%
# from sklearn.model_selection import train_test_split
# import numpy as np

# # X is your feature data
# # y is your target data
# X_train, X_holdout, y_train, y_holdout = train_test_split(X, y, test_size=0.1, stratify=y, random_state=42)

# # Now you can perform the train-test split on X_train and y_train
# X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.1, stratify=y_train, random_state=42)

# %% [markdown]
# ## Models

# %% [markdown]
# ### Lazy predict

# %%
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# %%
class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|███████████████████████████████████████████| 29/29 [00:26<00:00,  1.08it/s]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.99               0.99    None      0.99
# AdaBoostClassifier                 0.99               0.99    None      0.99
# RandomForestClassifier             0.99               0.99    None      0.99
# ExtraTreesClassifier               0.99               0.99    None      0.99
# SVC                                0.98               0.98    None      0.98
# BaggingClassifier                  0.98               0.98    None      0.98
# DecisionTreeClassifier             0.98               0.98    None      0.98
# LabelPropagation                   0.98               0.98    None      0.98
# LabelSpreading                     0.98               0.98    None      0.98
# KNeighborsClassifier               0.98               0.98    None      0.98
# LinearSVC                          0.97               0.97    None      0.97
# CalibratedClassifierCV             0.97               0.97    None      0.97
# LogisticRegression                 0.97               0.97    None      0.97
# SGDClassifier                      0.96               0.96    None      0.96
# ExtraTreeClassifier                0.96               0.96    None      0.96
# LinearDiscriminantAnalysis         0.96               0.96    None      0.96
# RidgeClassifier                    0.96               0.96    None      0.96
# RidgeClassifierCV                  0.96               0.96    None      0.96
# NuSVC                              0.95               0.95    None      0.95
# Perceptron                         0.95               0.95    None      0.95
# PassiveAggressiveClassifier        0.95               0.95    None      0.95
# BernoulliNB                        0.83               0.83    None      0.83
# NearestCentroid                    0.81               0.81    None      0.81
# QuadraticDiscriminantAnalysis      0.76               0.76    None      0.75
# GaussianNB                         0.61               0.61    None      0.54
# DummyClassifier                    0.50               0.50    None      0.33
#
#                                Time Taken
# Model
# LGBMClassifier                       0.96
# AdaBoostClassifier                   1.55
# RandomForestClassifier               2.03
# ExtraTreesClassifier                 0.80
# SVC                                  1.30
# BaggingClassifier                    1.37
# DecisionTreeClassifier               0.27
# LabelPropagation                     2.65
# LabelSpreading                       3.53
# KNeighborsClassifier                 0.62
# LinearSVC                            0.68
# CalibratedClassifierCV               2.22
# LogisticRegression                   0.33
# SGDClassifier                        0.10
# ExtraTreeClassifier                  0.07
# LinearDiscriminantAnalysis           0.14
# RidgeClassifier                      0.10
# RidgeClassifierCV                    0.15
# NuSVC                                7.23
# Perceptron                           0.08
# PassiveAggressiveClassifier          0.08
# BernoulliNB                          0.10
# NearestCentroid                      0.08
# QuadraticDiscriminantAnalysis        0.12
# GaussianNB                           0.06
# DummyClassifier                      0.06

# %% [markdown]
# ### LightBGM

# %% [markdown]
# #### train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

lgbm = LGBMClassifier(random_state=random_seed)
lgbm.fit(X_train_transformed, y_train_transformed)
print('Accuracy of LGBM classifier on training set: {:.4f}'.format(lgbm.score(X_train_transformed, y_train_transformed)))
print('Accuracy of LGBM classifier on test set: {:.4f}'.format(lgbm.score(X_test_transformed, y_test_transformed)))

pred = lgbm.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, lgbm.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=lgbm.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of LGBM classifier on training set: 1.0000
# Accuracy of LGBM classifier on test set: 0.9948
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1060
#            1       0.99      1.00      0.99      1060
#
#     accuracy                           0.99      2120
#    macro avg       0.99      0.99      0.99      2120
# weighted avg       0.99      0.99      0.99      2120

# %%
acc_train1_LBGM = lgbm.score(X_train_transformed, y_train_transformed)
acc_test1_LBGM = lgbm.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Cross validation for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'num_leaves': [31, 63, 127],
              'learning_rate': [0.1, 0.01, 0.001],
              'n_estimators': [100, 500, 1000]
             }

# %%
grid_search = GridSearchCV(lgbm, param_grid, cv=5)
grid_search.fit(X_train_transformed, y_train_transformed)
# Out:
# GridSearchCV(cv=5, estimator=LGBMClassifier(random_state=42),
#              param_grid={'learning_rate': [0.1, 0.01, 0.001],
#                          'n_estimators': [100, 500, 1000],
#                          'num_leaves': [31, 63, 127]})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'learning_rate': 0.1, 'n_estimators': 500, 'num_leaves': 31}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 3           0.88          0.11             0.02            0.00
# 6           1.26          0.07             0.02            0.00
# 7           2.21          0.42             0.02            0.00
#
#   param_learning_rate param_n_estimators param_num_leaves  \
# 3                 0.1                500               31
# 6                 0.1               1000               31
# 7                 0.1               1000               63
#
#                                               params  split0_test_score  \
# 3  {'learning_rate': 0.1, 'n_estimators': 500, 'n...               0.99
# 6  {'learning_rate': 0.1, 'n_estimators': 1000, '...               0.99
# 7  {'learning_rate': 0.1, 'n_estimators': 1000, '...               0.99
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 3               0.99               0.99               0.99               0.99
# 6               0.99               0.99               0.99               0.99
# 7               0.99               0.99               0.99               0.99
#
#    mean_test_score  std_test_score  rank_test_score
# 3             0.99            0.00                1
# 6             0.99            0.00                2
# 7             0.99            0.00                3

# %%
# grid_search.predict(x_test)

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of LBGM classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of LBGM classifier on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of LBGM classifier on training set: 1.0000
# Accuracy of LBGM classifier on test set: 0.9958
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      1060
#            1       0.99      1.00      1.00      1060
#
#     accuracy                           1.00      2120
#    macro avg       1.00      1.00      1.00      2120
# weighted avg       1.00      1.00      1.00      2120

# %%
acc_train2_LBGM = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_LBGM = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
importances = lgbm.feature_importances_

# Sort the feature importances in descending order
indices = np.argsort(importances)[::-1]
feature_names = data_resampled.columns[1:]
names = [feature_names[i] for i in indices]

importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# Sort the dataframe by importance
importance_df.sort_values(by='importance', ascending=False, inplace=True)

# Print the top 10 features
print(importance_df.head(10))

fi_LGBM = importance_df
# Out:
#           feature_name  importance
# 33         Ellipticity         478
# 22              Extent         404
# 24           Curvature         232
# 13           L/T Ratio         204
# 12          Sphericity         182
# 4              ELength         128
# 30  CHull Surface Area         121
# 25        Surface Area         113
# 19            Solidity         105
# 0                   Dp          90

# %%
# Create plot
plt.figure()

# Create plot title
plt.title("Feature Importance")

# Add bars
plt.bar(range(X_train.shape[1]), importances[indices])

# Add feature names as x-axis labels
plt.xticks(range(X_train.shape[1]), names, rotation=90)

# Show plot
plt.show()

# %% [markdown]
# ### AdaBoost (Adaptive Boosting)

# %% [markdown]
# #### Train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

ada = AdaBoostClassifier(random_state=random_seed)
ada.fit(X_train_transformed, y_train_transformed)
print('Accuracy of LGBM classifier on training set: {:.4f}'.format(ada.score(X_train_transformed, y_train_transformed)))
print('Accuracy of LGBM classifier on test set: {:.4f}'.format(ada.score(X_test_transformed, y_test_transformed)))

pred = ada.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, ada.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=ada.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of LGBM classifier on training set: 0.9933
# Accuracy of LGBM classifier on test set: 0.9910
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1060
#            1       0.99      0.99      0.99      1060
#
#     accuracy                           0.99      2120
#    macro avg       0.99      0.99      0.99      2120
# weighted avg       0.99      0.99      0.99      2120

# %%
acc_train1_ada = ada.score(X_train_transformed, y_train_transformed)
acc_test1_ada = ada.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Cross validation for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_estimators': [50, 100, 150],
              'learning_rate': [0.1, 0.5, 1.0],
              'algorithm': ['SAMME', 'SAMME.R']}

# %%
grid_search = GridSearchCV(ada, param_grid, cv=5)
grid_search.fit(X_train_transformed, y_train_transformed)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(random_state=42),
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.1, 0.5, 1.0],
#                          'n_estimators': [50, 100, 150]})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'algorithm': 'SAMME.R', 'learning_rate': 1.0, 'n_estimators': 150}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 17           2.33          0.06             0.05            0.00
# 14           2.26          0.01             0.05            0.00
# 16           1.52          0.01             0.03            0.00
#
#    param_algorithm param_learning_rate param_n_estimators  \
# 17         SAMME.R                 1.0                150
# 14         SAMME.R                 0.5                150
# 16         SAMME.R                 1.0                100
#
#                                                params  split0_test_score  \
# 17  {'algorithm': 'SAMME.R', 'learning_rate': 1.0,...               0.99
# 14  {'algorithm': 'SAMME.R', 'learning_rate': 0.5,...               0.99
# 16  {'algorithm': 'SAMME.R', 'learning_rate': 1.0,...               0.99
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 17               0.99               0.99               0.99
# 14               0.99               0.99               0.99
# 16               0.99               0.99               0.99
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 17               0.99             0.99            0.00                1
# 14               0.99             0.99            0.00                2
# 16               0.99             0.99            0.00                3

# %%
# grid_search.predict(x_test)

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of AdaBoost classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of AdaBoost classifier on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of AdaBoost classifier on training set: 0.9994
# Accuracy of AdaBoost classifier on test set: 0.9958
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1060
#            1       1.00      1.00      1.00      1060
#
#     accuracy                           1.00      2120
#    macro avg       1.00      1.00      1.00      2120
# weighted avg       1.00      1.00      1.00      2120

# %%
acc_train2_ada = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_ada = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
importances = ada.feature_importances_

# Sort the feature importances in descending order
indices = np.argsort(importances)[::-1]
feature_names = data_resampled.columns[1:]
names = [feature_names[i] for i in indices]

importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# Sort the dataframe by importance
importance_df.sort_values(by='importance', ascending=False, inplace=True)

# Print the top 10 features
print(importance_df.head(10))

fi_ada = importance_df
# Out:
#     feature_name  importance
# 33   Ellipticity        0.18
# 22        Extent        0.16
# 12    Sphericity        0.10
# 29     T/W Ratio        0.10
# 4        ELength        0.08
# 24     Curvature        0.08
# 13     L/T Ratio        0.08
# 19      Solidity        0.06
# 23  Transparency        0.04
# 26     L/W Ratio        0.04

# %%
# Create plot
plt.figure()

# Create plot title
plt.title("Feature Importance")

# Add bars
plt.bar(range(X_train.shape[1]), importances[indices])

# Add feature names as x-axis labels
plt.xticks(range(X_train.shape[1]), names, rotation=90)

# Show plot
plt.show()

# %% [markdown]
# ### Random forest

# %% [markdown]
# #### Train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

X_holdout = X_test
y_holdout = y_test

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

rf = RandomForestClassifier(random_state=random_seed)
rf.fit(X_train_transformed, y_train_transformed)
print('Accuracy of RF classifier on training set: {:.4f}'.format(rf.score(X_train_transformed, y_train_transformed)))
print('Accuracy of RF classifier on test set: {:.4f}'.format(rf.score(X_test_transformed, y_test_transformed)))

pred = rf.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, rf.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=rf.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of RF classifier on training set: 1.0000
# Accuracy of RF classifier on test set: 0.9882
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      1060
#            1       0.98      0.99      0.99      1060
#
#     accuracy                           0.99      2120
#    macro avg       0.99      0.99      0.99      2120
# weighted avg       0.99      0.99      0.99      2120

# %%
acc_train1_rf = rf.score(X_train_transformed, y_train_transformed)
acc_test1_rf = rf.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Grid search for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_estimators': [10, 50, 100],
              'max_depth': [None, 5, 10],
              'min_samples_split': [2, 5, 10]}
#               'min_samples_leaf': [1, 2, 4],
#               'max_features': ['auto', 'sqrt', 'log2'],
#               'max_leaf_nodes': [10, 20, 30],
#               'class_weight':[None, 'balanced'],
#               'criterion': ['gini', 'entropy']}

# %%
grid_search = GridSearchCV(rf, param_grid, cv=5)
grid_search.fit(X_test_transformed, y_test_transformed)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'max_depth': [None, 5, 10],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 50, 100]})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 100}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 5           0.36          0.01             0.01            0.00
# 4           0.18          0.00             0.01            0.00
# 8           0.37          0.01             0.01            0.00
#
#   param_max_depth param_min_samples_split param_n_estimators  \
# 5            None                       5                100
# 4            None                       5                 50
# 8            None                      10                100
#
#                                               params  split0_test_score  \
# 5  {'max_depth': None, 'min_samples_split': 5, 'n...               1.00
# 4  {'max_depth': None, 'min_samples_split': 5, 'n...               1.00
# 8  {'max_depth': None, 'min_samples_split': 10, '...               0.99
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 5               0.97               0.99               0.97               0.99
# 4               0.97               0.99               0.97               0.99
# 8               0.97               0.99               0.98               0.98
#
#    mean_test_score  std_test_score  rank_test_score
# 5             0.98            0.01                1
# 4             0.98            0.01                2
# 8             0.98            0.01                3

# %% [markdown]
# #### Cross validation

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score
# Perform cross-validation after grid search
scores = cross_val_score(grid_search, X_test_transformed, y_test_transformed, cv=10)
print("Cross-validation scores: ", scores)
print("Mean accuracy: ", scores.mean())

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of Random Forest classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of Random Forest classifier on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of Random Forest classifier on training set: 0.9781
# Accuracy of Random Forest classifier on test set: 1.0000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1060
#            1       1.00      1.00      1.00      1060
#
#     accuracy                           1.00      2120
#    macro avg       1.00      1.00      1.00      2120
# weighted avg       1.00      1.00      1.00      2120

# %%
acc_train2_rf = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_rf = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
importances = rf.feature_importances_

# Sort the feature importances in descending order
indices = np.argsort(importances)[::-1]
feature_names = data_resampled.columns[1:]
names = [feature_names[i] for i in indices]

importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# Sort the dataframe by importance
importance_df.sort_values(by='importance', ascending=False, inplace=True)

# Print the top 10 features
print(importance_df.head(10))

fi_rf = importance_df
# Out:
#           feature_name  importance
# 30  CHull Surface Area        0.17
# 29           T/W Ratio        0.14
# 25        Surface Area        0.07
# 2              FLength        0.07
# 7               Volume        0.06
# 19            Solidity        0.05
# 33         Ellipticity        0.04
# 13           L/T Ratio        0.04
# 27           W/L Ratio        0.04
# 32          Angularity        0.03

# %%
# Create plot
plt.figure()

# Create plot title
plt.title("Feature Importance")

# Add bars
plt.bar(range(X_train.shape[1]), importances[indices])

# Add feature names as x-axis labels
plt.xticks(range(X_train.shape[1]), names, rotation=90)

# Show plot
plt.show()

# %% [markdown]
# ### Bagging (Bootstrapped Aggregation)

# %% [markdown]
# #### Train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

base_estimator = DecisionTreeClassifier(max_depth=4, random_state=random_seed)
bagging = BaggingClassifier(base_estimator=base_estimator, random_state=random_seed)
bagging.fit(X_train_transformed, y_train_transformed)
print('Accuracy of LGBM classifier on training set: {:.4f}'.format(bagging.score(X_train_transformed, y_train_transformed)))
print('Accuracy of LGBM classifier on test set: {:.4f}'.format(bagging.score(X_test_transformed, y_test_transformed)))

pred = bagging.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, bagging.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=bagging.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of LGBM classifier on training set: 0.9707
# Accuracy of LGBM classifier on test set: 0.9627
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      1060
#            1       0.96      0.96      0.96      1060
#
#     accuracy                           0.96      2120
#    macro avg       0.96      0.96      0.96      2120
# weighted avg       0.96      0.96      0.96      2120

# %%
acc_train1_bagging = bagging.score(X_train_transformed, y_train_transformed)
acc_test1_bagging = bagging.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Cross validation for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_estimators': [50, 100, 150],
              'max_samples': [0.5, 1.0, 2.0],
              'max_features': [0.5, 1.0, 2.0]}

# %%
grid_search = GridSearchCV(bagging, param_grid, cv=5)
grid_search.fit(X_train_transformed, y_train_transformed)
# Out:
# GridSearchCV(cv=5,
#              estimator=BaggingClassifier(base_estimator=DecisionTreeClassifier(max_depth=4,
#                                                                                random_state=42),
#                                          random_state=42),
#              param_grid={'max_features': [0.5, 1.0, 2.0],
#                          'max_samples': [0.5, 1.0, 2.0],
#                          'n_estimators': [50, 100, 150]})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 100}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 10           2.37          0.09             0.03            0.00
# 13           3.45          0.01             0.03            0.00
# 9            1.19          0.03             0.02            0.00
#
#    param_max_features param_max_samples param_n_estimators  \
# 10                1.0               0.5                100
# 13                1.0               1.0                100
# 9                 1.0               0.5                 50
#
#                                                params  split0_test_score  \
# 10  {'max_features': 1.0, 'max_samples': 0.5, 'n_e...               0.97
# 13  {'max_features': 1.0, 'max_samples': 1.0, 'n_e...               0.97
# 9   {'max_features': 1.0, 'max_samples': 0.5, 'n_e...               0.97
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 10               0.97               0.97               0.97
# 13               0.97               0.97               0.97
# 9                0.97               0.97               0.96
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 10               0.98             0.97            0.00                1
# 13               0.98             0.97            0.00                2
# 9                0.98             0.97            0.00                3

# %%
# grid_search.predict(x_test)

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of Bagging classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of Bagging classifie on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of Bagging classifier on training set: 0.9724
# Accuracy of Bagging classifie on test set: 0.9660
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1060
#            1       0.97      0.97      0.97      1060
#
#     accuracy                           0.97      2120
#    macro avg       0.97      0.97      0.97      2120
# weighted avg       0.97      0.97      0.97      2120

# %%
acc_train2_bagging = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_bagging = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
# importances = bagging.feature_importances_

# # Sort the feature importances in descending order
# indices = np.argsort(importances)[::-1]
# feature_names = data_resampled.columns[1:]
# names = [feature_names[i] for i in indices]

# importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# # Sort the dataframe by importance
# importance_df.sort_values(by='importance', ascending=False, inplace=True)

# # Print the top 10 features
# print(importance_df.head(10))

# fi_bagging = importance_df

# %%
# # Create plot
# plt.figure()

# # Create plot title
# plt.title("Feature Importance")

# # Add bars
# plt.bar(range(X_train.shape[1]), importances[indices])

# # Add feature names as x-axis labels
# plt.xticks(range(X_train.shape[1]), names, rotation=90)

# # Show plot
# plt.show()

# %% [markdown]
# ### Extra trees

# %% [markdown]
# #### Train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

X_holdout = X_test
y_holdout = y_test

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

etree = ExtraTreesClassifier(random_state=random_seed)
etree.fit(X_train_transformed, y_train_transformed)
print('Accuracy of Extra Trees classifier on training set: {:.4f}'.format(etree.score(X_train_transformed, y_train_transformed)))
print('Accuracy of Extra Trees classifier on test set: {:.4f}'.format(etree.score(X_test_transformed, y_test_transformed)))

pred = etree.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, etree.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=etree.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of Extra Trees classifier on training set: 1.0000
# Accuracy of Extra Trees classifier on test set: 0.9858
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      1060
#            1       0.98      0.99      0.99      1060
#
#     accuracy                           0.99      2120
#    macro avg       0.99      0.99      0.99      2120
# weighted avg       0.99      0.99      0.99      2120

# %%
acc_train1_etree = etree.score(X_train_transformed, y_train_transformed)
acc_test1_etree = etree.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Cross validation for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_estimators': [10, 50, 100, 150],
              'max_depth': [None, 5, 10, 20],
              'min_samples_split': [2, 5, 10]}

# %%
grid_search = GridSearchCV(etree, param_grid, cv=5)
grid_search.fit(X_test_transformed, y_test_transformed)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesClassifier(random_state=42),
#              param_grid={'max_depth': [None, 5, 10, 20],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 50, 100, 150]})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 100}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 38           0.16          0.00             0.01            0.00
# 7            0.23          0.00             0.02            0.00
# 43           0.23          0.00             0.02            0.00
#
#    param_max_depth param_min_samples_split param_n_estimators  \
# 38              20                       2                100
# 7             None                       5                150
# 43              20                       5                150
#
#                                                params  split0_test_score  \
# 38  {'max_depth': 20, 'min_samples_split': 2, 'n_e...               0.99
# 7   {'max_depth': None, 'min_samples_split': 5, 'n...               0.99
# 43  {'max_depth': 20, 'min_samples_split': 5, 'n_e...               0.99
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 38               0.97               0.98               0.98
# 7                0.97               0.98               0.97
# 43               0.97               0.98               0.97
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 38               0.98             0.98            0.00                1
# 7                0.98             0.98            0.01                2
# 43               0.98             0.98            0.01                2

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of Extra Trees classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of Extra Trees classifier on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of Extra Trees classifier on training set: 0.9753
# Accuracy of Extra Trees classifier on test set: 1.0000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1060
#            1       1.00      1.00      1.00      1060
#
#     accuracy                           1.00      2120
#    macro avg       1.00      1.00      1.00      2120
# weighted avg       1.00      1.00      1.00      2120

# %%
acc_train2_etree = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_etree = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
importances = etree.feature_importances_

# Sort the feature importances in descending order
indices = np.argsort(importances)[::-1]
feature_names = data_resampled.columns[1:]
names = [feature_names[i] for i in indices]

importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# Sort the dataframe by importance
importance_df.sort_values(by='importance', ascending=False, inplace=True)

# Print the top 10 features
print(importance_df.head(10))

fi_etree = importance_df
# Out:
#           feature_name  importance
# 30  CHull Surface Area        0.20
# 29           T/W Ratio        0.11
# 28           W/T Ratio        0.08
# 19            Solidity        0.08
# 33         Ellipticity        0.07
# 27           W/L Ratio        0.06
# 13           L/T Ratio        0.05
# 22              Extent        0.03
# 24           Curvature        0.03
# 25        Surface Area        0.02

# %%
# Create plot
plt.figure()

# Create plot title
plt.title("Feature Importance")

# Add bars
plt.bar(range(X_train.shape[1]), importances[indices])

# Add feature names as x-axis labels
plt.xticks(range(X_train.shape[1]), names, rotation=90)

# Show plot
plt.show()

# %% [markdown]
# ### SVC (Support Vector Classification)

# %% [markdown]
# #### Train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

svc = SVC(random_state=random_seed)
svc.fit(X_train_transformed, y_train_transformed)
print('Accuracy of LR classifier on training set: {:.4f}'.format(svc.score(X_train_transformed, y_train_transformed)))
print('Accuracy of LR classifier on test set: {:.4f}'.format(svc.score(X_test_transformed, y_test_transformed)))

pred = svc.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, svc.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svc.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of LR classifier on training set: 0.9823
# Accuracy of LR classifier on test set: 0.9844
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1060
#            1       0.98      0.98      0.98      1060
#
#     accuracy                           0.98      2120
#    macro avg       0.98      0.98      0.98      2120
# weighted avg       0.98      0.98      0.98      2120

# %%
acc_train1_svc = svc.score(X_train_transformed, y_train_transformed)
acc_test1_svc = svc.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Cross validation for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C': [0.1, 1, 10],
              'kernel': ['linear', 'rbf', 'poly'],
              'gamma': [0.01, 0.1, 1]}

# %%
grid_search = GridSearchCV(svc, param_grid, cv=5)
grid_search.fit(X_test_transformed, y_test_transformed)
# Out:
# GridSearchCV(cv=5, estimator=SVC(random_state=42),
#              param_grid={'C': [0.1, 1, 10], 'gamma': [0.01, 0.1, 1],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 22           0.03          0.00             0.02            0.00      10
# 19           0.02          0.00             0.02            0.00      10
# 13           0.04          0.00             0.03            0.00       1
#
#    param_gamma param_kernel                                     params  \
# 22         0.1          rbf   {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 19        0.01          rbf  {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 13         0.1          rbf    {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 22               0.99               0.98               0.99
# 19               0.98               0.97               0.99
# 13               0.98               0.98               0.98
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 22               0.98               0.99             0.99            0.01
# 19               0.97               0.98             0.98            0.01
# 13               0.97               0.98             0.98            0.00
#
#     rank_test_score
# 22                1
# 19                2
# 13                3

# %%
# grid_search.predict(x_test)

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of SV classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of SV classifie on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of SV classifier on training set: 0.9787
# Accuracy of SV classifie on test set: 0.9962
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1060
#            1       1.00      1.00      1.00      1060
#
#     accuracy                           1.00      2120
#    macro avg       1.00      1.00      1.00      2120
# weighted avg       1.00      1.00      1.00      2120

# %%
acc_train2_svc = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_svc = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
# importances = svc.feature_importances_

# # Sort the feature importances in descending order
# indices = np.argsort(importances)[::-1]
# feature_names = data_resampled.columns[1:]
# names = [feature_names[i] for i in indices]

# importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# # Sort the dataframe by importance
# importance_df.sort_values(by='importance', ascending=False, inplace=True)

# # Print the top 10 features
# print(importance_df.head(10))

# fi_svc = importance_df

# %%
# # Create plot
# plt.figure()

# # Create plot title
# plt.title("Feature Importance")

# # Add bars
# plt.bar(range(X_train.shape[1]), importances[indices])

# # Add feature names as x-axis labels
# plt.xticks(range(X_train.shape[1]), names, rotation=90)

# # Show plot
# plt.show()

# %%
### XGBoost

# %%
### Gradient Boosting

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ### Model accuracies

# %%
df = {'model': ['LightGBM', 'AdaBoost', 'Random Forest', 'Bagging', 'Extra Trees', 'SVC'], 
            'train_accuracy': [acc_train1_LBGM, acc_train1_ada, acc_train1_rf, acc_train1_bagging, acc_train1_etree, acc_train1_svc], 
            'test_accuracy': [acc_test1_LBGM, acc_test1_ada, acc_test1_rf, acc_test1_bagging, acc_test1_etree, acc_test1_svc],
            'train_accuracy_CV': [acc_train2_LBGM, acc_train2_ada, acc_train2_rf, acc_train2_bagging, acc_train2_etree, acc_train2_svc], 
            'test_accuracy_CV': [acc_test2_LBGM, acc_test2_ada, acc_test2_rf, acc_test2_bagging, acc_test1_etree, acc_test2_svc]}

accuracy = pd.DataFrame(df)

# %%
df = pd.DataFrame(df)
df
# Out:
#            model  train_accuracy  test_accuracy  train_accuracy_CV  \
# 0       LightGBM            1.00           0.99               1.00
# 1       AdaBoost            0.99           0.99               1.00
# 2  Random Forest            1.00           0.99               0.98
# 3        Bagging            0.97           0.96               0.97
# 4    Extra Trees            1.00           0.99               0.98
# 5            SVC            0.98           0.98               0.98
#
#    test_accuracy_CV
# 0              1.00
# 1              1.00
# 2              1.00
# 3              0.97
# 4              0.99
# 5              1.00

# %%
bar_width = 0.35

models = np.arange(len(df['model']))

plt.bar(models - bar_width/2, df['test_accuracy'], bar_width, 
        color='#FF8F45', label='test accuracy', alpha=0.9)
plt.bar(models + bar_width/2, df['test_accuracy_CV'], bar_width, 
        color='#7CF3A0', label='test accuracy after CV', alpha=0.9)

# for i, v in enumerate(df['test_accuracy']):
#     plt.text(i - bar_width/2, v + 0.01, format(v, '.4f'), ha='center', va='bottom')

# for i, v in enumerate(df['test_accuracy_CV']):
#     plt.text(i + bar_width/2, v + 0.01, format(v, '.4f'), ha='center', va='bottom')

plt.xticks(models, df['model'])
plt.xticks(rotation = 45)
plt.ylim(0.95, 1)
plt.legend()
plt.show()

# %%
# acc_train1_LBGM
# acc_test1_LBGM

# acc_train1_ada
# acc_test1_ada

# acc_train1_rf
# acc_test1_rf

# acc_train1_bagging
# acc_test1_bagging

# acc_train1_svc 
# acc_test1_svc

# acc_train2_LBGM
# acc_test2_LBGM

# acc_train2_ada 
# acc_test2_ada 

# acc_train2_rf
# acc_test2_rf

# acc_train2_bagging 
# acc_test2_bagging

# acc_train2_svc
# acc_test2_svc

# %% [markdown]
# ### Overall feature importance

# %%
fi_LGBM['importance'] = fi_LGBM['importance'] / fi_LGBM['importance'].sum()

# %%
fi_LGBM['rank'] = range(1, fi_LGBM.shape[0]+1)

# %%
fi_LGBM.head(5)
# Out:
#    feature_name  importance  rank
# 33  Ellipticity        0.16     1
# 22       Extent        0.13     2
# 24    Curvature        0.08     3
# 13    L/T Ratio        0.07     4
# 12   Sphericity        0.06     5

# %%
fi_LGBM = fi_LGBM[['feature_name','importance']]
fi_LGBM = fi_LGBM.reset_index(drop=True)

# %%
fi_ada['rank'] = range(1, fi_ada.shape[0]+1)

# %%
fi_ada.head(5)
# Out:
#    feature_name  importance  rank
# 33  Ellipticity        0.18     1
# 22       Extent        0.16     2
# 12   Sphericity        0.10     3
# 29    T/W Ratio        0.10     4
# 4       ELength        0.08     5

# %%
fi_ada = fi_ada[['feature_name','importance']]
fi_ada = fi_ada.reset_index(drop=True)

# %%
fi_rf['rank'] = range(1, fi_rf.shape[0]+1)

# %%
fi_rf.head()
# Out:
#           feature_name  importance  rank
# 30  CHull Surface Area        0.17     1
# 29           T/W Ratio        0.14     2
# 25        Surface Area        0.07     3
# 2              FLength        0.07     4
# 7               Volume        0.06     5

# %%
fi_rf = fi_rf[['feature_name','importance']]
fi_rf = fi_rf.reset_index(drop=True)

# %%
fi_etree['rank'] = range(1, fi_etree.shape[0]+1)

# %%
fi_etree = fi_etree[['feature_name','importance']]
fi_etree = fi_etree.reset_index(drop=True)

# %%
fi = pd.concat([fi_LGBM, fi_ada, fi_rf, fi_etree])

# %%
mean_rank = fi.groupby('feature_name').mean()
mean_rank.sort_values(by='importance', ascending=False, inplace=True)

# %%
mean_rank.head(10)
# Out:
#                     importance
# feature_name
# Ellipticity               0.11
# CHull Surface Area        0.10
# T/W Ratio                 0.09
# Extent                    0.09
# L/T Ratio                 0.06
# Solidity                  0.05
# Curvature                 0.05
# Sphericity                0.05
# ELength                   0.04
# Surface Area              0.04

# %%
import matplotlib.pyplot as plt

mean_rank.reset_index(inplace=True)
mean_rank.head(15).plot(kind='bar', x='feature_name', y='importance')
plt.xlabel('Feature name')
plt.xticks(rotation = 90)
plt.ylabel('Feature importance')
plt.title('Overall feature importance')
plt.show()
