# %% [markdown]
# ## load package

# %%
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.utils import resample

# %%
import lazypredict

# %% [markdown]
# ## import data

# %%
# !pwd
# Out:
# /Users/ricky/Desktop/sp23-ancient-artifacts-team8/3_ml/binary_classification

# %%
master_micro = pd.read_csv("../../0_data/master.csv")

# %%
master_micro
# Out:
#         Unnamed: 0   Id  Img Id      Da      Dp  FWidth  FLength  FThickness  \
# 0                0  104   10708  30.893  38.251  36.878   46.822      10.179
# 1                1   19    5682  27.727  33.375  35.149   40.001       9.029
# 2                2   14    4826  26.726  36.061  30.199   46.332       8.025
# 3                3    1    2812  24.408  36.198  25.039   57.353       5.086
# 4                4   83    9441  22.869  29.388  24.044   39.820       4.390
# ...            ...  ...     ...     ...     ...     ...      ...         ...
# 483648         600  591   13305   0.146   0.155   0.129    0.168       0.129
# 483649         601  464   10826   0.137   0.141   0.128    0.155       0.128
# 483650         602  236    8388   0.144   0.149   0.128    0.163       0.128
# 483651         603  369    9727   0.148   0.154   0.126    0.179       0.126
# 483652         604  481   11134   0.142   0.154   0.126    0.186       0.126
#
#         ELength  EThickness  ...  T/W Ratio  CHull Surface Area   Sieve  \
# 0        44.168      10.102  ...      0.276            3211.655  23.529
# 1        39.022       7.978  ...      0.257            2547.278  22.089
# 2        47.365       7.753  ...      0.266            2571.497  19.112
# 3        50.536       4.904  ...      0.203            2001.165  15.063
# 4        38.568       3.948  ...      0.183            1745.237  14.217
# ...         ...         ...  ...        ...                 ...     ...
# 483648    0.166       0.131  ...      1.000               0.069   0.129
# 483649    0.147       0.127  ...      1.000               0.060   0.128
# 483650    0.156       0.132  ...      1.000               0.065   0.128
# 483651    0.174       0.126  ...      1.000               0.069   0.126
# 483652    0.173       0.119  ...      1.000               0.065   0.126
#
#         Angularity  Ellipticity  Fiber Length  Fiber Width  Krumbein Rnd  \
# 0           19.392        4.372        49.768       22.823         0.214
# 1           20.688        4.891        37.445        5.128         0.214
# 2           21.250        6.110        52.384       17.379         0.219
# 3           18.233       10.304        51.467       17.096         0.251
# 4           17.086        9.769        36.426        3.135         0.276
# ...            ...          ...           ...          ...           ...
# 483648      55.000        1.271         0.000        0.000           NaN
# 483649      63.750        1.164         0.000        0.000           NaN
# 483650      56.667        1.180         0.000        0.000           NaN
# 483651      56.667        1.383         0.000        0.000           NaN
# 483652      55.714        1.450         0.000        0.000           NaN
#
#         size_micro  type_micro
# 0          unknown      lithic
# 1          unknown      lithic
# 2          unknown      lithic
# 3          unknown      lithic
# 4          unknown      lithic
# ...            ...         ...
# 483648         4mm        soil
# 483649         4mm        soil
# 483650         4mm        soil
# 483651         4mm        soil
# 483652         4mm        soil
#
# [483653 rows x 51 columns]

# %%
micro = master_micro[(master_micro['size_micro']=="1mm") | (master_micro['type_micro']=="lithic")].iloc[: , 3:]

# %%
pd.set_option('display.max_columns', None)
micro
# Out:
#             Da      Dp  FWidth  FLength  FThickness  ELength  EThickness  \
# 0       30.893  38.251  36.878   46.822      10.179   44.168      10.102
# 1       27.727  33.375  35.149   40.001       9.029   39.022       7.978
# 2       26.726  36.061  30.199   46.332       8.025   47.365       7.753
# 3       24.408  36.198  25.039   57.353       5.086   50.536       4.904
# 4       22.869  29.388  24.044   39.820       4.390   38.568       3.948
# ...        ...     ...     ...      ...         ...      ...         ...
# 478703   0.220   0.301   0.277    0.377       0.125    0.379       0.115
# 478704   0.148   0.162   0.125    0.192       0.125    0.181       0.124
# 478705   0.178   0.191   0.148    0.259       0.125    0.268       0.120
# 478706   0.149   0.164   0.125    0.194       0.125    0.189       0.118
# 478707   0.130   0.136   0.125    0.153       0.125    0.142       0.120
#
#         EWidth    Volume     Area  Perimeter  CHull  Area  CHull Perimeter  \
# 0       34.444  9202.973  749.562    120.170      802.914          108.399
# 1       34.108  6646.859  603.785    104.849      636.820           99.590
# 2       28.230  5879.233  560.995    113.290      642.874          100.583
# 3       23.943  3824.409  467.900    113.719      500.291          108.846
# 4       22.535  2200.862  410.744     92.327      436.309           89.254
# ...        ...       ...      ...        ...          ...              ...
# 478703   0.259     0.007    0.038      0.945        0.047            0.857
# 478704   0.124     0.002    0.017      0.509        0.018            0.507
# 478705   0.151     0.003    0.025      0.601        0.025            0.600
# 478706   0.118     0.002    0.017      0.515        0.018            0.508
# 478707   0.120     0.001    0.013      0.428        0.014            0.427
#
#         Sphericity  L/T Ratio  T/L Aspect Ratio  Compactness  Roundness  \
# 0            0.808      4.600             0.217        0.660      0.435
# 1            0.831      4.430             0.226        0.693      0.480
# 2            0.741      5.774             0.173        0.577      0.333
# 3            0.674     11.276             0.089        0.426      0.181
# 4            0.778      9.070             0.110        0.574      0.330
# ...            ...        ...               ...          ...        ...
# 478703       0.731      3.008             0.332        0.584      0.341
# 478704       0.913      1.536             0.651        0.769      0.591
# 478705       0.931      2.073             0.482        0.686      0.471
# 478706       0.908      1.554             0.643        0.766      0.587
# 478707       0.958      1.225             0.816        0.852      0.725
#
#         Ellipse Ratio  Circularity  Solidity  Concavity  Convexity  Extent  \
# 0               0.229        0.652     0.934      0.066      0.902   1.573
# 1               0.204        0.690     0.948      0.052      0.950   1.672
# 2               0.164        0.549     0.873      0.127      0.888   1.509
# 3               0.097        0.455     0.935      0.065      0.957   1.604
# 4               0.102        0.606     0.941      0.059      0.967   2.350
# ...               ...          ...       ...        ...        ...     ...
# 478703          0.303        0.535     0.814      0.186      0.907   0.806
# 478704          0.682        0.834     0.974      0.026      0.997   0.713
# 478705          0.447        0.866     0.994      0.006      0.999   0.767
# 478706          0.623        0.825     0.954      0.046      0.986   0.716
# 478707          0.845        0.917     0.988      0.012      0.998   0.698
#
#         hash  Transparency  Curvature  Surface Area Filter0 Filter1 Filter2  \
# 0          0         0.081      0.000      2998.247  Reject  Reject  Reject
# 1          0         0.126      0.000      2415.141  Reject  Reject  Reject
# 2          0         0.096      0.000      2243.981  Reject  Reject  Reject
# 3          0         0.088      0.000      1871.602  Reject  Reject  Reject
# 4          0         0.077      0.000      1642.977  Reject  Reject  Reject
# ...      ...           ...        ...           ...     ...     ...     ...
# 478703     0         0.506      0.393         0.152  Reject  Reject  Reject
# 478704     0         0.443      0.296         0.069  Reject  Reject  Reject
# 478705     0         0.354      0.000         0.100  Reject  Reject  Reject
# 478706     0         0.535      0.000         0.070  Reject  Reject  Reject
# 478707     0         0.431      0.000         0.053  Reject  Reject  Reject
#
#        Filter3 Filter4 Filter5 Filter6  L/W Ratio  W/L Ratio  W/T Ratio  \
# 0       Reject  Reject  Reject  Reject      1.270      0.788      3.623
# 1       Reject  Reject  Reject  Reject      1.138      0.879      3.893
# 2       Reject  Reject  Reject  Reject      1.534      0.652      3.763
# 3       Reject  Reject  Reject  Reject      2.291      0.437      4.923
# 4       Reject  Reject  Reject  Reject      1.656      0.604      5.477
# ...        ...     ...     ...     ...        ...        ...        ...
# 478703  Reject  Reject  Reject  Reject      1.360      0.735      2.211
# 478704  Reject  Reject  Reject  Reject      1.536      0.651      1.000
# 478705  Reject  Reject  Reject  Reject      1.753      0.570      1.183
# 478706  Reject  Reject  Reject  Reject      1.554      0.643      1.000
# 478707  Reject  Reject  Reject  Reject      1.225      0.816      1.000
#
#         T/W Ratio  CHull Surface Area   Sieve  Angularity  Ellipticity  \
# 0           0.276            3211.655  23.529      19.392        4.372
# 1           0.257            2547.278  22.089      20.688        4.891
# 2           0.266            2571.497  19.112      21.250        6.110
# 3           0.203            2001.165  15.063      18.233       10.304
# 4           0.183            1745.237  14.217      17.086        9.769
# ...           ...                 ...     ...         ...          ...
# 478703      0.452               0.187   0.201      67.778        3.305
# 478704      1.000               0.071   0.125      47.143        1.467
# 478705      0.846               0.100   0.137      60.000        2.237
# 478706      1.000               0.073   0.125      55.000        1.606
# 478707      1.000               0.054   0.125      61.667        1.183
#
#         Fiber Length  Fiber Width  Krumbein Rnd size_micro type_micro
# 0             49.768       22.823         0.214    unknown     lithic
# 1             37.445        5.128         0.214    unknown     lithic
# 2             52.384       17.379         0.219    unknown     lithic
# 3             51.467       17.096         0.251    unknown     lithic
# 4             36.426        3.135         0.276    unknown     lithic
# ...              ...          ...           ...        ...        ...
# 478703         0.598        0.065           NaN        1mm       soil
# 478704         0.000        0.000           NaN        1mm       soil
# 478705         0.000        0.000           NaN        1mm       soil
# 478706         0.000        0.000           NaN        1mm       soil
# 478707         0.000        0.000           NaN        1mm       soil
#
# [15490 rows x 48 columns]

# %% [markdown]
# ## data processing

# %% [markdown]
# ### Other processing

# %%
# Drop the columns (filter1, filter2, ...)
to_drop = micro.filter(regex='^Filter').columns
micro = micro.drop(columns=to_drop)
micro
# Out:
#             Da      Dp  FWidth  FLength  FThickness  ELength  EThickness  \
# 0       30.893  38.251  36.878   46.822      10.179   44.168      10.102
# 1       27.727  33.375  35.149   40.001       9.029   39.022       7.978
# 2       26.726  36.061  30.199   46.332       8.025   47.365       7.753
# 3       24.408  36.198  25.039   57.353       5.086   50.536       4.904
# 4       22.869  29.388  24.044   39.820       4.390   38.568       3.948
# ...        ...     ...     ...      ...         ...      ...         ...
# 478703   0.220   0.301   0.277    0.377       0.125    0.379       0.115
# 478704   0.148   0.162   0.125    0.192       0.125    0.181       0.124
# 478705   0.178   0.191   0.148    0.259       0.125    0.268       0.120
# 478706   0.149   0.164   0.125    0.194       0.125    0.189       0.118
# 478707   0.130   0.136   0.125    0.153       0.125    0.142       0.120
#
#         EWidth    Volume     Area  Perimeter  CHull  Area  CHull Perimeter  \
# 0       34.444  9202.973  749.562    120.170      802.914          108.399
# 1       34.108  6646.859  603.785    104.849      636.820           99.590
# 2       28.230  5879.233  560.995    113.290      642.874          100.583
# 3       23.943  3824.409  467.900    113.719      500.291          108.846
# 4       22.535  2200.862  410.744     92.327      436.309           89.254
# ...        ...       ...      ...        ...          ...              ...
# 478703   0.259     0.007    0.038      0.945        0.047            0.857
# 478704   0.124     0.002    0.017      0.509        0.018            0.507
# 478705   0.151     0.003    0.025      0.601        0.025            0.600
# 478706   0.118     0.002    0.017      0.515        0.018            0.508
# 478707   0.120     0.001    0.013      0.428        0.014            0.427
#
#         Sphericity  L/T Ratio  T/L Aspect Ratio  Compactness  Roundness  \
# 0            0.808      4.600             0.217        0.660      0.435
# 1            0.831      4.430             0.226        0.693      0.480
# 2            0.741      5.774             0.173        0.577      0.333
# 3            0.674     11.276             0.089        0.426      0.181
# 4            0.778      9.070             0.110        0.574      0.330
# ...            ...        ...               ...          ...        ...
# 478703       0.731      3.008             0.332        0.584      0.341
# 478704       0.913      1.536             0.651        0.769      0.591
# 478705       0.931      2.073             0.482        0.686      0.471
# 478706       0.908      1.554             0.643        0.766      0.587
# 478707       0.958      1.225             0.816        0.852      0.725
#
#         Ellipse Ratio  Circularity  Solidity  Concavity  Convexity  Extent  \
# 0               0.229        0.652     0.934      0.066      0.902   1.573
# 1               0.204        0.690     0.948      0.052      0.950   1.672
# 2               0.164        0.549     0.873      0.127      0.888   1.509
# 3               0.097        0.455     0.935      0.065      0.957   1.604
# 4               0.102        0.606     0.941      0.059      0.967   2.350
# ...               ...          ...       ...        ...        ...     ...
# 478703          0.303        0.535     0.814      0.186      0.907   0.806
# 478704          0.682        0.834     0.974      0.026      0.997   0.713
# 478705          0.447        0.866     0.994      0.006      0.999   0.767
# 478706          0.623        0.825     0.954      0.046      0.986   0.716
# 478707          0.845        0.917     0.988      0.012      0.998   0.698
#
#         hash  Transparency  Curvature  Surface Area  L/W Ratio  W/L Ratio  \
# 0          0         0.081      0.000      2998.247      1.270      0.788
# 1          0         0.126      0.000      2415.141      1.138      0.879
# 2          0         0.096      0.000      2243.981      1.534      0.652
# 3          0         0.088      0.000      1871.602      2.291      0.437
# 4          0         0.077      0.000      1642.977      1.656      0.604
# ...      ...           ...        ...           ...        ...        ...
# 478703     0         0.506      0.393         0.152      1.360      0.735
# 478704     0         0.443      0.296         0.069      1.536      0.651
# 478705     0         0.354      0.000         0.100      1.753      0.570
# 478706     0         0.535      0.000         0.070      1.554      0.643
# 478707     0         0.431      0.000         0.053      1.225      0.816
#
#         W/T Ratio  T/W Ratio  CHull Surface Area   Sieve  Angularity  \
# 0           3.623      0.276            3211.655  23.529      19.392
# 1           3.893      0.257            2547.278  22.089      20.688
# 2           3.763      0.266            2571.497  19.112      21.250
# 3           4.923      0.203            2001.165  15.063      18.233
# 4           5.477      0.183            1745.237  14.217      17.086
# ...           ...        ...                 ...     ...         ...
# 478703      2.211      0.452               0.187   0.201      67.778
# 478704      1.000      1.000               0.071   0.125      47.143
# 478705      1.183      0.846               0.100   0.137      60.000
# 478706      1.000      1.000               0.073   0.125      55.000
# 478707      1.000      1.000               0.054   0.125      61.667
#
#         Ellipticity  Fiber Length  Fiber Width  Krumbein Rnd size_micro  \
# 0             4.372        49.768       22.823         0.214    unknown
# 1             4.891        37.445        5.128         0.214    unknown
# 2             6.110        52.384       17.379         0.219    unknown
# 3            10.304        51.467       17.096         0.251    unknown
# 4             9.769        36.426        3.135         0.276    unknown
# ...             ...           ...          ...           ...        ...
# 478703        3.305         0.598        0.065           NaN        1mm
# 478704        1.467         0.000        0.000           NaN        1mm
# 478705        2.237         0.000        0.000           NaN        1mm
# 478706        1.606         0.000        0.000           NaN        1mm
# 478707        1.183         0.000        0.000           NaN        1mm
#
#        type_micro
# 0          lithic
# 1          lithic
# 2          lithic
# 3          lithic
# 4          lithic
# ...           ...
# 478703       soil
# 478704       soil
# 478705       soil
# 478706       soil
# 478707       soil
#
# [15490 rows x 41 columns]

# %%
micro = micro.drop(columns=['hash', 'size_micro', 'Krumbein Rnd']) #'Krumbein Rnd'
micro
# Out:
#             Da      Dp  FWidth  FLength  FThickness  ELength  EThickness  \
# 0       30.893  38.251  36.878   46.822      10.179   44.168      10.102
# 1       27.727  33.375  35.149   40.001       9.029   39.022       7.978
# 2       26.726  36.061  30.199   46.332       8.025   47.365       7.753
# 3       24.408  36.198  25.039   57.353       5.086   50.536       4.904
# 4       22.869  29.388  24.044   39.820       4.390   38.568       3.948
# ...        ...     ...     ...      ...         ...      ...         ...
# 478703   0.220   0.301   0.277    0.377       0.125    0.379       0.115
# 478704   0.148   0.162   0.125    0.192       0.125    0.181       0.124
# 478705   0.178   0.191   0.148    0.259       0.125    0.268       0.120
# 478706   0.149   0.164   0.125    0.194       0.125    0.189       0.118
# 478707   0.130   0.136   0.125    0.153       0.125    0.142       0.120
#
#         EWidth    Volume     Area  Perimeter  CHull  Area  CHull Perimeter  \
# 0       34.444  9202.973  749.562    120.170      802.914          108.399
# 1       34.108  6646.859  603.785    104.849      636.820           99.590
# 2       28.230  5879.233  560.995    113.290      642.874          100.583
# 3       23.943  3824.409  467.900    113.719      500.291          108.846
# 4       22.535  2200.862  410.744     92.327      436.309           89.254
# ...        ...       ...      ...        ...          ...              ...
# 478703   0.259     0.007    0.038      0.945        0.047            0.857
# 478704   0.124     0.002    0.017      0.509        0.018            0.507
# 478705   0.151     0.003    0.025      0.601        0.025            0.600
# 478706   0.118     0.002    0.017      0.515        0.018            0.508
# 478707   0.120     0.001    0.013      0.428        0.014            0.427
#
#         Sphericity  L/T Ratio  T/L Aspect Ratio  Compactness  Roundness  \
# 0            0.808      4.600             0.217        0.660      0.435
# 1            0.831      4.430             0.226        0.693      0.480
# 2            0.741      5.774             0.173        0.577      0.333
# 3            0.674     11.276             0.089        0.426      0.181
# 4            0.778      9.070             0.110        0.574      0.330
# ...            ...        ...               ...          ...        ...
# 478703       0.731      3.008             0.332        0.584      0.341
# 478704       0.913      1.536             0.651        0.769      0.591
# 478705       0.931      2.073             0.482        0.686      0.471
# 478706       0.908      1.554             0.643        0.766      0.587
# 478707       0.958      1.225             0.816        0.852      0.725
#
#         Ellipse Ratio  Circularity  Solidity  Concavity  Convexity  Extent  \
# 0               0.229        0.652     0.934      0.066      0.902   1.573
# 1               0.204        0.690     0.948      0.052      0.950   1.672
# 2               0.164        0.549     0.873      0.127      0.888   1.509
# 3               0.097        0.455     0.935      0.065      0.957   1.604
# 4               0.102        0.606     0.941      0.059      0.967   2.350
# ...               ...          ...       ...        ...        ...     ...
# 478703          0.303        0.535     0.814      0.186      0.907   0.806
# 478704          0.682        0.834     0.974      0.026      0.997   0.713
# 478705          0.447        0.866     0.994      0.006      0.999   0.767
# 478706          0.623        0.825     0.954      0.046      0.986   0.716
# 478707          0.845        0.917     0.988      0.012      0.998   0.698
#
#         Transparency  Curvature  Surface Area  L/W Ratio  W/L Ratio  \
# 0              0.081      0.000      2998.247      1.270      0.788
# 1              0.126      0.000      2415.141      1.138      0.879
# 2              0.096      0.000      2243.981      1.534      0.652
# 3              0.088      0.000      1871.602      2.291      0.437
# 4              0.077      0.000      1642.977      1.656      0.604
# ...              ...        ...           ...        ...        ...
# 478703         0.506      0.393         0.152      1.360      0.735
# 478704         0.443      0.296         0.069      1.536      0.651
# 478705         0.354      0.000         0.100      1.753      0.570
# 478706         0.535      0.000         0.070      1.554      0.643
# 478707         0.431      0.000         0.053      1.225      0.816
#
#         W/T Ratio  T/W Ratio  CHull Surface Area   Sieve  Angularity  \
# 0           3.623      0.276            3211.655  23.529      19.392
# 1           3.893      0.257            2547.278  22.089      20.688
# 2           3.763      0.266            2571.497  19.112      21.250
# 3           4.923      0.203            2001.165  15.063      18.233
# 4           5.477      0.183            1745.237  14.217      17.086
# ...           ...        ...                 ...     ...         ...
# 478703      2.211      0.452               0.187   0.201      67.778
# 478704      1.000      1.000               0.071   0.125      47.143
# 478705      1.183      0.846               0.100   0.137      60.000
# 478706      1.000      1.000               0.073   0.125      55.000
# 478707      1.000      1.000               0.054   0.125      61.667
#
#         Ellipticity  Fiber Length  Fiber Width type_micro
# 0             4.372        49.768       22.823     lithic
# 1             4.891        37.445        5.128     lithic
# 2             6.110        52.384       17.379     lithic
# 3            10.304        51.467       17.096     lithic
# 4             9.769        36.426        3.135     lithic
# ...             ...           ...          ...        ...
# 478703        3.305         0.598        0.065       soil
# 478704        1.467         0.000        0.000       soil
# 478705        2.237         0.000        0.000       soil
# 478706        1.606         0.000        0.000       soil
# 478707        1.183         0.000        0.000       soil
#
# [15490 rows x 38 columns]

# %% [markdown]
# ### Redersampling

# %% [markdown]
# https://machinelearningmastery.com/undersampling-algorithms-for-imbalanced-classification/
# https://www.analyticsvidhya.com/blog/2020/07/10-techniques-to-deal-with-class-imbalance-in-machine-learning/
# https://towardsdatascience.com/imbalanced-classification-in-python-smote-tomek-links-method-6e48dfe69bbc

# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in /Users/ricky/opt/anaconda3/lib/python3.7/site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in /Users/ricky/opt/anaconda3/lib/python3.7/site-packages (from imblearn) (0.10.1)
# Requirement already satisfied: scipy>=1.3.2 in /Users/ricky/opt/anaconda3/lib/python3.7/site-packages (from imbalanced-learn->imblearn) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/ricky/opt/anaconda3/lib/python3.7/site-packages (from imbalanced-learn->imblearn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /Users/ricky/opt/anaconda3/lib/python3.7/site-packages (from imbalanced-learn->imblearn) (1.21.5)
# Requirement already satisfied: joblib>=1.1.1 in /Users/ricky/opt/anaconda3/lib/python3.7/site-packages (from imbalanced-learn->imblearn) (1.2.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /Users/ricky/opt/anaconda3/lib/python3.7/site-packages (from imbalanced-learn->imblearn) (1.0.2)

# %%
# from imblearn.combine import SMOTETomek
from imblearn.under_sampling import TomekLinks
from imblearn.combine import SMOTETomek
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.under_sampling import CondensedNearestNeighbour
from collections import Counter

# %%
micro.groupby('type_micro').describe()
# Out:
#                  Da                                                          \
#               count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic       5299.0  0.408032  1.629126  0.040  0.161  0.193  0.251  30.893
# soil        10191.0  0.859683  0.593296  0.104  0.287  0.624  1.356   3.783
#
#                  Dp                                                          \
#               count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic       5299.0  0.533303  2.193727  0.058  0.198  0.250  0.330  38.251
# soil        10191.0  0.930845  0.639726  0.131  0.316  0.696  1.459   4.326
#
#              FWidth                                                          \
#               count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic       5299.0  0.351058  1.685466  0.021  0.107  0.138  0.194  36.878
# soil        10191.0  0.841913  0.582515  0.125  0.282  0.621  1.338   4.096
#
#             FLength                                                          \
#               count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic       5299.0  0.731248  3.023436  0.074  0.254  0.339  0.458  57.353
# soil        10191.0  1.177975  0.829635  0.136  0.398  0.914  1.847   5.376
#
#            FThickness                                                          \
#                 count      mean       std    min    25%    50%    75%     max
# type_micro
# lithic         5299.0  0.220404  0.661258  0.021  0.102  0.130  0.170  16.445
# soil          10191.0  0.603765  0.424010  0.125  0.205  0.436  0.969   2.614
#
#             ELength                                                           \
#               count      mean       std    min    25%    50%     75%     max
# type_micro
# lithic       5299.0  0.700690  2.950370  0.041  0.238  0.315  0.4315  50.536
# soil        10191.0  1.164056  0.824259  0.132  0.392  0.913  1.8190   5.341
#
#            EThickness                                                   \
#                 count      mean       std    min    25%    50%     75%
# type_micro
# lithic         5299.0  0.208487  0.623842  0.015  0.096  0.122  0.1630
# soil          10191.0  0.600125  0.424563  0.084  0.201  0.432  0.9675
#
#                      EWidth                                                   \
#                max    count      mean       std    min     25%    50%    75%
# type_micro
# lithic      16.227   5299.0  0.336963  1.629089  0.015  0.1000  0.130  0.186
# soil         2.526  10191.0  0.838245  0.581375  0.096  0.2795  0.616  1.334
#
#                      Volume                                              \
#                max    count       mean         std    min    25%    50%
# type_micro
# lithic      34.444   5299.0  16.602042  236.156080  0.000  0.002  0.003
# soil         4.120  10191.0   0.774874    1.082688  0.001  0.012  0.124
#
#                                  Area                                     \
#                75%       max    count      mean        std    min    25%
# type_micro
# lithic      0.0070  9202.973   5299.0  2.214862  25.126003  0.001  0.020
# soil        1.2115    29.083  10191.0  0.856886   0.917978  0.008  0.065
#
#                                    Perimeter                             \
#               50%     75%      max     count      mean       std    min
# type_micro
# lithic      0.029  0.0490  749.562    5299.0  1.675445  6.891800  0.183
# soil        0.305  1.4445   11.242   10191.0  2.924336  2.009759  0.411
#
#                                          CHull  Area                       \
#               25%    50%    75%      max       count      mean        std
# type_micro
# lithic      0.623  0.785  1.036  120.170      5299.0  2.402839  27.222648
# soil        0.992  2.186  4.583   13.592     10191.0  0.876348   0.940021
#
#                                                 CHull Perimeter            \
#               min    25%    50%    75%      max           count      mean
# type_micro
# lithic      0.001  0.021  0.031  0.052  802.914          5299.0  1.632610
# soil        0.013  0.067  0.312  1.472   11.900         10191.0  2.889452
#
#                                                            Sphericity  \
#                  std    min    25%    50%     75%      max      count
# type_micro
# lithic      6.573565  0.183  0.622  0.779  1.0260  108.846     5299.0
# soil        1.989992  0.411  0.974  2.116  4.5395   12.960    10191.0
#
#                                                                   L/T Ratio  \
#                 mean       std    min    25%    50%    75%    max     count
# type_micro
# lithic      0.790303  0.117014  0.226  0.726  0.813  0.881  0.981    5299.0
# soil        0.919560  0.048870  0.350  0.907  0.931  0.948  1.000   10191.0
#
#                                                                     \
#                 mean       std    min    25%    50%    75%     max
# type_micro
# lithic      2.962653  1.638428  1.084  1.908  2.535  3.524  19.069
# soil        1.995958  0.560815  1.063  1.646  1.875  2.211  10.318
#
#            T/L Aspect Ratio                                                  \
#                       count      mean       std    min    25%    50%    75%
# type_micro
# lithic               5299.0  0.413635  0.168698  0.052  0.284  0.394  0.524
# soil                10191.0  0.530596  0.116071  0.097  0.452  0.533  0.608
#
#                   Compactness                                           \
#               max       count      mean       std    min    25%    50%
# type_micro
# lithic      0.922      5299.0  0.599855  0.130086  0.194  0.507  0.601
# soil        0.941     10191.0  0.736981  0.074285  0.315  0.693  0.743
#
#                           Roundness                                           \
#                75%    max     count      mean       std    min    25%    50%
# type_micro
# lithic      0.6945  0.941    5299.0  0.376740  0.156491  0.037  0.257  0.361
# soil        0.7890  0.954   10191.0  0.548654  0.106179  0.099  0.480  0.552
#
#                          Ellipse Ratio                                    \
#               75%    max         count      mean       std    min    25%
# type_micro
# lithic      0.482  0.885        5299.0  0.420723  0.182279  0.043  0.280
# soil        0.622  0.909       10191.0  0.532748  0.124785  0.097  0.449
#
#                                 Circularity                                    \
#               50%     75%   max       count      mean       std    min    25%
# type_micro
# lithic      0.402  0.5485  1.00      5299.0  0.638278  0.172553  0.051  0.527
# soil        0.534  0.6150  0.98     10191.0  0.847974  0.082134  0.122  0.823
#
#                                 Solidity                                    \
#               50%    75%    max    count      mean       std    min    25%
# type_micro
# lithic      0.660  0.776  0.962   5299.0  0.943644  0.080178  0.111  0.936
# soil        0.867  0.898  1.000  10191.0  0.971139  0.035763  0.321  0.969
#
#                               Concavity                                  \
#               50%    75%  max     count      mean       std  min    25%
# type_micro
# lithic      0.971  0.988  1.0    5299.0  0.056356  0.080179  0.0  0.012
# soil        0.980  0.987  1.0   10191.0  0.028860  0.035762  0.0  0.013
#
#                                 Convexity                                    \
#               50%    75%    max     count      mean       std    min    25%
# type_micro
# lithic      0.029  0.064  0.889    5299.0  0.991046  0.018609  0.530  0.991
# soil        0.020  0.031  0.679   10191.0  0.986154  0.024902  0.643  0.988
#
#                                 Extent                                    \
#               50%    75%  max    count      mean       std    min    25%
# type_micro
# lithic      0.997  0.999  1.0   5299.0  0.730798  0.187890  0.071  0.653
# soil        0.993  0.996  1.0  10191.0  0.826709  0.138121  0.219  0.743
#
#                                 Transparency                             \
#               50%    75%    max        count      mean       std    min
# type_micro
# lithic      0.711  0.764  3.002       5299.0  0.456355  0.162607  0.000
# soil        0.800  0.882  3.077      10191.0  0.328845  0.127820  0.151
#
#                                        Curvature                           \
#               25%    50%    75%    max     count      mean       std  min
# type_micro
# lithic      0.424  0.512  0.551  0.832    5299.0  0.075975  0.320574  0.0
# soil        0.190  0.330  0.446  0.727   10191.0  0.229309  0.380082  0.0
#
#                                    Surface Area                               \
#             25%  50%    75%    max        count      mean         std    min
# type_micro
# lithic      0.0  0.0  0.000  6.108       5299.0  8.859449  100.504014  0.005
# soil        0.0  0.0  0.348  4.339      10191.0  3.427554    3.671899  0.034
#
#                                           L/W Ratio                      \
#               25%    50%    75%       max     count      mean       std
# type_micro
# lithic      0.082  0.117  0.198  2998.247    5299.0  2.614261  1.261189
# soil        0.258  1.222  5.779    44.967   10191.0  1.411405  0.223905
#
#                                                W/L Ratio                      \
#               min    25%    50%    75%     max     count      mean       std
# type_micro
# lithic      1.084  1.756  2.269  3.102  18.300    5299.0  0.451302  0.166853
# soil        1.058  1.255  1.363  1.512   3.936   10191.0  0.723584  0.097915
#
#                                               W/T Ratio                      \
#               min    25%    50%    75%    max     count      mean       std
# type_micro
# lithic      0.055  0.322  0.441  0.569  0.922    5299.0  1.175189  0.565394
# soil        0.254  0.662  0.734  0.797  0.945   10191.0  1.417583  0.340172
#
#                                             T/W Ratio                      \
#             min    25%    50%    75%    max     count      mean       std
# type_micro
# lithic      1.0  1.000  1.000  1.000  6.841    5299.0  0.930623  0.179607
# soil        1.0  1.204  1.337  1.541  8.415   10191.0  0.734958  0.133567
#
#                                             CHull Surface Area            \
#               min    25%    50%    75%  max              count      mean
# type_micro
# lithic      0.146  1.000  1.000  1.000  1.0             5299.0  9.611345
# soil        0.119  0.649  0.748  0.831  1.0            10191.0  3.505370
#
#                                                                  Sieve  \
#                    std    min    25%    50%     75%       max    count
# type_micro
# lithic      108.890588  0.006  0.086  0.125  0.2100  3211.655   5299.0
# soil          3.760086  0.052  0.268  1.247  5.8885    47.600  10191.0
#
#                                                                      \
#                 mean       std    min    25%    50%     75%     max
# type_micro
# lithic      0.285732  1.145785  0.021  0.107  0.137  0.1835  23.529
# soil        0.722838  0.496046  0.125  0.244  0.535  1.1460   3.355
#
#            Angularity                                                  \
#                 count       mean        std   min     25%   50%   75%
# type_micro
# lithic         5299.0  69.491435  27.561298   0.0  63.333  70.0  85.0
# soil          10191.0  39.633408  16.327922  12.0  24.500  37.5  54.0
#
#                     Ellipticity                                          \
#                 max       count      mean       std   min    25%    50%
# type_micro
# lithic      120.000      5299.0  3.009928  1.868712  1.00  1.824  2.489
# soil         97.143     10191.0  2.004577  0.605951  1.02  1.626  1.873
#
#                            Fiber Length                                       \
#                75%     max        count      mean       std  min  25%    50%
# type_micro
# lithic      3.5765  23.322       5299.0  0.648506  3.047920  0.0  0.0  0.272
# soil        2.2290  10.286      10191.0  0.416860  0.678387  0.0  0.0  0.000
#
#                           Fiber Width                                       \
#               75%     max       count      mean       std  min  25%    50%
# type_micro
# lithic      0.396  52.384      5299.0  0.193938  0.937805  0.0  0.0  0.084
# soil        0.522   5.930     10191.0  0.209435  0.361734  0.0  0.0  0.000
#
#
#               75%     max
# type_micro
# lithic      0.126  22.823
# soil        0.213   2.144

# %%
# define the undersampling method
undersample = SMOTE(sampling_strategy='minority')
# undersample = TomekLinks(sampling_strategy='majority')
# undersample = CondensedNearestNeighbour(n_neighbors=1)

# Separate majority and minority classes
class_column = ['type_micro']
X = micro.drop(columns=class_column)
y = micro[class_column]

X_resampled, y_resampled = undersample.fit_resample(X, y)

# %%
data_resampled = pd.concat([X_resampled, y_resampled], axis=1)

# %%
data_resampled.columns = X.columns.tolist() + ['type_micro']

# %%
data_resampled
# Out:
#               Da         Dp     FWidth    FLength  FThickness    ELength  \
# 0      30.893000  38.251000  36.878000  46.822000   10.179000  44.168000
# 1      27.727000  33.375000  35.149000  40.001000    9.029000  39.022000
# 2      26.726000  36.061000  30.199000  46.332000    8.025000  47.365000
# 3      24.408000  36.198000  25.039000  57.353000    5.086000  50.536000
# 4      22.869000  29.388000  24.044000  39.820000    4.390000  38.568000
# ...          ...        ...        ...        ...         ...        ...
# 20377   0.048263   0.065039   0.023697   0.083671    0.023697   0.089473
# 20378   0.191954   0.281211   0.114573   0.397404    0.114573   0.398789
# 20379   0.168411   0.197201   0.114580   0.258075    0.114580   0.252865
# 20380   0.275304   0.352702   0.232693   0.500315    0.074566   0.504274
# 20381   0.173986   0.248224   0.128885   0.319663    0.128885   0.291346
#
#        EThickness     EWidth       Volume        Area   Perimeter  \
# 0       10.102000  34.444000  9202.973000  749.562000  120.170000
# 1        7.978000  34.108000  6646.859000  603.785000  104.849000
# 2        7.753000  28.230000  5879.233000  560.995000  113.290000
# 3        4.904000  23.943000  3824.409000  467.900000  113.719000
# 4        3.948000  22.535000  2200.862000  410.744000   92.327000
# ...           ...        ...          ...         ...         ...
# 20377    0.024224   0.024224     0.000000    0.001724    0.205170
# 20378    0.097447   0.097447     0.003313    0.029194    0.882886
# 20379    0.110622   0.110622     0.001958    0.022832    0.620435
# 20380    0.070522   0.225693     0.004174    0.059652    1.107671
# 20381    0.116936   0.116936     0.002993    0.023496    0.778133
#
#        CHull  Area  CHull Perimeter  Sphericity  L/T Ratio  T/L Aspect Ratio  \
# 0       802.914000       108.399000    0.808000   4.600000          0.217000
# 1       636.820000        99.590000    0.831000   4.430000          0.226000
# 2       642.874000       100.583000    0.741000   5.774000          0.173000
# 3       500.291000       108.846000    0.674000  11.276000          0.089000
# 4       436.309000        89.254000    0.778000   9.070000          0.110000
# ...            ...              ...         ...        ...               ...
# 20377     0.001724         0.205104    0.742066   3.525316          0.283868
# 20378     0.032883         0.870071    0.683815   3.465781          0.288940
# 20379     0.022832         0.619477    0.855378   2.249210          0.444958
# 20380     0.062826         1.096323    0.783334   6.711343          0.148782
# 20381     0.029957         0.740377    0.717731   2.471534          0.405079
#
#        Compactness  Roundness  Ellipse Ratio  Circularity  Solidity  \
# 0         0.660000   0.435000       0.229000     0.652000  0.934000
# 1         0.693000   0.480000       0.204000     0.690000  0.948000
# 2         0.577000   0.333000       0.164000     0.549000  0.873000
# 3         0.426000   0.181000       0.097000     0.455000  0.935000
# 4         0.574000   0.330000       0.102000     0.606000  0.941000
# ...            ...        ...            ...          ...       ...
# 20377     0.584026   0.340763       0.264289     0.550132  0.999474
# 20378     0.483692   0.234630       0.244125     0.468128  0.891174
# 20379     0.654874   0.428832       0.439463     0.730715  0.987336
# 20380     0.552641   0.305945       0.140519     0.615588  0.943912
# 20381     0.555537   0.314098       0.401993     0.526053  0.813960
#
#        Concavity  Convexity    Extent  Transparency  Curvature  Surface Area  \
# 0       0.066000   0.902000  1.573000      0.081000   0.000000   2998.247000
# 1       0.052000   0.950000  1.672000      0.126000   0.000000   2415.141000
# 2       0.127000   0.888000  1.509000      0.096000   0.000000   2243.981000
# 3       0.065000   0.957000  1.604000      0.088000   0.000000   1871.602000
# 4       0.059000   0.967000  2.350000      0.077000   0.000000   1642.977000
# ...          ...        ...       ...           ...        ...           ...
# 20377   0.000526   0.999934  0.943211      0.000000   0.000000      0.008697
# 20378   0.108826   0.985624  0.637256      0.483074   0.514874      0.117775
# 20379   0.012664   0.999042  0.757790      0.513006   0.000000      0.089369
# 20380   0.056088   0.989826  1.611466      0.533389   0.077641      0.237956
# 20381   0.186040   0.957265  0.605046      0.620217   1.516651      0.094986
#
#        L/W Ratio  W/L Ratio  W/T Ratio  T/W Ratio  CHull Surface Area  \
# 0       1.270000   0.788000   3.623000   0.276000         3211.655000
# 1       1.138000   0.879000   3.893000   0.257000         2547.278000
# 2       1.534000   0.652000   3.763000   0.266000         2571.497000
# 3       2.291000   0.437000   4.923000   0.203000         2001.165000
# 4       1.656000   0.604000   5.477000   0.183000         1745.237000
# ...          ...        ...        ...        ...                 ...
# 20377   3.525316   0.283868   1.000000   1.000000            0.008763
# 20378   3.465781   0.288940   1.000000   1.000000            0.133407
# 20379   2.249210   0.444958   1.000000   1.000000            0.090327
# 20380   2.157506   0.468030   3.133579   0.321182            0.252304
# 20381   2.471534   0.405079   1.000000   1.000000            0.120835
#
#            Sieve  Angularity  Ellipticity  Fiber Length  Fiber Width  \
# 0      23.529000   19.392000     4.372000     49.768000    22.823000
# 1      22.089000   20.688000     4.891000     37.445000     5.128000
# 2      19.112000   21.250000     6.110000     52.384000    17.379000
# 3      15.063000   18.233000    10.304000     51.467000    17.096000
# 4      14.217000   17.086000     9.769000     36.426000     3.135000
# ...          ...         ...          ...           ...          ...
# 20377   0.023697    0.000000     3.792279     12.736457     9.351064
# 20378   0.114573   68.333000     4.096245      0.326347     0.089194
# 20379   0.114580   68.000000     2.275645      0.209402     0.107042
# 20380   0.153956   85.825966     7.142618      0.446229     0.070616
# 20381   0.128885   67.574569     2.489043      0.300513     0.082618
#
#       type_micro
# 0         lithic
# 1         lithic
# 2         lithic
# 3         lithic
# 4         lithic
# ...          ...
# 20377     lithic
# 20378     lithic
# 20379     lithic
# 20380     lithic
# 20381     lithic
#
# [20382 rows x 38 columns]

# %%
data_resampled.groupby('type_micro').describe()
# Out:
#                  Da                                                       \
#               count      mean       std    min    25%      50%       75%
# type_micro
# lithic      10191.0  0.399918  1.543338  0.040  0.162  0.19271  0.248099
# soil        10191.0  0.859683  0.593296  0.104  0.287  0.62400  1.356000
#
#                          Dp                                                \
#                max    count      mean       std    min      25%       50%
# type_micro
# lithic      30.893  10191.0  0.521518  2.071976  0.058  0.19968  0.249042
# soil         3.783  10191.0  0.930845  0.639726  0.131  0.31600  0.696000
#
#                                FWidth                                    \
#                  75%     max    count      mean       std    min    25%
# type_micro
# lithic      0.326923  38.251  10191.0  0.340773  1.578423  0.021  0.107
# soil        1.459000   4.326  10191.0  0.841913  0.582515  0.125  0.282
#
#                                   FLength                                    \
#               50%    75%     max    count      mean       std    min    25%
# type_micro
# lithic      0.137  0.192  36.878  10191.0  0.716384  2.861070  0.074  0.257
# soil        0.621  1.338   4.096  10191.0  1.177975  0.829635  0.136  0.398
#
#                                        FThickness                            \
#                  50%       75%     max      count      mean      std    min
# type_micro
# lithic      0.338446  0.454634  57.353    10191.0  0.218971  0.64456  0.021
# soil        0.914000  1.847000   5.376    10191.0  0.603765  0.42401  0.125
#
#                                                ELength                      \
#               25%       50%       75%     max    count      mean       std
# type_micro
# lithic      0.103  0.129266  0.169428  16.445  10191.0  0.687826  2.809977
# soil        0.205  0.436000  0.969000   2.614  10191.0  1.164056  0.824259
#
#                                                   EThickness            \
#               min       25%    50%    75%     max      count      mean
# type_micro
# lithic      0.041  0.240128  0.315  0.429  50.536    10191.0  0.207071
# soil        0.132  0.392000  0.913  1.819   5.341    10191.0  0.600125
#
#                                                                EWidth  \
#                  std    min       25%    50%     75%     max    count
# type_micro
# lithic      0.608718  0.015  0.096405  0.122  0.1620  16.227  10191.0
# soil        0.424563  0.084  0.201000  0.432  0.9675   2.526  10191.0
#
#                                                                            \
#                 mean       std    min     25%       50%       75%     max
# type_micro
# lithic      0.327554  1.532933  0.015  0.1000  0.129161  0.184972  34.444
# soil        0.838245  0.581375  0.096  0.2795  0.616000  1.334000   4.120
#
#              Volume                                                        \
#               count       mean         std    min    25%    50%       75%
# type_micro
# lithic      10191.0  14.463179  208.440865  0.000  0.002  0.003  0.006593
# soil        10191.0   0.774874    1.082688  0.001  0.012  0.124  1.211500
#
#                          Area                                               \
#                  max    count      mean        std    min       25%    50%
# type_micro
# lithic      9202.973  10191.0  1.997363  22.746533  0.001  0.020898  0.029
# soil          29.083  10191.0  0.856886   0.917978  0.008  0.065000  0.305
#
#                               Perimeter                                    \
#                  75%      max     count      mean       std    min    25%
# type_micro
# lithic      0.048675  749.562   10191.0  1.638426  6.509312  0.183  0.627
# soil        1.444500   11.242   10191.0  2.924336  2.009759  0.411  0.992
#
#                                   CHull  Area                              \
#               50%    75%      max       count      mean        std    min
# type_micro
# lithic      0.783  1.026  120.170     10191.0  2.161028  24.565427  0.001
# soil        2.186  4.583   13.592     10191.0  0.876348   0.940021  0.013
#
#                                                CHull Perimeter            \
#                  25%    50%       75%      max           count      mean
# type_micro
# lithic      0.021959  0.031  0.051365  802.914         10191.0  1.599781
# soil        0.067000  0.312  1.472000   11.900         10191.0  2.889452
#
#                                                                 Sphericity  \
#                  std    min    25%       50%       75%      max      count
# type_micro
# lithic      6.232134  0.183  0.625  0.777024  1.015855  108.846    10191.0
# soil        1.989992  0.411  0.974  2.116000  4.539500   12.960    10191.0
#
#                                                                       \
#                 mean       std    min       25%    50%    75%    max
# type_micro
# lithic      0.791065  0.114152  0.226  0.729257  0.812  0.879  0.981
# soil        0.919560  0.048870  0.350  0.907000  0.931  0.948  1.000
#
#            L/T Ratio                                                     \
#                count      mean       std    min       25%    50%    75%
# type_micro
# lithic       10191.0  2.960714  1.590726  1.084  1.927738  2.547  3.524
# soil         10191.0  1.995958  0.560815  1.063  1.646000  1.875  2.211
#
#                    T/L Aspect Ratio                                    \
#                max            count      mean       std    min    25%
# type_micro
# lithic      19.069          10191.0  0.412092  0.166816  0.052  0.284
# soil        10.318          10191.0  0.530596  0.116071  0.097  0.452
#
#                                       Compactness                             \
#                  50%       75%    max       count      mean       std    min
# type_micro
# lithic      0.393144  0.519159  0.922     10191.0  0.599157  0.127654  0.194
# soil        0.533000  0.608000  0.941     10191.0  0.736981  0.074285  0.315
#
#                                           Roundness                      \
#                  25%    50%    75%    max     count      mean       std
# type_micro
# lithic      0.508444  0.599  0.692  0.941   10191.0  0.375512  0.153863
# soil        0.693000  0.743  0.789  0.954   10191.0  0.548654  0.106179
#
#                                                  Ellipse Ratio            \
#               min    25%       50%    75%    max         count      mean
# type_micro
# lithic      0.037  0.259  0.358993  0.479  0.885       10191.0  0.418907
# soil        0.099  0.480  0.552000  0.622  0.909       10191.0  0.532748
#
#                                                           Circularity  \
#                  std    min    25%       50%    75%   max       count
# type_micro
# lithic      0.180106  0.043  0.280  0.400466  0.541  1.00     10191.0
# soil        0.124785  0.097  0.449  0.534000  0.615  0.98     10191.0
#
#                                                                          \
#                 mean       std    min       25%       50%    75%    max
# type_micro
# lithic      0.639117  0.168999  0.051  0.532007  0.659364  0.773  0.962
# soil        0.847974  0.082134  0.122  0.823000  0.867000  0.898  1.000
#
#            Solidity                                                         \
#               count      mean       std    min       25%   50%    75%  max
# type_micro
# lithic      10191.0  0.945342  0.074643  0.111  0.936694  0.97  0.987  1.0
# soil        10191.0  0.971139  0.035763  0.321  0.969000  0.98  0.987  1.0
#
#            Concavity                                                         \
#                count      mean       std  min    25%   50%       75%    max
# type_micro
# lithic       10191.0  0.054659  0.074643  0.0  0.013  0.03  0.063306  0.889
# soil         10191.0  0.028860  0.035762  0.0  0.013  0.02  0.031000  0.679
#
#            Convexity                                                          \
#                count      mean       std    min    25%       50%    75%  max
# type_micro
# lithic       10191.0  0.991504  0.016669  0.530  0.991  0.997036  0.999  1.0
# soil         10191.0  0.986154  0.024902  0.643  0.988  0.993000  0.996  1.0
#
#              Extent                                                            \
#               count      mean       std    min    25%       50%    75%    max
# type_micro
# lithic      10191.0  0.731498  0.182953  0.071  0.657  0.710851  0.760  3.002
# soil        10191.0  0.826709  0.138121  0.219  0.743  0.800000  0.882  3.077
#
#            Transparency                                                       \
#                   count      mean       std    min   25%   50%    75%    max
# type_micro
# lithic          10191.0  0.455739  0.159667  0.000  0.43  0.51  0.548  0.832
# soil            10191.0  0.328845  0.127820  0.151  0.19  0.33  0.446  0.727
#
#            Curvature                                                   \
#                count      mean       std  min  25%  50%    75%    max
# type_micro
# lithic       10191.0  0.068034  0.281471  0.0  0.0  0.0  0.000  6.108
# soil         10191.0  0.229309  0.380082  0.0  0.0  0.0  0.348  4.339
#
#            Surface Area                                                      \
#                   count      mean        std    min       25%    50%    75%
# type_micro
# lithic          10191.0  7.989449  90.986138  0.005  0.082955  0.117  0.194
# soil            10191.0  3.427554   3.671899  0.034  0.258000  1.222  5.779
#
#                      L/W Ratio                                                 \
#                  max     count      mean       std    min       25%       50%
# type_micro
# lithic      2998.247   10191.0  2.616054  1.229931  1.084  1.783398  2.280671
# soil          44.967   10191.0  1.411405  0.223905  1.058  1.255000  1.363000
#
#                           W/L Ratio                                    \
#               75%     max     count      mean       std    min    25%
# type_micro
# lithic      3.082  18.300   10191.0  0.449308  0.164078  0.055  0.325
# soil        1.512   3.936   10191.0  0.723584  0.097915  0.254  0.662
#
#                                    W/T Ratio                                  \
#                  50%    75%    max     count      mean       std  min    25%
# type_micro
# lithic      0.439032  0.563  0.922   10191.0  1.174112  0.558206  1.0  1.000
# soil        0.734000  0.797  0.945   10191.0  1.417583  0.340172  1.0  1.204
#
#                                 T/W Ratio                                    \
#               50%    75%    max     count      mean       std    min    25%
# type_micro
# lithic      1.000  1.000  6.841   10191.0  0.931126  0.177772  0.146  1.000
# soil        1.337  1.541  8.415   10191.0  0.734958  0.133567  0.119  0.649
#
#                               CHull Surface Area                              \
#               50%    75%  max              count      mean        std    min
# type_micro
# lithic      1.000  1.000  1.0            10191.0  8.644091  98.261697  0.006
# soil        0.748  0.831  1.0            10191.0  3.505370   3.760086  0.052
#
#                                                   Sieve                      \
#               25%       50%      75%       max    count      mean       std
# type_micro
# lithic      0.087  0.124629  0.20555  3211.655  10191.0  0.279873  1.086628
# soil        0.268  1.247000  5.88850    47.600  10191.0  0.722838  0.496046
#
#                                                   Angularity             \
#               min    25%    50%       75%     max      count       mean
# type_micro
# lithic      0.021  0.107  0.136  0.181967  23.529    10191.0  69.685234
# soil        0.125  0.244  0.535  1.146000   3.355    10191.0  39.633408
#
#                                                          Ellipticity  \
#                   std   min     25%   50%   75%      max       count
# type_micro
# lithic      27.656167   0.0  63.333  70.0  85.0  120.000     10191.0
# soil        16.327922  12.0  24.500  37.5  54.0   97.143     10191.0
#
#                                                                        \
#                 mean       std   min       25%    50%     75%     max
# type_micro
# lithic      3.006183  1.800446  1.00  1.851726  2.500  3.5765  23.322
# soil        2.004577  0.605951  1.02  1.626000  1.873  2.2290  10.286
#
#            Fiber Length                                                     \
#                   count      mean       std  min       25%    50%      75%
# type_micro
# lithic          10191.0  0.626391  2.849762  0.0  0.125287  0.272  0.39273
# soil            10191.0  0.416860  0.678387  0.0  0.000000  0.000  0.52200
#
#                    Fiber Width                                         \
#                max       count      mean       std  min    25%    50%
# type_micro
# lithic      52.384     10191.0  0.188157  0.875414  0.0  0.026  0.085
# soil         5.930     10191.0  0.209435  0.361734  0.0  0.000  0.000
#
#
#                  75%     max
# type_micro
# lithic      0.124982  22.823
# soil        0.213000   2.144

# %%
# # Separate majority and minority classes
# df_majority = micro1[micro1.type_micro=='soil']
# df_minority = micro1[micro1.type_micro=='lithic']

# # Downsample majority class
# df_majority_downsampled = resample(df_majority, 
#                                  replace=False,    # sample without replacement
#                                  n_samples=5299,     # to match minority class
#                                  random_state=123) # reproducible results
 
# # Combine minority class with downsampled majority class
# df_downsampled = pd.concat([df_majority_downsampled, df_minority])

# %% [markdown]
# ### Selected features

# %%
# micro1_selected = micro1[["Transparency","FLength","FWidth","FThickness","W/L Ratio", "L/W Ratio", 'Sphericity', 'Circularity', 'Convexity',"type_micro"]]

# %% [markdown]
# ### Hold-out data

# %%
# from sklearn.model_selection import train_test_split
# import numpy as np

# # X is your feature data
# # y is your target data
# X_train, X_holdout, y_train, y_holdout = train_test_split(X, y, test_size=0.1, stratify=y, random_state=42)

# # Now you can perform the train-test split on X_train and y_train
# X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.1, stratify=y_train, random_state=42)

# %% [markdown]
# ## Models

# %% [markdown]
# ### Lazy predict

# %%
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# %%
class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|███████████████████████████████████████████| 29/29 [01:13<00:00,  2.53s/it]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     1.00               1.00    None      1.00
# RandomForestClassifier             0.99               0.99    None      0.99
# ExtraTreesClassifier               0.99               0.99    None      0.99
# AdaBoostClassifier                 0.99               0.99    None      0.99
# BaggingClassifier                  0.99               0.99    None      0.99
# SVC                                0.99               0.99    None      0.99
# LabelSpreading                     0.99               0.99    None      0.99
# LabelPropagation                   0.99               0.99    None      0.99
# DecisionTreeClassifier             0.98               0.98    None      0.98
# KNeighborsClassifier               0.98               0.98    None      0.98
# CalibratedClassifierCV             0.97               0.97    None      0.97
# LinearSVC                          0.97               0.97    None      0.97
# LogisticRegression                 0.97               0.97    None      0.97
# SGDClassifier                      0.97               0.97    None      0.97
# Perceptron                         0.96               0.96    None      0.96
# ExtraTreeClassifier                0.96               0.96    None      0.96
# RidgeClassifier                    0.96               0.96    None      0.96
# LinearDiscriminantAnalysis         0.96               0.96    None      0.96
# RidgeClassifierCV                  0.96               0.96    None      0.96
# PassiveAggressiveClassifier        0.96               0.96    None      0.96
# NuSVC                              0.94               0.94    None      0.94
# QuadraticDiscriminantAnalysis      0.88               0.88    None      0.88
# BernoulliNB                        0.86               0.86    None      0.86
# NearestCentroid                    0.85               0.85    None      0.84
# GaussianNB                         0.74               0.74    None      0.73
# DummyClassifier                    0.50               0.50    None      0.33
#
#                                Time Taken
# Model
# LGBMClassifier                       1.01
# RandomForestClassifier               4.42
# ExtraTreesClassifier                 1.33
# AdaBoostClassifier                   3.21
# BaggingClassifier                    2.66
# SVC                                  2.93
# LabelSpreading                      14.66
# LabelPropagation                     8.77
# DecisionTreeClassifier               0.50
# KNeighborsClassifier                 1.72
# CalibratedClassifierCV               3.70
# LinearSVC                            0.96
# LogisticRegression                   0.32
# SGDClassifier                        0.22
# Perceptron                           0.15
# ExtraTreeClassifier                  0.11
# RidgeClassifier                      0.17
# LinearDiscriminantAnalysis           0.28
# RidgeClassifierCV                    0.40
# PassiveAggressiveClassifier          0.19
# NuSVC                               25.09
# QuadraticDiscriminantAnalysis        0.16
# BernoulliNB                          0.14
# NearestCentroid                      0.12
# GaussianNB                           0.10
# DummyClassifier                      0.07

# %% [markdown]
# ### LightBGM

# %% [markdown]
# #### train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

lgbm = LGBMClassifier(random_state=random_seed)
lgbm.fit(X_train_transformed, y_train_transformed)
print('Accuracy of LGBM classifier on training set: {:.4f}'.format(lgbm.score(X_train_transformed, y_train_transformed)))
print('Accuracy of LGBM classifier on test set: {:.4f}'.format(lgbm.score(X_test_transformed, y_test_transformed)))

pred = lgbm.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, lgbm.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=lgbm.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of LGBM classifier on training set: 1.0000
# Accuracy of LGBM classifier on test set: 0.9971
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2039
#            1       1.00      1.00      1.00      2038
#
#     accuracy                           1.00      4077
#    macro avg       1.00      1.00      1.00      4077
# weighted avg       1.00      1.00      1.00      4077

# %%
acc_train1_LBGM = lgbm.score(X_train_transformed, y_train_transformed)
acc_test1_LBGM = lgbm.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Cross validation for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'num_leaves': [31, 63, 127],
              'learning_rate': [0.1, 0.01, 0.001],
              'n_estimators': [100, 500, 1000]
             }

# %%
grid_search = GridSearchCV(lgbm, param_grid, cv=5)
grid_search.fit(X_train_transformed, y_train_transformed)
# Out:
# GridSearchCV(cv=5, estimator=LGBMClassifier(random_state=42),
#              param_grid={'learning_rate': [0.1, 0.01, 0.001],
#                          'n_estimators': [100, 500, 1000],
#                          'num_leaves': [31, 63, 127]})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'learning_rate': 0.1, 'n_estimators': 1000, 'num_leaves': 31}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 6           1.27          0.25             0.03            0.00
# 3           2.75          0.92             0.03            0.01
# 4           0.94          0.09             0.02            0.00
#
#   param_learning_rate param_n_estimators param_num_leaves  \
# 6                 0.1               1000               31
# 3                 0.1                500               31
# 4                 0.1                500               63
#
#                                               params  split0_test_score  \
# 6  {'learning_rate': 0.1, 'n_estimators': 1000, '...               1.00
# 3  {'learning_rate': 0.1, 'n_estimators': 500, 'n...               1.00
# 4  {'learning_rate': 0.1, 'n_estimators': 500, 'n...               1.00
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 6               1.00               1.00               1.00               1.00
# 3               1.00               1.00               1.00               1.00
# 4               1.00               1.00               1.00               1.00
#
#    mean_test_score  std_test_score  rank_test_score
# 6             1.00            0.00                1
# 3             1.00            0.00                2
# 4             1.00            0.00                3

# %%
# grid_search.predict(x_test)

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of LBGM classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of LBGM classifier on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of LBGM classifier on training set: 1.0000
# Accuracy of LBGM classifier on test set: 0.9971
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2039
#            1       1.00      1.00      1.00      2038
#
#     accuracy                           1.00      4077
#    macro avg       1.00      1.00      1.00      4077
# weighted avg       1.00      1.00      1.00      4077

# %%
acc_train2_LBGM = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_LBGM = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
importances = lgbm.feature_importances_

# Sort the feature importances in descending order
indices = np.argsort(importances)[::-1]
feature_names = data_resampled.columns[1:]
names = [feature_names[i] for i in indices]

importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# Sort the dataframe by importance
importance_df.sort_values(by='importance', ascending=False, inplace=True)

# Print the top 10 features
print(importance_df.head(10))

fi_LGBM = importance_df
# Out:
#           feature_name  importance
# 33         Ellipticity         513
# 24           Curvature         307
# 22              Extent         299
# 13           L/T Ratio         136
# 25        Surface Area         126
# 30  CHull Surface Area         122
# 4              ELength         118
# 27           W/L Ratio         114
# 19            Solidity         102
# 12          Sphericity          99

# %%
# Create plot
plt.figure()

# Create plot title
plt.title("Feature Importance")

# Add bars
plt.bar(range(X_train.shape[1]), importances[indices])

# Add feature names as x-axis labels
plt.xticks(range(X_train.shape[1]), names, rotation=90)

# Show plot
plt.show()

# %% [markdown]
# ### AdaBoost (Adaptive Boosting)

# %% [markdown]
# #### Train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

ada = AdaBoostClassifier(random_state=random_seed)
ada.fit(X_train_transformed, y_train_transformed)
print('Accuracy of LGBM classifier on training set: {:.4f}'.format(ada.score(X_train_transformed, y_train_transformed)))
print('Accuracy of LGBM classifier on test set: {:.4f}'.format(ada.score(X_test_transformed, y_test_transformed)))

pred = ada.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, ada.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=ada.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of LGBM classifier on training set: 0.9914
# Accuracy of LGBM classifier on test set: 0.9909
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2039
#            1       0.99      0.99      0.99      2038
#
#     accuracy                           0.99      4077
#    macro avg       0.99      0.99      0.99      4077
# weighted avg       0.99      0.99      0.99      4077

# %%
acc_train1_ada = ada.score(X_train_transformed, y_train_transformed)
acc_test1_ada = ada.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Cross validation for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_estimators': [50, 100, 150],
              'learning_rate': [0.1, 0.5, 1.0],
              'algorithm': ['SAMME', 'SAMME.R']}

# %%
grid_search = GridSearchCV(ada, param_grid, cv=5)
grid_search.fit(X_train_transformed, y_train_transformed)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(random_state=42),
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.1, 0.5, 1.0],
#                          'n_estimators': [50, 100, 150]})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'algorithm': 'SAMME.R', 'learning_rate': 1.0, 'n_estimators': 150}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 17           5.01          0.05             0.07            0.00
# 16           3.30          0.01             0.05            0.00
# 14           5.40          0.09             0.07            0.00
#
#    param_algorithm param_learning_rate param_n_estimators  \
# 17         SAMME.R                 1.0                150
# 16         SAMME.R                 1.0                100
# 14         SAMME.R                 0.5                150
#
#                                                params  split0_test_score  \
# 17  {'algorithm': 'SAMME.R', 'learning_rate': 1.0,...               0.99
# 16  {'algorithm': 'SAMME.R', 'learning_rate': 1.0,...               0.99
# 14  {'algorithm': 'SAMME.R', 'learning_rate': 0.5,...               0.99
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 17               0.99               0.99               0.99
# 16               0.99               0.99               0.99
# 14               0.99               0.99               0.99
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 17               1.00             0.99            0.00                1
# 16               0.99             0.99            0.00                2
# 14               0.99             0.99            0.00                3

# %%
# grid_search.predict(x_test)

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of AdaBoost classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of AdaBoost classifier on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of AdaBoost classifier on training set: 0.9978
# Accuracy of AdaBoost classifier on test set: 0.9961
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2039
#            1       1.00      1.00      1.00      2038
#
#     accuracy                           1.00      4077
#    macro avg       1.00      1.00      1.00      4077
# weighted avg       1.00      1.00      1.00      4077

# %%
acc_train2_ada = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_ada = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
importances = ada.feature_importances_

# Sort the feature importances in descending order
indices = np.argsort(importances)[::-1]
feature_names = data_resampled.columns[1:]
names = [feature_names[i] for i in indices]

importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# Sort the dataframe by importance
importance_df.sort_values(by='importance', ascending=False, inplace=True)

# Print the top 10 features
print(importance_df.head(10))

fi_ada = importance_df
# Out:
#           feature_name  importance
# 33         Ellipticity        0.20
# 24           Curvature        0.12
# 22              Extent        0.10
# 12          Sphericity        0.10
# 30  CHull Surface Area        0.08
# 4              ELength        0.04
# 14    T/L Aspect Ratio        0.04
# 13           L/T Ratio        0.04
# 26           L/W Ratio        0.04
# 25        Surface Area        0.04

# %%
# Create plot
plt.figure()

# Create plot title
plt.title("Feature Importance")

# Add bars
plt.bar(range(X_train.shape[1]), importances[indices])

# Add feature names as x-axis labels
plt.xticks(range(X_train.shape[1]), names, rotation=90)

# Show plot
plt.show()

# %% [markdown]
# ### Random forest

# %% [markdown]
# #### Train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

X_holdout = X_test
y_holdout = y_test

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

rf = RandomForestClassifier(random_state=random_seed)
rf.fit(X_train_transformed, y_train_transformed)
print('Accuracy of RF classifier on training set: {:.4f}'.format(rf.score(X_train_transformed, y_train_transformed)))
print('Accuracy of RF classifier on test set: {:.4f}'.format(rf.score(X_test_transformed, y_test_transformed)))

pred = rf.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, rf.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=rf.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of RF classifier on training set: 1.0000
# Accuracy of RF classifier on test set: 0.9924
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2039
#            1       0.99      0.99      0.99      2038
#
#     accuracy                           0.99      4077
#    macro avg       0.99      0.99      0.99      4077
# weighted avg       0.99      0.99      0.99      4077

# %%
acc_train1_rf = rf.score(X_train_transformed, y_train_transformed)
acc_test1_rf = rf.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Grid search for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_estimators': [10, 50, 100],
              'max_depth': [None, 5, 10],
              'min_samples_split': [2, 5, 10]}
#               'min_samples_leaf': [1, 2, 4],
#               'max_features': ['auto', 'sqrt', 'log2'],
#               'max_leaf_nodes': [10, 20, 30],
#               'class_weight':[None, 'balanced'],
#               'criterion': ['gini', 'entropy']}

# %%
grid_search = GridSearchCV(rf, param_grid, cv=5)
grid_search.fit(X_test_transformed, y_test_transformed)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'max_depth': [None, 5, 10],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 50, 100]})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 50}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1           0.35          0.01             0.01            0.00
# 2           0.69          0.01             0.01            0.00
# 5           0.69          0.02             0.01            0.00
#
#   param_max_depth param_min_samples_split param_n_estimators  \
# 1            None                       2                 50
# 2            None                       2                100
# 5            None                       5                100
#
#                                               params  split0_test_score  \
# 1  {'max_depth': None, 'min_samples_split': 2, 'n...               0.99
# 2  {'max_depth': None, 'min_samples_split': 2, 'n...               0.99
# 5  {'max_depth': None, 'min_samples_split': 5, 'n...               0.99
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 1               0.98               0.98               0.99               0.98
# 2               0.98               0.98               0.99               0.98
# 5               0.98               0.98               0.99               0.98
#
#    mean_test_score  std_test_score  rank_test_score
# 1             0.98            0.00                1
# 2             0.98            0.00                2
# 5             0.98            0.00                3

# %% [markdown]
# #### Cross validation

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score
# Perform cross-validation after grid search
scores = cross_val_score(grid_search, X_test_transformed, y_test_transformed, cv=10)
print("Cross-validation scores: ", scores)
print("Mean accuracy: ", scores.mean())
# Out:
# Cross-validation scores:  [0.99509804 0.9754902  0.98284314 0.98039216 0.97303922 0.9754902
#  0.98284314 0.99017199 0.98280098 0.97788698]
# Mean accuracy:  0.9816056029291322

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of Random Forest classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of Random Forest classifier on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of Random Forest classifier on training set: 0.9831
# Accuracy of Random Forest classifier on test set: 1.0000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2039
#            1       1.00      1.00      1.00      2038
#
#     accuracy                           1.00      4077
#    macro avg       1.00      1.00      1.00      4077
# weighted avg       1.00      1.00      1.00      4077

# %%
acc_train2_rf = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_rf = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
importances = rf.feature_importances_

# Sort the feature importances in descending order
indices = np.argsort(importances)[::-1]
feature_names = data_resampled.columns[1:]
names = [feature_names[i] for i in indices]

importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# Sort the dataframe by importance
importance_df.sort_values(by='importance', ascending=False, inplace=True)

# Print the top 10 features
print(importance_df.head(10))

fi_rf = importance_df
# Out:
#           feature_name  importance
# 30  CHull Surface Area        0.17
# 29           T/W Ratio        0.12
# 2              FLength        0.09
# 7               Volume        0.08
# 33         Ellipticity        0.06
# 32          Angularity        0.05
# 27           W/L Ratio        0.05
# 28           W/T Ratio        0.05
# 19            Solidity        0.04
# 13           L/T Ratio        0.03

# %%
# Create plot
plt.figure()

# Create plot title
plt.title("Feature Importance")

# Add bars
plt.bar(range(X_train.shape[1]), importances[indices])

# Add feature names as x-axis labels
plt.xticks(range(X_train.shape[1]), names, rotation=90)

# Show plot
plt.show()

# %% [markdown]
# ### Bagging (Bootstrapped Aggregation)

# %% [markdown]
# #### Train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

base_estimator = DecisionTreeClassifier(max_depth=4, random_state=random_seed)
bagging = BaggingClassifier(base_estimator=base_estimator, random_state=random_seed)
bagging.fit(X_train_transformed, y_train_transformed)
print('Accuracy of LGBM classifier on training set: {:.4f}'.format(bagging.score(X_train_transformed, y_train_transformed)))
print('Accuracy of LGBM classifier on test set: {:.4f}'.format(bagging.score(X_test_transformed, y_test_transformed)))

pred = bagging.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, bagging.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=bagging.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of LGBM classifier on training set: 0.9728
# Accuracy of LGBM classifier on test set: 0.9728
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      2039
#            1       0.96      0.98      0.97      2038
#
#     accuracy                           0.97      4077
#    macro avg       0.97      0.97      0.97      4077
# weighted avg       0.97      0.97      0.97      4077

# %%
acc_train1_bagging = bagging.score(X_train_transformed, y_train_transformed)
acc_test1_bagging = bagging.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Cross validation for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_estimators': [50, 100, 150],
              'max_samples': [0.5, 1.0, 2.0],
              'max_features': [0.5, 1.0, 2.0]}

# %%
grid_search = GridSearchCV(bagging, param_grid, cv=5)
grid_search.fit(X_train_transformed, y_train_transformed)
# Out:
# GridSearchCV(cv=5,
#              estimator=BaggingClassifier(base_estimator=DecisionTreeClassifier(max_depth=4,
#                                                                                random_state=42),
#                                          random_state=42),
#              param_grid={'max_features': [0.5, 1.0, 2.0],
#                          'max_samples': [0.5, 1.0, 2.0],
#                          'n_estimators': [50, 100, 150]})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 100}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 11           7.78          0.33             0.10            0.03
# 10           5.40          0.12             0.06            0.01
# 9            2.76          0.15             0.03            0.01
#
#    param_max_features param_max_samples param_n_estimators  \
# 11                1.0               0.5                150
# 10                1.0               0.5                100
# 9                 1.0               0.5                 50
#
#                                                params  split0_test_score  \
# 11  {'max_features': 1.0, 'max_samples': 0.5, 'n_e...               0.97
# 10  {'max_features': 1.0, 'max_samples': 0.5, 'n_e...               0.97
# 9   {'max_features': 1.0, 'max_samples': 0.5, 'n_e...               0.97
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 11               0.98               0.97               0.97
# 10               0.98               0.97               0.97
# 9                0.98               0.97               0.97
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 11               0.97             0.97            0.00                1
# 10               0.97             0.97            0.00                1
# 9                0.97             0.97            0.00                3

# %%
# grid_search.predict(x_test)

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of Bagging classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of Bagging classifie on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of Bagging classifier on training set: 0.9733
# Accuracy of Bagging classifie on test set: 0.9738
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      2039
#            1       0.96      0.98      0.97      2038
#
#     accuracy                           0.97      4077
#    macro avg       0.97      0.97      0.97      4077
# weighted avg       0.97      0.97      0.97      4077

# %%
acc_train2_bagging = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_bagging = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
# importances = bagging.feature_importances_

# # Sort the feature importances in descending order
# indices = np.argsort(importances)[::-1]
# feature_names = data_resampled.columns[1:]
# names = [feature_names[i] for i in indices]

# importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# # Sort the dataframe by importance
# importance_df.sort_values(by='importance', ascending=False, inplace=True)

# # Print the top 10 features
# print(importance_df.head(10))

# fi_bagging = importance_df

# %%
# # Create plot
# plt.figure()

# # Create plot title
# plt.title("Feature Importance")

# # Add bars
# plt.bar(range(X_train.shape[1]), importances[indices])

# # Add feature names as x-axis labels
# plt.xticks(range(X_train.shape[1]), names, rotation=90)

# # Show plot
# plt.show()

# %% [markdown]
# ### SVC (Support Vector Classification)

# %% [markdown]
# #### Train-test split

# %%
# machine learning libs
from sklearn.model_selection import train_test_split

class_column = ['type_micro']
random_seed = 42

features = data_resampled.drop(columns=class_column)
target = data_resampled[class_column]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, 
                                                    random_state=random_seed, 
                                                    stratify=data_resampled[class_column])

# %%
# # X Train
# print('On X train: ')
# print('X train dimensions: ', X_train.shape)
# display(X_train.head())

# # X test
# print('\nOn X test: ')
# print('X test dimensions: ', X_test.shape)
# display(X_test.head())

# %%
# # X Train
# print('On y train: ')
# print('y train dimensions: ', y_train.shape)
# display(y_train.head())

# # X test
# print('\nOn y test: ')
# print('y test dimensions: ', y_test.shape)
# display(y_test.head())

# %% [markdown]
# #### Data Preprocessing - Imputation
# Not needed for imputation for this data

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# # fill missing values with medians
# imputer = SimpleImputer(strategy='median')
# X_train_transformed = imputer.fit_transform(X_train)
# scale the data
scale = StandardScaler()
X_train_transformed = scale.fit_transform(X_train)

# apply imputer and scaler to test data. But here we will not apply the
# fit method because we do not want the model to learn anything from the test data!
# X_test_transformed = imputer.transform(X_test)
X_test_transformed = scale.transform(X_test)

# Encode the target as well since it's categorical - we can also transform the target column using pandas
le = LabelEncoder()
le.fit(y_train)
y_train_transformed = le.transform(y_train)
y_test_transformed = le.transform(y_test)
le.classes_
# Out:
# array(['lithic', 'soil'], dtype=object)

# %% [markdown]
# #### Modeling

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

random_seed = 42

svc = SVC(random_state=random_seed)
svc.fit(X_train_transformed, y_train_transformed)
print('Accuracy of LR classifier on training set: {:.4f}'.format(svc.score(X_train_transformed, y_train_transformed)))
print('Accuracy of LR classifier on test set: {:.4f}'.format(svc.score(X_test_transformed, y_test_transformed)))

pred = svc.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, svc.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svc.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of LR classifier on training set: 0.9879
# Accuracy of LR classifier on test set: 0.9865
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      2039
#            1       0.99      0.98      0.99      2038
#
#     accuracy                           0.99      4077
#    macro avg       0.99      0.99      0.99      4077
# weighted avg       0.99      0.99      0.99      4077

# %%
acc_train1_svc = svc.score(X_train_transformed, y_train_transformed)
acc_test1_svc = svc.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Cross validation for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C': [0.1, 1, 10],
              'kernel': ['linear', 'rbf', 'poly'],
              'gamma': [0.01, 0.1, 1]}

# %%
grid_search = GridSearchCV(svc, param_grid, cv=5)
grid_search.fit(X_test_transformed, y_test_transformed)
# Out:
# GridSearchCV(cv=5, estimator=SVC(random_state=42),
#              param_grid={'C': [0.1, 1, 10], 'gamma': [0.01, 0.1, 1],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
print("Best parameters found: ",grid_search.best_params_)
# Out:
# Best parameters found:  {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 22           0.09          0.01             0.06            0.00      10
# 23           0.10          0.00             0.01            0.00      10
# 8            0.15          0.02             0.01            0.00     0.1
#
#    param_gamma param_kernel                                     params  \
# 22         0.1          rbf   {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 23         0.1         poly  {'C': 10, 'gamma': 0.1, 'kernel': 'poly'}
# 8            1         poly   {'C': 0.1, 'gamma': 1, 'kernel': 'poly'}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 22               0.98               0.99               0.99
# 23               0.98               0.98               0.98
# 8                0.97               0.98               0.98
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 22               0.99               0.98             0.99            0.00
# 23               0.98               0.98             0.98            0.00
# 8                0.98               0.98             0.98            0.00
#
#     rank_test_score
# 22                1
# 23                2
# 8                 3

# %%
# grid_search.predict(x_test)

# %% [markdown]
# #### Re-run model

# %%
print('Accuracy of SV classifier on training set: {:.4f}'.format(grid_search.score(X_train_transformed, y_train_transformed)))
print('Accuracy of SV classifie on test set: {:.4f}'.format(grid_search.score(X_test_transformed, y_test_transformed)))

pred = grid_search.predict(X_test_transformed)

print(classification_report(y_test_transformed, pred))

cm = confusion_matrix(y_test_transformed, grid_search.predict(X_test_transformed))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.classes_)
disp.plot()

plt.show()
# Out:
# Accuracy of SV classifier on training set: 0.9882
# Accuracy of SV classifie on test set: 0.9975
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2039
#            1       1.00      1.00      1.00      2038
#
#     accuracy                           1.00      4077
#    macro avg       1.00      1.00      1.00      4077
# weighted avg       1.00      1.00      1.00      4077

# %%
acc_train2_svc = grid_search.score(X_train_transformed, y_train_transformed)
acc_test2_svc = grid_search.score(X_test_transformed, y_test_transformed)

# %% [markdown]
# #### Feature importance

# %%
# importances = svc.feature_importances_

# # Sort the feature importances in descending order
# indices = np.argsort(importances)[::-1]
# feature_names = data_resampled.columns[1:]
# names = [feature_names[i] for i in indices]

# importance_df = pd.DataFrame({'feature_name': feature_names, 'importance': importances})

# # Sort the dataframe by importance
# importance_df.sort_values(by='importance', ascending=False, inplace=True)

# # Print the top 10 features
# print(importance_df.head(10))

# fi_svc = importance_df

# %%
# # Create plot
# plt.figure()

# # Create plot title
# plt.title("Feature Importance")

# # Add bars
# plt.bar(range(X_train.shape[1]), importances[indices])

# # Add feature names as x-axis labels
# plt.xticks(range(X_train.shape[1]), names, rotation=90)

# # Show plot
# plt.show()

# %%
### XGBoost

# %%
### Gradient Boosting

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ### Model accuracies

# %%
df = {'model': ['LightGBM', 'AdaBoost', 'Random Forest', 'Bagging', 'SVC'], 
            'train_accuracy': [acc_train1_LBGM, acc_train1_ada, acc_train1_rf, acc_train1_bagging, acc_train1_svc], 
            'test_accuracy': [acc_test1_LBGM, acc_test1_ada, acc_test1_rf, acc_test1_bagging, acc_test1_svc],
            'train_accuracy_CV': [acc_train2_LBGM, acc_train2_ada, acc_train2_rf, acc_train2_bagging, acc_train2_svc], 
            'test_accuracy_CV': [acc_test2_LBGM, acc_test2_ada, acc_test2_rf, acc_test2_bagging, acc_test2_svc]}

accuracy = pd.DataFrame(df)

# %%
df = pd.DataFrame(df)
df
# Out:
#            model  train_accuracy  test_accuracy  train_accuracy_CV  \
# 0       LightGBM            1.00           1.00               1.00
# 1       AdaBoost            0.99           0.99               1.00
# 2  Random Forest            1.00           0.99               0.98
# 3        Bagging            0.97           0.97               0.97
# 4            SVC            0.99           0.99               0.99
#
#    test_accuracy_CV
# 0              1.00
# 1              1.00
# 2              1.00
# 3              0.97
# 4              1.00

# %%
bar_width = 0.35

models = np.arange(len(df['model']))

plt.bar(models - bar_width/2, df['test_accuracy'], bar_width, 
        color='#FF8F45', label='test accuracy', alpha=0.9)
plt.bar(models + bar_width/2, df['test_accuracy_CV'], bar_width, 
        color='#7CF3A0', label='test accuracy after CV', alpha=0.9)

plt.xticks(models, df['model'])
plt.ylim(0.95, 1)
plt.legend()
plt.show()

# %%
bar_width = 0.4
index = df.index

fig, ax = plt.subplots(figsize=(10, 5))

train_acc = ax.bar(index, df['test_accuracy'], bar_width, color='b')
test_acc = ax.bar(index + bar_width, df['test_accuracy_CV'], bar_width, color='r')

ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(df['model'])
ax.set_ylabel('Accuracy')
ax.set_title('Train and Test Accuracy by Model')

plt.legend((train_acc[0], test_acc[0]), ('Test Accuracy', 'Test Accuracy after CV'))

for i, v in enumerate(df['test_accuracy']):
    plt.text(i - bar_width/2, v + 0.01, format(v, '.4f'), fontsize=8, ha='center', va='bottom')

for i, v in enumerate(df['test_accuracy_CV']):
    plt.text(i + bar_width/2, v + 0.01, format(v, '.4f'), fontsize=8, ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
df.to_csv("accuracy_1mm_over.csv")

# %%
# acc_train1_LBGM
# acc_test1_LBGM

# acc_train1_ada
# acc_test1_ada

# acc_train1_rf
# acc_test1_rf

# acc_train1_bagging
# acc_test1_bagging

# acc_train1_svc 
# acc_test1_svc

# acc_train2_LBGM
# acc_test2_LBGM

# acc_train2_ada 
# acc_test2_ada 

# acc_train2_rf
# acc_test2_rf

# acc_train2_bagging 
# acc_test2_bagging

# acc_train2_svc
# acc_test2_svc

# %% [markdown]
# ### Overall feature importance

# %%
fi_LGBM['importance'] = fi_LGBM['importance'] / fi_LGBM['importance'].sum()

# %%
fi_LGBM['rank'] = range(1, fi_LGBM.shape[0]+1)

# %%
fi_LGBM.head(5)
# Out:
#     feature_name  importance  rank
# 33   Ellipticity        0.17     1
# 24     Curvature        0.10     2
# 22        Extent        0.10     3
# 13     L/T Ratio        0.05     4
# 25  Surface Area        0.04     5

# %%
fi_LGBM = fi_LGBM[['feature_name','importance']]
fi_LGBM = fi_LGBM.reset_index(drop=True)

# %%
fi_ada['rank'] = range(1, fi_ada.shape[0]+1)

# %%
fi_ada.head(5)
# Out:
#           feature_name  importance  rank
# 33         Ellipticity        0.20     1
# 24           Curvature        0.12     2
# 22              Extent        0.10     3
# 12          Sphericity        0.10     4
# 30  CHull Surface Area        0.08     5

# %%
fi_ada = fi_ada[['feature_name','importance']]
fi_ada = fi_ada.reset_index(drop=True)

# %%
fi_rf['rank'] = range(1, fi_rf.shape[0]+1)

# %%
fi_rf.head()
# Out:
#           feature_name  importance  rank
# 30  CHull Surface Area        0.17     1
# 29           T/W Ratio        0.12     2
# 2              FLength        0.09     3
# 7               Volume        0.08     4
# 33         Ellipticity        0.06     5

# %%
fi_rf = fi_rf[['feature_name','importance']]
fi_rf = fi_rf.reset_index(drop=True)

# %%
fi = pd.concat([fi_LGBM, fi_ada, fi_rf])

# %%
mean_rank = fi.groupby('feature_name').mean()
mean_rank.sort_values(by='importance', ascending=False, inplace=True)

# %%
mean_rank.head(10)
# Out:
#                     importance
# feature_name
# Ellipticity               0.14
# CHull Surface Area        0.10
# Curvature                 0.08
# Extent                    0.07
# Sphericity                0.05
# T/W Ratio                 0.04
# FLength                   0.04
# L/T Ratio                 0.04
# W/L Ratio                 0.04
# ELength                   0.03

# %%
import matplotlib.pyplot as plt

mean_rank.reset_index(inplace=True)
mean_rank.head(15).plot(kind='bar', x='feature_name', y='importance')
plt.xlabel('Feature name')
plt.ylabel('Feature importance')
plt.title('Overall feature importance')
plt.show()

# %%
mean_rank[['feature_name','importance']]
# Out:
#           feature_name  importance
# 0          Ellipticity        0.14
# 1   CHull Surface Area        0.10
# 2            Curvature        0.08
# 3               Extent        0.07
# 4           Sphericity        0.05
# 5            T/W Ratio        0.04
# 6              FLength        0.04
# 7            L/T Ratio        0.04
# 8            W/L Ratio        0.04
# 9              ELength        0.03
# 10              Volume        0.03
# 11        Surface Area        0.03
# 12            Solidity        0.03
# 13          Angularity        0.03
# 14    T/L Aspect Ratio        0.03
# 15           L/W Ratio        0.03
# 16           W/T Ratio        0.02
# 17          FThickness        0.02
# 18                  Dp        0.02
# 19              FWidth        0.02
# 20         Circularity        0.01
# 21          type_micro        0.01
# 22                Area        0.01
# 23         Fiber Width        0.01
# 24              EWidth        0.01
# 25               Sieve        0.01
# 26           Perimeter        0.01
# 27           Roundness        0.01
# 28         Compactness        0.01
# 29       Ellipse Ratio        0.01
# 30        Transparency        0.01
# 31           Concavity        0.01
# 32          EThickness        0.01
# 33           Convexity        0.00
# 34        Fiber Length        0.00
# 35     CHull Perimeter        0.00
# 36         CHull  Area        0.00

# %%
mean_rank[['feature_name','importance']].to_csv("fi_1mm_over.csv")
